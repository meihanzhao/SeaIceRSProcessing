# %% [markdown]
# # cmems

# %% [markdown]
# ## 散点图

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

plt.rcParams['font.sans-serif'] = ['SimHei']

def plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date, output_dir):
    """
    绘制订正前、订正后的非参考数据与参考数据的散点图
    :param non_ref_data: 订正前的非参考数据 (2D numpy array)
    :param corrected_data: 订正后的非参考数据 (2D numpy array)
    :param ref_data: 参考数据 (2D numpy array)
    :param date: 当前日期 (str)
    :param output_dir: 输出散点图的保存目录
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 平铺数组，去除 NaN 数据
    mask = (~np.isnan(non_ref_data)) & (~np.isnan(ref_data))
    x_non_ref = non_ref_data[mask]
    x_corrected = corrected_data[mask]
    y_ref = ref_data[mask]
    
    # 绘制订正前的散点图
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_non_ref, y_ref, s=2, alpha=0.5, color='blue')
    plt.plot([0, 3], [0, 3], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 3)
    plt.ylim(0, 3)
   
    plt.xlabel("非参考数据 (订正前)")
    plt.ylabel("参考数据")
    plt.title(f"订正前 ({date})")
    
    # 绘制订正后的散点图
    plt.subplot(1, 2, 2)
    plt.scatter(x_corrected, y_ref, s=2, alpha=0.5, color='red')
    plt.plot([0, 3], [0, 3], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 3)
    plt.ylim(0, 3)
    plt.xlabel("非参考数据 (订正后)")
    plt.ylabel("参考数据")
    plt.title(f"订正后 ({date})")
    
    # 保存散点图
    plt.tight_layout()
    output_file = os.path.join(output_dir, f"scatter_comparison_{date}.png")
    plt.savefig(output_file, dpi=100)
    plt.close()
    print(f"Saved scatter plot: {output_file}")

def generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date):
    """
    生成非参考数据的订正前后与参考数据的散点图
    :param input_dir: 订正前非参考数据目录
    :param corrected_dir: 订正后数据目录
    :param reference_dir: 参考数据目录
    :param output_dir: 输出散点图的保存目录
    :param hemisphere: 'north' 或 'south'
    :param start_date: 开始日期 (str)
    :param end_date: 结束日期 (str)
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        date_str = date.strftime('%Y%m%d')
        print(f"Processing scatter plot for date: {date_str}")

        # 文件路径
        ref_file = os.path.join(reference_dir, f"APPX_{hemisphere}_SIT_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"cmems_pdfcorrected_{hemisphere}_SIT_25000_{date_str}.nc")
        non_ref_file = os.path.join(input_dir, f"cmems_{hemisphere}_SIT_25000_{date_str}.nc")

        # 检查文件是否存在
        if not all(os.path.exists(f) for f in [ref_file, corrected_file, non_ref_file]):
            print(f"Missing file for date {date_str}, skipping...")
            continue

        # 读取数据
        ref_data = xr.open_dataset(ref_file)['appx_sit'].values
        corrected_data = xr.open_dataset(corrected_file)['cmems_sit'].values
        non_ref_data = xr.open_dataset(non_ref_file)['cmems_sit'].values

        # 绘制散点图
        plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date_str, output_dir)

if __name__ == "__main__":
    import pandas as pd

    # 文件目录路径
    input_dir = r"D:\zmh\icethickness\Copernicus-Global\0_pre_com\north"
    corrected_dir = r"D:\zmh\icethickness\Copernicus-Global\1_PDFcorrected\north"
    reference_dir = r"D:\zmh\icethickness\APP-X\0_pre_com\north"
    output_dir = r"D:\zmh\icethickness\Copernicus-Global\2_scatter_plots"
    # 若output_dir不存在，创建output_dir
    os.makedirs(output_dir, exist_ok=True)

    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing scatter plot for date: 20220101
# Missing file for date 20220101, skipping...
# Processing scatter plot for date: 20220102
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220102.png
# Processing scatter plot for date: 20220103
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220103.png
# Processing scatter plot for date: 20220104
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220104.png
# Processing scatter plot for date: 20220105
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220105.png
# Processing scatter plot for date: 20220106
# Missing file for date 20220106, skipping...
# Processing scatter plot for date: 20220107
# Missing file for date 20220107, skipping...
# Processing scatter plot for date: 20220108
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220108.png
# Processing scatter plot for date: 20220109
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220109.png
# Processing scatter plot for date: 20220110
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220110.png
# Processing scatter plot for date: 20220111
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220111.png
# Processing scatter plot for date: 20220112
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220112.png
# Processing scatter plot for date: 20220113
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220113.png
# Processing scatter plot for date: 20220114
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220114.png
# Processing scatter plot for date: 20220115
# Missing file for date 20220115, skipping...
# Processing scatter plot for date: 20220116
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220116.png
# Processing scatter plot for date: 20220117
# Missing file for date 20220117, skipping...
# Processing scatter plot for date: 20220118
# Missing file for date 20220118, skipping...
# Processing scatter plot for date: 20220119
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220119.png
# Processing scatter plot for date: 20220120
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220120.png
# Processing scatter plot for date: 20220121
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220121.png
# Processing scatter plot for date: 20220122
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220122.png
# Processing scatter plot for date: 20220123
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220123.png
# Processing scatter plot for date: 20220124
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220124.png
# Processing scatter plot for date: 20220125
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220125.png
# Processing scatter plot for date: 20220126
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220126.png
# Processing scatter plot for date: 20220127
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220127.png
# Processing scatter plot for date: 20220128
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220128.png
# Processing scatter plot for date: 20220129
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220129.png
# Processing scatter plot for date: 20220130
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220130.png
# Processing scatter plot for date: 20220131
# Missing file for date 20220131, skipping...
# Processing scatter plot for date: 20220201
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220201.png
# Processing scatter plot for date: 20220202
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220202.png
# Processing scatter plot for date: 20220203
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220203.png
# Processing scatter plot for date: 20220204
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220204.png
# Processing scatter plot for date: 20220205
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220205.png
# Processing scatter plot for date: 20220206
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220206.png
# Processing scatter plot for date: 20220207
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220207.png
# Processing scatter plot for date: 20220208
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220208.png
# Processing scatter plot for date: 20220209
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220209.png
# Processing scatter plot for date: 20220210
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220210.png
# Processing scatter plot for date: 20220211
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220211.png
# Processing scatter plot for date: 20220212
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220212.png
# Processing scatter plot for date: 20220213
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220213.png
# Processing scatter plot for date: 20220214
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220214.png
# Processing scatter plot for date: 20220215
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220215.png
# Processing scatter plot for date: 20220216
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220216.png
# Processing scatter plot for date: 20220217
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220217.png
# Processing scatter plot for date: 20220218
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220218.png
# Processing scatter plot for date: 20220219
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220219.png
# Processing scatter plot for date: 20220220
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220220.png
# Processing scatter plot for date: 20220221
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220221.png
# Processing scatter plot for date: 20220222
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220222.png
# Processing scatter plot for date: 20220223
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220223.png
# Processing scatter plot for date: 20220224
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220224.png
# Processing scatter plot for date: 20220225
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220225.png
# Processing scatter plot for date: 20220226
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220226.png
# Processing scatter plot for date: 20220227
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220227.png
# Processing scatter plot for date: 20220228
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220228.png
# Processing scatter plot for date: 20220301
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220301.png
# Processing scatter plot for date: 20220302
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220302.png
# Processing scatter plot for date: 20220303
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220303.png
# Processing scatter plot for date: 20220304
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220304.png
# Processing scatter plot for date: 20220305
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220305.png
# Processing scatter plot for date: 20220306
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220306.png
# Processing scatter plot for date: 20220307
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220307.png
# Processing scatter plot for date: 20220308
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220308.png
# Processing scatter plot for date: 20220309
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220309.png
# Processing scatter plot for date: 20220310
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220310.png
# Processing scatter plot for date: 20220311
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220311.png
# Processing scatter plot for date: 20220312
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220312.png
# Processing scatter plot for date: 20220313
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220313.png
# Processing scatter plot for date: 20220314
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220314.png
# Processing scatter plot for date: 20220315
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220315.png
# Processing scatter plot for date: 20220316
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220316.png
# Processing scatter plot for date: 20220317
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220317.png
# Processing scatter plot for date: 20220318
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220318.png
# Processing scatter plot for date: 20220319
# Missing file for date 20220319, skipping...
# Processing scatter plot for date: 20220320
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220320.png
# Processing scatter plot for date: 20220321
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220321.png
# Processing scatter plot for date: 20220322
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220322.png
# Processing scatter plot for date: 20220323
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220323.png
# Processing scatter plot for date: 20220324
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220324.png
# Processing scatter plot for date: 20220325
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220325.png
# Processing scatter plot for date: 20220326
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220326.png
# Processing scatter plot for date: 20220327
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220327.png
# Processing scatter plot for date: 20220328
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220328.png
# Processing scatter plot for date: 20220329
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220329.png
# Processing scatter plot for date: 20220330
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220330.png
# Processing scatter plot for date: 20220331
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220331.png
# Processing scatter plot for date: 20220401
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220401.png
# Processing scatter plot for date: 20220402
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220402.png
# Processing scatter plot for date: 20220403
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220403.png
# Processing scatter plot for date: 20220404
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220404.png
# Processing scatter plot for date: 20220405
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220405.png
# Processing scatter plot for date: 20220406
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220406.png
# Processing scatter plot for date: 20220407
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220407.png
# Processing scatter plot for date: 20220408
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220408.png
# Processing scatter plot for date: 20220409
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220409.png
# Processing scatter plot for date: 20220410
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220410.png
# Processing scatter plot for date: 20220411
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220411.png
# Processing scatter plot for date: 20220412
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220412.png
# Processing scatter plot for date: 20220413
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220413.png
# Processing scatter plot for date: 20220414
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220414.png
# Processing scatter plot for date: 20220415
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220415.png
# Processing scatter plot for date: 20220416
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220416.png
# Processing scatter plot for date: 20220417
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220417.png
# Processing scatter plot for date: 20220418
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220418.png
# Processing scatter plot for date: 20220419
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220419.png
# Processing scatter plot for date: 20220420
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220420.png
# Processing scatter plot for date: 20220421
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220421.png
# Processing scatter plot for date: 20220422
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220422.png
# Processing scatter plot for date: 20220423
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220423.png
# Processing scatter plot for date: 20220424
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220424.png
# Processing scatter plot for date: 20220425
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220425.png
# Processing scatter plot for date: 20220426
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220426.png
# Processing scatter plot for date: 20220427
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220427.png
# Processing scatter plot for date: 20220428
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220428.png
# Processing scatter plot for date: 20220429
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220429.png
# Processing scatter plot for date: 20220430
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220430.png
# Processing scatter plot for date: 20220501
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220501.png
# Processing scatter plot for date: 20220502
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220502.png
# Processing scatter plot for date: 20220503
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220503.png
# Processing scatter plot for date: 20220504
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220504.png
# Processing scatter plot for date: 20220505
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220505.png
# Processing scatter plot for date: 20220506
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220506.png
# Processing scatter plot for date: 20220507
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220507.png
# Processing scatter plot for date: 20220508
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220508.png
# Processing scatter plot for date: 20220509
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220509.png
# Processing scatter plot for date: 20220510
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220510.png
# Processing scatter plot for date: 20220511
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220511.png
# Processing scatter plot for date: 20220512
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220512.png
# Processing scatter plot for date: 20220513
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220513.png
# Processing scatter plot for date: 20220514
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220514.png
# Processing scatter plot for date: 20220515
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220515.png
# Processing scatter plot for date: 20220516
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220516.png
# Processing scatter plot for date: 20220517
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220517.png
# Processing scatter plot for date: 20220518
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220518.png
# Processing scatter plot for date: 20220519
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220519.png
# Processing scatter plot for date: 20220520
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220520.png
# Processing scatter plot for date: 20220521
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220521.png
# Processing scatter plot for date: 20220522
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220522.png
# Processing scatter plot for date: 20220523
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220523.png
# Processing scatter plot for date: 20220524
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220524.png
# Processing scatter plot for date: 20220525
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220525.png
# Processing scatter plot for date: 20220526
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220526.png
# Processing scatter plot for date: 20220527
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220527.png
# Processing scatter plot for date: 20220528
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220528.png
# Processing scatter plot for date: 20220529
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220529.png
# Processing scatter plot for date: 20220530
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220530.png
# Processing scatter plot for date: 20220531
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220531.png
# Processing scatter plot for date: 20220601
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220601.png
# Processing scatter plot for date: 20220602
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220602.png
# Processing scatter plot for date: 20220603
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220603.png
# Processing scatter plot for date: 20220604
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220604.png
# Processing scatter plot for date: 20220605
# Missing file for date 20220605, skipping...
# Processing scatter plot for date: 20220606
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220606.png
# Processing scatter plot for date: 20220607
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220607.png
# Processing scatter plot for date: 20220608
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220608.png
# Processing scatter plot for date: 20220609
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220609.png
# Processing scatter plot for date: 20220610
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220610.png
# Processing scatter plot for date: 20220611
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220611.png
# Processing scatter plot for date: 20220612
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220612.png
# Processing scatter plot for date: 20220613
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220613.png
# Processing scatter plot for date: 20220614
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220614.png
# Processing scatter plot for date: 20220615
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220615.png
# Processing scatter plot for date: 20220616
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220616.png
# Processing scatter plot for date: 20220617
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220617.png
# Processing scatter plot for date: 20220618
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220618.png
# Processing scatter plot for date: 20220619
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220619.png
# Processing scatter plot for date: 20220620
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220620.png
# Processing scatter plot for date: 20220621
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220621.png
# Processing scatter plot for date: 20220622
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220622.png
# Processing scatter plot for date: 20220623
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220623.png
# Processing scatter plot for date: 20220624
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220624.png
# Processing scatter plot for date: 20220625
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220625.png
# Processing scatter plot for date: 20220626
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220626.png
# Processing scatter plot for date: 20220627
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220627.png
# Processing scatter plot for date: 20220628
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220628.png
# Processing scatter plot for date: 20220629
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220629.png
# Processing scatter plot for date: 20220630
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220630.png
# Processing scatter plot for date: 20220701
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220701.png
# Processing scatter plot for date: 20220702
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220702.png
# Processing scatter plot for date: 20220703
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220703.png
# Processing scatter plot for date: 20220704
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220704.png
# Processing scatter plot for date: 20220705
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220705.png
# Processing scatter plot for date: 20220706
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220706.png
# Processing scatter plot for date: 20220707
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220707.png
# Processing scatter plot for date: 20220708
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220708.png
# Processing scatter plot for date: 20220709
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220709.png
# Processing scatter plot for date: 20220710
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220710.png
# Processing scatter plot for date: 20220711
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220711.png
# Processing scatter plot for date: 20220712
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220712.png
# Processing scatter plot for date: 20220713
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20220713.png
# Processing scatter plot for date: 20220714
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221125.png
# Processing scatter plot for date: 20221126
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221126.png
# Processing scatter plot for date: 20221127
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221127.png
# Processing scatter plot for date: 20221128
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221128.png
# Processing scatter plot for date: 20221129
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221129.png
# Processing scatter plot for date: 20221130
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221130.png
# Processing scatter plot for date: 20221201
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221201.png
# Processing scatter plot for date: 20221202
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221202.png
# Processing scatter plot for date: 20221203
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221203.png
# Processing scatter plot for date: 20221204
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221204.png
# Processing scatter plot for date: 20221205
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221205.png
# Processing scatter plot for date: 20221206
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221206.png
# Processing scatter plot for date: 20221207
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221207.png
# Processing scatter plot for date: 20221208
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221208.png
# Processing scatter plot for date: 20221209
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221209.png
# Processing scatter plot for date: 20221210
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221210.png
# Processing scatter plot for date: 20221211
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221211.png
# Processing scatter plot for date: 20221212
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221212.png
# Processing scatter plot for date: 20221213
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221213.png
# Processing scatter plot for date: 20221214
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221214.png
# Processing scatter plot for date: 20221215
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221215.png
# Processing scatter plot for date: 20221216
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221216.png
# Processing scatter plot for date: 20221217
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221217.png
# Processing scatter plot for date: 20221218
# Missing file for date 20221218, skipping...
# Processing scatter plot for date: 20221219
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221219.png
# Processing scatter plot for date: 20221220
# Missing file for date 20221220, skipping...
# Processing scatter plot for date: 20221221
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221221.png
# Processing scatter plot for date: 20221222
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221222.png
# Processing scatter plot for date: 20221223
# Missing file for date 20221223, skipping...
# Processing scatter plot for date: 20221224
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221224.png
# Processing scatter plot for date: 20221225
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221225.png
# Processing scatter plot for date: 20221226
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221226.png
# Processing scatter plot for date: 20221227
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221227.png
# Processing scatter plot for date: 20221228
# Missing file for date 20221228, skipping...
# Processing scatter plot for date: 20221229
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221229.png
# Processing scatter plot for date: 20221230
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221230.png
# Processing scatter plot for date: 20221231
# Saved scatter plot: D:\zmh\icethickness\Copernicus-Global\2_scatter_plots\scatter_comparison_20221231.png

# %% [markdown]
# ## 偏差

# %%
import numpy as np
import xarray as xr
import os
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
import pandas as pd 

plt.rcParams['font.sans-serif'] = ['SimHei']

def calculate_metrics(reference, corrected, original):
    """
    计算均方根误差（RMSE）、偏差（Bias） 和相关系数（CC）
    """
    # 有效数据掩模
    mask = ~np.isnan(reference) & ~np.isnan(corrected) & ~np.isnan(original)
    ref = reference[mask]
    corr = corrected[mask]
    orig = original[mask]
    
    # 计算 RMSE、Bias 和相关系数
    rmse_corrected = np.sqrt(mean_squared_error(ref, corr))
    rmse_original = np.sqrt(mean_squared_error(ref, orig))
    bias_corrected = np.mean(corr - ref)
    bias_original = np.mean(orig - ref)
    cc_corrected, _ = pearsonr(ref, corr)
    cc_original, _ = pearsonr(ref, orig)
    
    return {
        'RMSE (Corrected)': rmse_corrected,
        'RMSE (Original)': rmse_original,
        'Bias (Corrected)': bias_corrected,
        'Bias (Original)': bias_original,
        'CC (Corrected)': cc_corrected,
        'CC (Original)': cc_original
    }

def compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date):
    """
    比较PDF订正后的结果和原始数据与参考数据之间的差异
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)
    results = []
    
    for current_date in date_range:
        date_str = current_date.strftime('%Y%m%d')
        print(f"Processing date: {date_str}")
        
        # 文件路径
        ref_file = os.path.join(reference_dir, f"APPX_north_SIT_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"cmems_pdfcorrected_north_SIT_25000_{date_str}.nc")
        original_file = os.path.join(input_dir, f"cmems_north_SIT_25000_{date_str}.nc")
        
        if not all(map(os.path.exists, [ref_file, corrected_file, original_file])):
            print(f"Skipping {date_str}, missing file.")
            continue
        
        # 读取数据
        ref_data = xr.open_dataset(ref_file)['appx_sit'].values
        corrected_data = xr.open_dataset(corrected_file)['cmems_sit'].values
        original_data = xr.open_dataset(original_file)['cmems_sit'].values
        
        # 计算指标
        metrics = calculate_metrics(ref_data, corrected_data, original_data)
        metrics['Date'] = date_str
        results.append(metrics)
    
    # 保存结果为CSV文件
    results_df = pd.DataFrame(results)
    output_file = os.path.join(output_dir, 'comparison_metrics_north_cmems.csv')
    results_df.to_csv(output_file, index=False)
    print(f"Saved metrics to {output_file}")
    

if __name__ == "__main__":
    # 参数设置

    original_dir = r"D:\zmh\icethickness\Copernicus-Global\0_pre_com\north"
    corrected_dir = r"D:\zmh\icethickness\Copernicus-Global\1_PDFcorrected\north"
    reference_dir = r"D:\zmh\icethickness\APP-X\0_pre_com\north"
    output_dir = r"D:\zmh\icethickness\Copernicus-Global\3_bias"

    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"
    
    compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing date: 20220101
# Skipping 20220101, missing file.
# Processing date: 20220102
# Processing date: 20220103
# Processing date: 20220104
# Processing date: 20220105
# Processing date: 20220106
# Skipping 20220106, missing file.
# Processing date: 20220107
# Skipping 20220107, missing file.
# Processing date: 20220108
# Processing date: 20220109
# Processing date: 20220110
# Processing date: 20220111
# Processing date: 20220112
# Processing date: 20220113
# Processing date: 20220114
# Processing date: 20220115
# Skipping 20220115, missing file.
# Processing date: 20220116
# Processing date: 20220117
# Skipping 20220117, missing file.
# Processing date: 20220118
# Skipping 20220118, missing file.
# Processing date: 20220119
# Processing date: 20220120
# Processing date: 20220121
# Processing date: 20220122
# Processing date: 20220123
# Processing date: 20220124
# Processing date: 20220125
# Processing date: 20220126
# Processing date: 20220127
# Processing date: 20220128
# Processing date: 20220129
# Processing date: 20220130
# Processing date: 20220131
# Skipping 20220131, missing file.
# Processing date: 20220201
# Processing date: 20220202
# Processing date: 20220203
# Processing date: 20220204
# Processing date: 20220205
# Processing date: 20220206
# Processing date: 20220207
# Processing date: 20220208
# Processing date: 20220209
# Processing date: 20220210
# Processing date: 20220211
# Processing date: 20220212
# Processing date: 20220213
# Processing date: 20220214
# Processing date: 20220215
# Processing date: 20220216
# Processing date: 20220217
# Processing date: 20220218
# Processing date: 20220219
# Processing date: 20220220
# Processing date: 20220221
# Processing date: 20220222
# Processing date: 20220223
# Processing date: 20220224
# Processing date: 20220225
# Processing date: 20220226
# Processing date: 20220227
# Processing date: 20220228
# Processing date: 20220301
# Processing date: 20220302
# Processing date: 20220303
# Processing date: 20220304
# Processing date: 20220305
# Processing date: 20220306
# Processing date: 20220307
# Processing date: 20220308
# Processing date: 20220309
# Processing date: 20220310
# Processing date: 20220311
# Processing date: 20220312
# Processing date: 20220313
# Processing date: 20220314
# Processing date: 20220315
# Processing date: 20220316
# Processing date: 20220317
# Processing date: 20220318
# Processing date: 20220319
# Skipping 20220319, missing file.
# Processing date: 20220320
# Processing date: 20220321
# Processing date: 20220322
# Processing date: 20220323
# Processing date: 20220324
# Processing date: 20220325
# Processing date: 20220326
# Processing date: 20220327
# Processing date: 20220328
# Processing date: 20220329
# Processing date: 20220330
# Processing date: 20220331
# Processing date: 20220401
# Processing date: 20220402
# Processing date: 20220403
# Processing date: 20220404
# Processing date: 20220405
# Processing date: 20220406
# Processing date: 20220407
# Processing date: 20220408
# Processing date: 20220409
# Processing date: 20220410
# Processing date: 20220411
# Processing date: 20220412
# Processing date: 20220413
# Processing date: 20220414
# Processing date: 20220415
# Processing date: 20220416
# Processing date: 20220417
# Processing date: 20220418
# Processing date: 20220419
# Processing date: 20220420
# Processing date: 20220421
# Processing date: 20220422
# Processing date: 20220423
# Processing date: 20220424
# Processing date: 20220425
# Processing date: 20220426
# Processing date: 20220427
# Processing date: 20220428
# Processing date: 20220429
# Processing date: 20220430
# Processing date: 20220501
# Processing date: 20220502
# Processing date: 20220503
# Processing date: 20220504
# Processing date: 20220505
# Processing date: 20220506
# Processing date: 20220507
# Processing date: 20220508
# Processing date: 20220509
# Processing date: 20220510
# Processing date: 20220511
# Processing date: 20220512
# Processing date: 20220513
# Processing date: 20220514
# Processing date: 20220515
# Processing date: 20220516
# Processing date: 20220517
# Processing date: 20220518
# Processing date: 20220519
# Processing date: 20220520
# Processing date: 20220521
# Processing date: 20220522
# Processing date: 20220523
# Processing date: 20220524
# Processing date: 20220525
# Processing date: 20220526
# Processing date: 20220527
# Processing date: 20220528
# Processing date: 20220529
# Processing date: 20220530
# Processing date: 20220531
# Processing date: 20220601
# Processing date: 20220602
# Processing date: 20220603
# Processing date: 20220604
# Processing date: 20220605
# Skipping 20220605, missing file.
# Processing date: 20220606
# Processing date: 20220607
# Processing date: 20220608
# Processing date: 20220609
# Processing date: 20220610
# Processing date: 20220611
# Processing date: 20220612
# Processing date: 20220613
# Processing date: 20220614
# Processing date: 20220615
# Processing date: 20220616
# Processing date: 20220617
# Processing date: 20220618
# Processing date: 20220619
# Processing date: 20220620
# Processing date: 20220621
# Processing date: 20220622
# Processing date: 20220623
# Processing date: 20220624
# Processing date: 20220625
# Processing date: 20220626
# Processing date: 20220627
# Processing date: 20220628
# Processing date: 20220629
# Processing date: 20220630
# Processing date: 20220701
# Processing date: 20220702
# Processing date: 20220703
# Processing date: 20220704
# Processing date: 20220705
# Processing date: 20220706
# Processing date: 20220707
# Processing date: 20220708
# Processing date: 20220709
# Processing date: 20220710
# Processing date: 20220711
# Processing date: 20220712
# Processing date: 20220713
# Processing date: 20220714
# Processing date: 20220715
# Processing date: 20220716
# Processing date: 20220717
# Processing date: 20220718
# Processing date: 20220719
# Processing date: 20220720
# Processing date: 20220721
# Processing date: 20220722
# Processing date: 20220723
# Processing date: 20220724
# Processing date: 20220725
# Processing date: 20220726
# Processing date: 20220727
# Processing date: 20220728
# Processing date: 20220729
# Processing date: 20220730
# Processing date: 20220731
# Processing date: 20220801
# Processing date: 20220802
# Processing date: 20220803
# Processing date: 20220804
# Processing date: 20220805
# Processing date: 20220806
# Processing date: 20220807
# Processing date: 20220808
# Processing date: 20220809
# Processing date: 20220810
# Processing date: 20220811
# Processing date: 20220812
# Processing date: 20220813
# Processing date: 20220814
# Processing date: 20220815
# Processing date: 20220816
# Processing date: 20220817
# Processing date: 20220818
# Processing date: 20220819
# Processing date: 20220820
# Processing date: 20220821
# Processing date: 20220822
# Processing date: 20220823
# Skipping 20220823, missing file.
# Processing date: 20220824
# Processing date: 20220825
# Processing date: 20220826
# Processing date: 20220827
# Processing date: 20220828
# Processing date: 20220829
# Processing date: 20220830
# Processing date: 20220831
# Processing date: 20220901
# Processing date: 20220902
# Processing date: 20220903
# Processing date: 20220904
# Processing date: 20220905
# Processing date: 20220906
# Processing date: 20220907
# Processing date: 20220908
# Processing date: 20220909
# Processing date: 20220910
# Processing date: 20220911
# Processing date: 20220912
# Processing date: 20220913
# Processing date: 20220914
# Processing date: 20220915
# Processing date: 20220916
# Processing date: 20220917
# Processing date: 20220918
# Processing date: 20220919
# Processing date: 20220920
# Processing date: 20220921
# Processing date: 20220922
# Processing date: 20220923
# Processing date: 20220924
# Processing date: 20220925
# Processing date: 20220926
# Processing date: 20220927
# Processing date: 20220928
# Processing date: 20220929
# Processing date: 20220930
# Processing date: 20221001
# Processing date: 20221002
# Processing date: 20221003
# Processing date: 20221004
# Processing date: 20221005
# Processing date: 20221006
# Processing date: 20221007
# Processing date: 20221008
# Processing date: 20221009
# Processing date: 20221010
# Processing date: 20221011
# Processing date: 20221012
# Processing date: 20221013
# Processing date: 20221014
# Processing date: 20221015
# Processing date: 20221016
# Processing date: 20221017
# Processing date: 20221018
# Processing date: 20221019
# Processing date: 20221020
# Processing date: 20221021
# Processing date: 20221022
# Processing date: 20221023
# Processing date: 20221024
# Processing date: 20221025
# Processing date: 20221026
# Processing date: 20221027
# Skipping 20221027, missing file.
# Processing date: 20221028
# Processing date: 20221029
# Processing date: 20221030
# Processing date: 20221031
# Processing date: 20221101
# Processing date: 20221102
# Processing date: 20221103
# Processing date: 20221104
# Processing date: 20221105
# Processing date: 20221106
# Processing date: 20221107
# Processing date: 20221108
# Processing date: 20221109
# Processing date: 20221110
# Processing date: 20221111
# Processing date: 20221112
# Processing date: 20221113
# Processing date: 20221114
# Processing date: 20221115
# C:\Users\holo\AppData\Local\Temp\ipykernel_15804\4139987018.py:25: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   cc_corrected, _ = pearsonr(ref, corr)
# C:\Users\holo\AppData\Local\Temp\ipykernel_15804\4139987018.py:26: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   cc_original, _ = pearsonr(ref, orig)
# Processing date: 20221116
# Processing date: 20221117
# Processing date: 20221118
# Processing date: 20221119
# Processing date: 20221120
# Processing date: 20221121
# Processing date: 20221122
# Processing date: 20221123
# Processing date: 20221124
# Processing date: 20221125
# Processing date: 20221126
# Processing date: 20221127
# Processing date: 20221128
# Processing date: 20221129
# Processing date: 20221130
# Processing date: 20221201
# Processing date: 20221202
# Processing date: 20221203
# Processing date: 20221204
# Processing date: 20221205
# Processing date: 20221206
# Processing date: 20221207
# Processing date: 20221208
# Processing date: 20221209
# Processing date: 20221210
# Processing date: 20221211
# Processing date: 20221212
# Processing date: 20221213
# Processing date: 20221214
# Processing date: 20221215
# Processing date: 20221216
# Processing date: 20221217
# Processing date: 20221218
# Skipping 20221218, missing file.
# Processing date: 20221219
# Processing date: 20221220
# Skipping 20221220, missing file.
# Processing date: 20221221
# Processing date: 20221222
# Processing date: 20221223
# Skipping 20221223, missing file.
# Processing date: 20221224
# Processing date: 20221225
# Processing date: 20221226
# Processing date: 20221227
# Processing date: 20221228
# Skipping 20221228, missing file.
# Processing date: 20221229
# Processing date: 20221230
# Processing date: 20221231
# Saved metrics to D:\zmh\icethickness\Copernicus-Global\3_bias\comparison_metrics_north_cmems.csv

# %% [markdown]
# # CS2

# %% [markdown]
# ## 散点图

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

plt.rcParams['font.sans-serif'] = ['SimHei']

def plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date, output_dir):
    """
    绘制订正前、订正后的非参考数据与参考数据的散点图
    :param non_ref_data: 订正前的非参考数据 (2D numpy array)
    :param corrected_data: 订正后的非参考数据 (2D numpy array)
    :param ref_data: 参考数据 (2D numpy array)
    :param date: 当前日期 (str)
    :param output_dir: 输出散点图的保存目录
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 平铺数组，去除 NaN 数据
    mask = (~np.isnan(non_ref_data)) & (~np.isnan(ref_data))
    x_non_ref = non_ref_data[mask]
    x_corrected = corrected_data[mask]
    y_ref = ref_data[mask]
    
    # 绘制订正前的散点图
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_non_ref, y_ref, s=2, alpha=0.5, color='blue')
    plt.plot([0, 3], [0, 3], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 3)
    plt.ylim(0, 3)
   
    plt.xlabel("非参考数据 (订正前)")
    plt.ylabel("参考数据")
    plt.title(f"订正前 ({date})")
    
    # 绘制订正后的散点图
    plt.subplot(1, 2, 2)
    plt.scatter(x_corrected, y_ref, s=2, alpha=0.5, color='red')
    plt.plot([0, 3], [0, 3], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 3)
    plt.ylim(0, 3)
    plt.xlabel("非参考数据 (订正后)")
    plt.ylabel("参考数据")
    plt.title(f"订正后 ({date})")
    
    # 保存散点图
    plt.tight_layout()
    output_file = os.path.join(output_dir, f"scatter_comparison_{date}.png")
    plt.savefig(output_file, dpi=100)
    plt.close()
    print(f"Saved scatter plot: {output_file}")

def generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date):
    """
    生成非参考数据的订正前后与参考数据的散点图
    :param input_dir: 订正前非参考数据目录
    :param corrected_dir: 订正后数据目录
    :param reference_dir: 参考数据目录
    :param output_dir: 输出散点图的保存目录
    :param hemisphere: 'north' 或 'south'
    :param start_date: 开始日期 (str)
    :param end_date: 结束日期 (str)
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        date_str = date.strftime('%Y%m%d')
        print(f"Processing scatter plot for date: {date_str}")

        # 文件路径
        ref_file = os.path.join(reference_dir, f"APPX_{hemisphere}_SIT_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"CS2_pdfcorrected_{hemisphere}_SIT_25000_{date_str}.nc")
        non_ref_file = os.path.join(input_dir, f"CS2_{hemisphere}_SIT_25000_{date_str}.nc")

        # 检查文件是否存在
        if not all(os.path.exists(f) for f in [ref_file, corrected_file, non_ref_file]):
            print(f"Missing file for date {date_str}, skipping...")
            continue

        # 读取数据
        ref_data = xr.open_dataset(ref_file)['appx_sit'].values
        corrected_data = xr.open_dataset(corrected_file)['CS2_sit'].values
        non_ref_data = xr.open_dataset(non_ref_file)['CS2_sit'].values

        # 绘制散点图
        plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date_str, output_dir)

if __name__ == "__main__":
    import pandas as pd

    # 文件目录路径
    input_dir = r"D:\zmh\icethickness\CS2\0_pre_com\north"
    corrected_dir = r"D:\zmh\icethickness\CS2\1_PDFcorrected\north"
    reference_dir = r"D:\zmh\icethickness\APP-X\0_pre_com\north"
    output_dir = r"D:\zmh\icethickness\CS2\2_scatter_plots"
    # 若output_dir不存在，创建output_dir
    os.makedirs(output_dir, exist_ok=True)

    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing scatter plot for date: 20220101
# Missing file for date 20220101, skipping...
# Processing scatter plot for date: 20220102
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220102.png
# Processing scatter plot for date: 20220103
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220103.png
# Processing scatter plot for date: 20220104
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220104.png
# Processing scatter plot for date: 20220105
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220105.png
# Processing scatter plot for date: 20220106
# Missing file for date 20220106, skipping...
# Processing scatter plot for date: 20220107
# Missing file for date 20220107, skipping...
# Processing scatter plot for date: 20220108
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220108.png
# Processing scatter plot for date: 20220109
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220109.png
# Processing scatter plot for date: 20220110
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220110.png
# Processing scatter plot for date: 20220111
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220111.png
# Processing scatter plot for date: 20220112
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220112.png
# Processing scatter plot for date: 20220113
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220113.png
# Processing scatter plot for date: 20220114
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220114.png
# Processing scatter plot for date: 20220115
# Missing file for date 20220115, skipping...
# Processing scatter plot for date: 20220116
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220116.png
# Processing scatter plot for date: 20220117
# Missing file for date 20220117, skipping...
# Processing scatter plot for date: 20220118
# Missing file for date 20220118, skipping...
# Processing scatter plot for date: 20220119
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220119.png
# Processing scatter plot for date: 20220120
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220120.png
# Processing scatter plot for date: 20220121
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220121.png
# Processing scatter plot for date: 20220122
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220122.png
# Processing scatter plot for date: 20220123
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220123.png
# Processing scatter plot for date: 20220124
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220124.png
# Processing scatter plot for date: 20220125
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220125.png
# Processing scatter plot for date: 20220126
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220126.png
# Processing scatter plot for date: 20220127
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220127.png
# Processing scatter plot for date: 20220128
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220128.png
# Processing scatter plot for date: 20220129
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220129.png
# Processing scatter plot for date: 20220130
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220130.png
# Processing scatter plot for date: 20220131
# Missing file for date 20220131, skipping...
# Processing scatter plot for date: 20220201
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220201.png
# Processing scatter plot for date: 20220202
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220202.png
# Processing scatter plot for date: 20220203
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220203.png
# Processing scatter plot for date: 20220204
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220204.png
# Processing scatter plot for date: 20220205
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220205.png
# Processing scatter plot for date: 20220206
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220206.png
# Processing scatter plot for date: 20220207
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220207.png
# Processing scatter plot for date: 20220208
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220208.png
# Processing scatter plot for date: 20220209
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220209.png
# Processing scatter plot for date: 20220210
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220210.png
# Processing scatter plot for date: 20220211
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220211.png
# Processing scatter plot for date: 20220212
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220212.png
# Processing scatter plot for date: 20220213
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220213.png
# Processing scatter plot for date: 20220214
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220214.png
# Processing scatter plot for date: 20220215
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220215.png
# Processing scatter plot for date: 20220216
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220216.png
# Processing scatter plot for date: 20220217
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220217.png
# Processing scatter plot for date: 20220218
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220218.png
# Processing scatter plot for date: 20220219
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220219.png
# Processing scatter plot for date: 20220220
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220220.png
# Processing scatter plot for date: 20220221
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220221.png
# Processing scatter plot for date: 20220222
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220222.png
# Processing scatter plot for date: 20220223
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220223.png
# Processing scatter plot for date: 20220224
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220224.png
# Processing scatter plot for date: 20220225
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220225.png
# Processing scatter plot for date: 20220226
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220226.png
# Processing scatter plot for date: 20220227
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220227.png
# Processing scatter plot for date: 20220228
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220228.png
# Processing scatter plot for date: 20220301
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220301.png
# Processing scatter plot for date: 20220302
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220302.png
# Processing scatter plot for date: 20220303
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220303.png
# Processing scatter plot for date: 20220304
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220304.png
# Processing scatter plot for date: 20220305
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220305.png
# Processing scatter plot for date: 20220306
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220306.png
# Processing scatter plot for date: 20220307
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220307.png
# Processing scatter plot for date: 20220308
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220308.png
# Processing scatter plot for date: 20220309
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220309.png
# Processing scatter plot for date: 20220310
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220310.png
# Processing scatter plot for date: 20220311
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220311.png
# Processing scatter plot for date: 20220312
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220312.png
# Processing scatter plot for date: 20220313
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220313.png
# Processing scatter plot for date: 20220314
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220314.png
# Processing scatter plot for date: 20220315
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220315.png
# Processing scatter plot for date: 20220316
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220316.png
# Processing scatter plot for date: 20220317
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220317.png
# Processing scatter plot for date: 20220318
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220318.png
# Processing scatter plot for date: 20220319
# Missing file for date 20220319, skipping...
# Processing scatter plot for date: 20220320
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220320.png
# Processing scatter plot for date: 20220321
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220321.png
# Processing scatter plot for date: 20220322
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220322.png
# Processing scatter plot for date: 20220323
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220323.png
# Processing scatter plot for date: 20220324
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220324.png
# Processing scatter plot for date: 20220325
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220325.png
# Processing scatter plot for date: 20220326
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220326.png
# Processing scatter plot for date: 20220327
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220327.png
# Processing scatter plot for date: 20220328
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220328.png
# Processing scatter plot for date: 20220329
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220329.png
# Processing scatter plot for date: 20220330
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220330.png
# Processing scatter plot for date: 20220331
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220331.png
# Processing scatter plot for date: 20220401
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220401.png
# Processing scatter plot for date: 20220402
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220402.png
# Processing scatter plot for date: 20220403
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220403.png
# Processing scatter plot for date: 20220404
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220404.png
# Processing scatter plot for date: 20220405
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220405.png
# Processing scatter plot for date: 20220406
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220406.png
# Processing scatter plot for date: 20220407
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220407.png
# Processing scatter plot for date: 20220408
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220408.png
# Processing scatter plot for date: 20220409
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20220409.png
# Processing scatter plot for date: 20220410
# Missing file for date 20220410, skipping...
# Processing scatter plot for date: 20220411
# Missing file for date 20220411, skipping...
# Processing scatter plot for date: 20220412
# Missing file for date 20220412, skipping...
# Processing scatter plot for date: 20220413
# Missing file for date 20220413, skipping...
# Processing scatter plot for date: 20220414
# Missing file for date 20220414, skipping...
# Processing scatter plot for date: 20220415
# Missing file for date 20220415, skipping...
# Processing scatter plot for date: 20220416
# Missing file for date 20220416, skipping...
# Processing scatter plot for date: 20220417
# Missing file for date 20220417, skipping...
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20221224.png
# Processing scatter plot for date: 20221225
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20221225.png
# Processing scatter plot for date: 20221226
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20221226.png
# Processing scatter plot for date: 20221227
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20221227.png
# Processing scatter plot for date: 20221228
# Missing file for date 20221228, skipping...
# Processing scatter plot for date: 20221229
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20221229.png
# Processing scatter plot for date: 20221230
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20221230.png
# Processing scatter plot for date: 20221231
# Saved scatter plot: D:\zmh\icethickness\CS2\2_scatter_plots\scatter_comparison_20221231.png

# %% [markdown]
# ## 偏差

# %%
import numpy as np
import xarray as xr
import os
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
import pandas as pd 

plt.rcParams['font.sans-serif'] = ['SimHei']

def calculate_metrics(reference, corrected, original):
    """
    计算均方根误差（RMSE）、偏差（Bias） 和相关系数（CC）
    """
    # 有效数据掩模
    mask = ~np.isnan(reference) & ~np.isnan(corrected) & ~np.isnan(original)
    ref = reference[mask]
    corr = corrected[mask]
    orig = original[mask]
    
    # 计算 RMSE、Bias 和相关系数
    rmse_corrected = np.sqrt(mean_squared_error(ref, corr))
    rmse_original = np.sqrt(mean_squared_error(ref, orig))
    bias_corrected = np.mean(corr - ref)
    bias_original = np.mean(orig - ref)
    cc_corrected, _ = pearsonr(ref, corr)
    cc_original, _ = pearsonr(ref, orig)
    
    return {
        'RMSE (Corrected)': rmse_corrected,
        'RMSE (Original)': rmse_original,
        'Bias (Corrected)': bias_corrected,
        'Bias (Original)': bias_original,
        'CC (Corrected)': cc_corrected,
        'CC (Original)': cc_original
    }

def compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date):
    """
    比较PDF订正后的结果和原始数据与参考数据之间的差异
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)
    results = []
    
    for current_date in date_range:
        date_str = current_date.strftime('%Y%m%d')
        print(f"Processing date: {date_str}")
        
        # 文件路径
        ref_file = os.path.join(reference_dir, f"APPX_north_SIT_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"CS2_pdfcorrected_north_SIT_25000_{date_str}.nc")
        original_file = os.path.join(input_dir, f"CS2_north_SIT_25000_{date_str}.nc")
        
        if not all(map(os.path.exists, [ref_file, corrected_file, original_file])):
            print(f"Skipping {date_str}, missing file.")
            continue
        
        # 读取数据
        ref_data = xr.open_dataset(ref_file)['appx_sit'].values
        corrected_data = xr.open_dataset(corrected_file)['CS2_sit'].values
        original_data = xr.open_dataset(original_file)['CS2_sit'].values
        
        # 计算指标
        metrics = calculate_metrics(ref_data, corrected_data, original_data)
        metrics['Date'] = date_str
        results.append(metrics)
    
    # 保存结果为CSV文件
    results_df = pd.DataFrame(results)
    output_file = os.path.join(output_dir, 'comparison_metrics_north_CS2.csv')
    results_df.to_csv(output_file, index=False)
    print(f"Saved metrics to {output_file}")
    

if __name__ == "__main__":
    # 参数设置

    original_dir = r"D:\zmh\icethickness\CS2\0_pre_com\north"
    corrected_dir = r"D:\zmh\icethickness\CS2\1_PDFcorrected\north"
    reference_dir = r"D:\zmh\icethickness\APP-X\0_pre_com\north"
    output_dir = r"D:\zmh\icethickness\CS2\3_bias"

    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"
    
    compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing date: 20220101
# Skipping 20220101, missing file.
# Processing date: 20220102
# Processing date: 20220103
# Processing date: 20220104
# Processing date: 20220105
# Processing date: 20220106
# Skipping 20220106, missing file.
# Processing date: 20220107
# Skipping 20220107, missing file.
# Processing date: 20220108
# Processing date: 20220109
# Processing date: 20220110
# Processing date: 20220111
# Processing date: 20220112
# Processing date: 20220113
# Processing date: 20220114
# Processing date: 20220115
# Skipping 20220115, missing file.
# Processing date: 20220116
# Processing date: 20220117
# Skipping 20220117, missing file.
# Processing date: 20220118
# Skipping 20220118, missing file.
# Processing date: 20220119
# Processing date: 20220120
# Processing date: 20220121
# Processing date: 20220122
# Processing date: 20220123
# Processing date: 20220124
# Processing date: 20220125
# Processing date: 20220126
# Processing date: 20220127
# Processing date: 20220128
# Processing date: 20220129
# Processing date: 20220130
# Processing date: 20220131
# Skipping 20220131, missing file.
# Processing date: 20220201
# Processing date: 20220202
# Processing date: 20220203
# Processing date: 20220204
# Processing date: 20220205
# Processing date: 20220206
# Processing date: 20220207
# Processing date: 20220208
# Processing date: 20220209
# Processing date: 20220210
# Processing date: 20220211
# Processing date: 20220212
# Processing date: 20220213
# Processing date: 20220214
# Processing date: 20220215
# Processing date: 20220216
# Processing date: 20220217
# Processing date: 20220218
# Processing date: 20220219
# Processing date: 20220220
# Processing date: 20220221
# Processing date: 20220222
# Processing date: 20220223
# Processing date: 20220224
# Processing date: 20220225
# Processing date: 20220226
# Processing date: 20220227
# Processing date: 20220228
# Processing date: 20220301
# Processing date: 20220302
# Processing date: 20220303
# Processing date: 20220304
# Processing date: 20220305
# Processing date: 20220306
# Processing date: 20220307
# Processing date: 20220308
# Processing date: 20220309
# Processing date: 20220310
# Processing date: 20220311
# Processing date: 20220312
# Processing date: 20220313
# Processing date: 20220314
# Processing date: 20220315
# Processing date: 20220316
# Processing date: 20220317
# Processing date: 20220318
# Processing date: 20220319
# Skipping 20220319, missing file.
# Processing date: 20220320
# Processing date: 20220321
# Processing date: 20220322
# Processing date: 20220323
# Processing date: 20220324
# Processing date: 20220325
# Processing date: 20220326
# Processing date: 20220327
# Processing date: 20220328
# Processing date: 20220329
# Processing date: 20220330
# Processing date: 20220331
# Processing date: 20220401
# Processing date: 20220402
# Processing date: 20220403
# Processing date: 20220404
# Processing date: 20220405
# Processing date: 20220406
# Processing date: 20220407
# Processing date: 20220408
# Processing date: 20220409
# Processing date: 20220410
# Skipping 20220410, missing file.
# Processing date: 20220411
# Skipping 20220411, missing file.
# Processing date: 20220412
# Skipping 20220412, missing file.
# Processing date: 20220413
# Skipping 20220413, missing file.
# Processing date: 20220414
# Skipping 20220414, missing file.
# Processing date: 20220415
# Skipping 20220415, missing file.
# Processing date: 20220416
# Skipping 20220416, missing file.
# Processing date: 20220417
# Skipping 20220417, missing file.
# Processing date: 20220418
# Skipping 20220418, missing file.
# Processing date: 20220419
# Skipping 20220419, missing file.
# Processing date: 20220420
# Skipping 20220420, missing file.
# Processing date: 20220421
# Skipping 20220421, missing file.
# Processing date: 20220422
# Skipping 20220422, missing file.
# Processing date: 20220423
# Skipping 20220423, missing file.
# Processing date: 20220424
# Skipping 20220424, missing file.
# Processing date: 20220425
# Skipping 20220425, missing file.
# Processing date: 20220426
# Skipping 20220426, missing file.
# Processing date: 20220427
# Skipping 20220427, missing file.
# Processing date: 20220428
# Skipping 20220428, missing file.
# Processing date: 20220429
# Skipping 20220429, missing file.
# Processing date: 20220430
# Skipping 20220430, missing file.
# Processing date: 20220501
# Skipping 20220501, missing file.
# Processing date: 20220502
# Skipping 20220502, missing file.
# Processing date: 20220503
# Skipping 20220503, missing file.
# Processing date: 20220504
# Skipping 20220504, missing file.
# Processing date: 20220505
# Skipping 20220505, missing file.
# Processing date: 20220506
# Skipping 20220506, missing file.
# Processing date: 20220507
# Skipping 20220507, missing file.
# Processing date: 20220508
# Skipping 20220508, missing file.
# Processing date: 20220509
# Skipping 20220509, missing file.
# Processing date: 20220510
# Skipping 20220510, missing file.
# Processing date: 20220511
# Skipping 20220511, missing file.
# Processing date: 20220512
# Skipping 20220512, missing file.
# Processing date: 20220513
# Skipping 20220513, missing file.
# Processing date: 20220514
# Skipping 20220514, missing file.
# Processing date: 20220515
# Skipping 20220515, missing file.
# Processing date: 20220516
# Skipping 20220516, missing file.
# Processing date: 20220517
# Skipping 20220517, missing file.
# Processing date: 20220518
# Skipping 20220518, missing file.
# Processing date: 20220519
# Skipping 20220519, missing file.
# Processing date: 20220520
# Skipping 20220520, missing file.
# Processing date: 20220521
# Skipping 20220521, missing file.
# Processing date: 20220522
# Skipping 20220522, missing file.
# Processing date: 20220523
# Skipping 20220523, missing file.
# Processing date: 20220524
# Skipping 20220524, missing file.
# Processing date: 20220525
# Skipping 20220525, missing file.
# Processing date: 20220526
# Skipping 20220526, missing file.
# Processing date: 20220527
# Skipping 20220527, missing file.
# Processing date: 20220528
# Skipping 20220528, missing file.
# Processing date: 20220529
# Skipping 20220529, missing file.
# Processing date: 20220530
# Skipping 20220530, missing file.
# Processing date: 20220531
# Skipping 20220531, missing file.
# Processing date: 20220601
# Skipping 20220601, missing file.
# Processing date: 20220602
# Skipping 20220602, missing file.
# Processing date: 20220603
# Skipping 20220603, missing file.
# Processing date: 20220604
# Skipping 20220604, missing file.
# Processing date: 20220605
# Skipping 20220605, missing file.
# Processing date: 20220606
# Skipping 20220606, missing file.
# Processing date: 20220607
# Skipping 20220607, missing file.
# Processing date: 20220608
# Skipping 20220608, missing file.
# Processing date: 20220609
# Skipping 20220609, missing file.
# Processing date: 20220610
# Skipping 20220610, missing file.
# Processing date: 20220611
# Skipping 20220611, missing file.
# Processing date: 20220612
# Skipping 20220612, missing file.
# Processing date: 20220613
# Skipping 20220613, missing file.
# Processing date: 20220614
# Skipping 20220614, missing file.
# Processing date: 20220615
# Skipping 20220615, missing file.
# Processing date: 20220616
# Skipping 20220616, missing file.
# Processing date: 20220617
# Skipping 20220617, missing file.
# Processing date: 20220618
# Skipping 20220618, missing file.
# Processing date: 20220619
# Skipping 20220619, missing file.
# Processing date: 20220620
# Skipping 20220620, missing file.
# Processing date: 20220621
# Skipping 20220621, missing file.
# Processing date: 20220622
# Skipping 20220622, missing file.
# Processing date: 20220623
# Skipping 20220623, missing file.
# Processing date: 20220624
# Skipping 20220624, missing file.
# Processing date: 20220625
# Skipping 20220625, missing file.
# Processing date: 20220626
# Skipping 20220626, missing file.
# Processing date: 20220627
# Skipping 20220627, missing file.
# Processing date: 20220628
# Skipping 20220628, missing file.
# Processing date: 20220629
# Skipping 20220629, missing file.
# Processing date: 20220630
# Skipping 20220630, missing file.
# Processing date: 20220701
# Skipping 20220701, missing file.
# Processing date: 20220702
# Skipping 20220702, missing file.
# Processing date: 20220703
# Skipping 20220703, missing file.
# Processing date: 20220704
# Skipping 20220704, missing file.
# Processing date: 20220705
# Skipping 20220705, missing file.
# Processing date: 20220706
# Skipping 20220706, missing file.
# Processing date: 20220707
# Skipping 20220707, missing file.
# Processing date: 20220708
# Skipping 20220708, missing file.
# Processing date: 20220709
# Skipping 20220709, missing file.
# Processing date: 20220710
# Skipping 20220710, missing file.
# Processing date: 20220711
# Skipping 20220711, missing file.
# Processing date: 20220712
# Skipping 20220712, missing file.
# Processing date: 20220713
# Skipping 20220713, missing file.
# Processing date: 20220714
# Skipping 20220714, missing file.
# Processing date: 20220715
# Skipping 20220715, missing file.
# Processing date: 20220716
# Skipping 20220716, missing file.
# Processing date: 20220717
# Skipping 20220717, missing file.
# Processing date: 20220718
# Skipping 20220718, missing file.
# Processing date: 20220719
# Skipping 20220719, missing file.
# Processing date: 20220720
# Skipping 20220720, missing file.
# Processing date: 20220721
# Skipping 20220721, missing file.
# Processing date: 20220722
# Skipping 20220722, missing file.
# Processing date: 20220723
# Skipping 20220723, missing file.
# Processing date: 20220724
# Skipping 20220724, missing file.
# Processing date: 20220725
# Skipping 20220725, missing file.
# Processing date: 20220726
# Skipping 20220726, missing file.
# Processing date: 20220727
# Skipping 20220727, missing file.
# Processing date: 20220728
# Skipping 20220728, missing file.
# Processing date: 20220729
# Skipping 20220729, missing file.
# Processing date: 20220730
# Skipping 20220730, missing file.
# Processing date: 20220731
# Skipping 20220731, missing file.
# Processing date: 20220801
# Skipping 20220801, missing file.
# Processing date: 20220802
# Skipping 20220802, missing file.
# Processing date: 20220803
# Skipping 20220803, missing file.
# Processing date: 20220804
# Skipping 20220804, missing file.
# Processing date: 20220805
# Skipping 20220805, missing file.
# Processing date: 20220806
# Skipping 20220806, missing file.
# Processing date: 20220807
# Skipping 20220807, missing file.
# Processing date: 20220808
# Skipping 20220808, missing file.
# Processing date: 20220809
# Skipping 20220809, missing file.
# Processing date: 20220810
# Skipping 20220810, missing file.
# Processing date: 20220811
# Skipping 20220811, missing file.
# Processing date: 20220812
# Skipping 20220812, missing file.
# Processing date: 20220813
# Skipping 20220813, missing file.
# Processing date: 20220814
# Skipping 20220814, missing file.
# Processing date: 20220815
# Skipping 20220815, missing file.
# Processing date: 20220816
# Skipping 20220816, missing file.
# Processing date: 20220817
# Skipping 20220817, missing file.
# Processing date: 20220818
# Skipping 20220818, missing file.
# Processing date: 20220819
# Skipping 20220819, missing file.
# Processing date: 20220820
# Skipping 20220820, missing file.
# Processing date: 20220821
# Skipping 20220821, missing file.
# Processing date: 20220822
# Skipping 20220822, missing file.
# Processing date: 20220823
# Skipping 20220823, missing file.
# Processing date: 20220824
# Skipping 20220824, missing file.
# Processing date: 20220825
# Skipping 20220825, missing file.
# Processing date: 20220826
# Skipping 20220826, missing file.
# Processing date: 20220827
# Skipping 20220827, missing file.
# Processing date: 20220828
# Skipping 20220828, missing file.
# Processing date: 20220829
# Skipping 20220829, missing file.
# Processing date: 20220830
# Skipping 20220830, missing file.
# Processing date: 20220831
# Skipping 20220831, missing file.
# Processing date: 20220901
# Skipping 20220901, missing file.
# Processing date: 20220902
# Skipping 20220902, missing file.
# Processing date: 20220903
# Skipping 20220903, missing file.
# Processing date: 20220904
# Skipping 20220904, missing file.
# Processing date: 20220905
# Skipping 20220905, missing file.
# Processing date: 20220906
# Skipping 20220906, missing file.
# Processing date: 20220907
# Skipping 20220907, missing file.
# Processing date: 20220908
# Skipping 20220908, missing file.
# Processing date: 20220909
# Skipping 20220909, missing file.
# Processing date: 20220910
# Skipping 20220910, missing file.
# Processing date: 20220911
# Skipping 20220911, missing file.
# Processing date: 20220912
# Skipping 20220912, missing file.
# Processing date: 20220913
# Skipping 20220913, missing file.
# Processing date: 20220914
# Skipping 20220914, missing file.
# Processing date: 20220915
# Skipping 20220915, missing file.
# Processing date: 20220916
# Skipping 20220916, missing file.
# Processing date: 20220917
# Skipping 20220917, missing file.
# Processing date: 20220918
# Skipping 20220918, missing file.
# Processing date: 20220919
# Skipping 20220919, missing file.
# Processing date: 20220920
# Skipping 20220920, missing file.
# Processing date: 20220921
# Skipping 20220921, missing file.
# Processing date: 20220922
# Skipping 20220922, missing file.
# Processing date: 20220923
# Skipping 20220923, missing file.
# Processing date: 20220924
# Skipping 20220924, missing file.
# Processing date: 20220925
# Skipping 20220925, missing file.
# Processing date: 20220926
# Skipping 20220926, missing file.
# Processing date: 20220927
# Skipping 20220927, missing file.
# Processing date: 20220928
# Skipping 20220928, missing file.
# Processing date: 20220929
# Skipping 20220929, missing file.
# Processing date: 20220930
# Skipping 20220930, missing file.
# Processing date: 20221001
# Skipping 20221001, missing file.
# Processing date: 20221002
# Skipping 20221002, missing file.
# Processing date: 20221003
# Skipping 20221003, missing file.
# Processing date: 20221004
# Skipping 20221004, missing file.
# Processing date: 20221005
# Skipping 20221005, missing file.
# Processing date: 20221006
# Skipping 20221006, missing file.
# Processing date: 20221007
# Skipping 20221007, missing file.
# Processing date: 20221008
# Skipping 20221008, missing file.
# Processing date: 20221009
# Skipping 20221009, missing file.
# Processing date: 20221010
# Skipping 20221010, missing file.
# Processing date: 20221011
# Skipping 20221011, missing file.
# Processing date: 20221012
# Skipping 20221012, missing file.
# Processing date: 20221013
# Skipping 20221013, missing file.
# Processing date: 20221014
# Skipping 20221014, missing file.
# Processing date: 20221015
# Processing date: 20221016
# Processing date: 20221017
# Processing date: 20221018
# Processing date: 20221019
# Processing date: 20221020
# Processing date: 20221021
# Processing date: 20221022
# Processing date: 20221023
# Processing date: 20221024
# Processing date: 20221025
# Processing date: 20221026
# Processing date: 20221027
# Skipping 20221027, missing file.
# Processing date: 20221028
# Processing date: 20221029
# Processing date: 20221030
# Processing date: 20221031
# Processing date: 20221101
# Processing date: 20221102
# Processing date: 20221103
# Processing date: 20221104
# Processing date: 20221105
# Processing date: 20221106
# Processing date: 20221107
# Processing date: 20221108
# Processing date: 20221109
# Processing date: 20221110
# Processing date: 20221111
# Processing date: 20221112
# Processing date: 20221113
# Processing date: 20221114
# Processing date: 20221115
# Processing date: 20221116
# Processing date: 20221117
# Processing date: 20221118
# Processing date: 20221119
# Processing date: 20221120
# Processing date: 20221121
# Processing date: 20221122
# Processing date: 20221123
# Processing date: 20221124
# C:\Users\holo\AppData\Local\Temp\ipykernel_15804\1954144531.py:25: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   cc_corrected, _ = pearsonr(ref, corr)
# C:\Users\holo\AppData\Local\Temp\ipykernel_15804\1954144531.py:26: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   cc_original, _ = pearsonr(ref, orig)
# Processing date: 20221125
# Processing date: 20221126
# Processing date: 20221127
# Processing date: 20221128
# Processing date: 20221129
# Processing date: 20221130
# Processing date: 20221201
# Processing date: 20221202
# Processing date: 20221203
# Processing date: 20221204
# Processing date: 20221205
# Processing date: 20221206
# Processing date: 20221207
# Processing date: 20221208
# Processing date: 20221209
# Processing date: 20221210
# Processing date: 20221211
# Processing date: 20221212
# Processing date: 20221213
# Processing date: 20221214
# Processing date: 20221215
# Processing date: 20221216
# Processing date: 20221217
# Processing date: 20221218
# Skipping 20221218, missing file.
# Processing date: 20221219
# Processing date: 20221220
# Skipping 20221220, missing file.
# Processing date: 20221221
# Processing date: 20221222
# Processing date: 20221223
# Skipping 20221223, missing file.
# Processing date: 20221224
# Processing date: 20221225
# Processing date: 20221226
# Processing date: 20221227
# Processing date: 20221228
# Skipping 20221228, missing file.
# Processing date: 20221229
# Processing date: 20221230
# Processing date: 20221231
# Saved metrics to D:\zmh\icethickness\CS2\3_bias\comparison_metrics_north_CS2.csv

# %% [markdown]
# # rdeft4

# %% [markdown]
# ## 散点图

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

plt.rcParams['font.sans-serif'] = ['SimHei']

def plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date, output_dir):
    """
    绘制订正前、订正后的非参考数据与参考数据的散点图
    :param non_ref_data: 订正前的非参考数据 (2D numpy array)
    :param corrected_data: 订正后的非参考数据 (2D numpy array)
    :param ref_data: 参考数据 (2D numpy array)
    :param date: 当前日期 (str)
    :param output_dir: 输出散点图的保存目录
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 平铺数组，去除 NaN 数据
    mask = (~np.isnan(non_ref_data)) & (~np.isnan(ref_data))
    x_non_ref = non_ref_data[mask]
    x_corrected = corrected_data[mask]
    y_ref = ref_data[mask]
    
    # 绘制订正前的散点图
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_non_ref, y_ref, s=2, alpha=0.5, color='blue')
    plt.plot([0, 3], [0, 3], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 3)
    plt.ylim(0, 3)
   
    plt.xlabel("非参考数据 (订正前)")
    plt.ylabel("参考数据")
    plt.title(f"订正前 ({date})")
    
    # 绘制订正后的散点图
    plt.subplot(1, 2, 2)
    plt.scatter(x_corrected, y_ref, s=2, alpha=0.5, color='red')
    plt.plot([0, 3], [0, 3], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 3)
    plt.ylim(0, 3)
    plt.xlabel("非参考数据 (订正后)")
    plt.ylabel("参考数据")
    plt.title(f"订正后 ({date})")
    
    # 保存散点图
    plt.tight_layout()
    output_file = os.path.join(output_dir, f"scatter_comparison_{date}.png")
    plt.savefig(output_file, dpi=100)
    plt.close()
    print(f"Saved scatter plot: {output_file}")

def generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date):
    """
    生成非参考数据的订正前后与参考数据的散点图
    :param input_dir: 订正前非参考数据目录
    :param corrected_dir: 订正后数据目录
    :param reference_dir: 参考数据目录
    :param output_dir: 输出散点图的保存目录
    :param hemisphere: 'north' 或 'south'
    :param start_date: 开始日期 (str)
    :param end_date: 结束日期 (str)
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        date_str = date.strftime('%Y%m%d')
        print(f"Processing scatter plot for date: {date_str}")

        # 文件路径
        ref_file = os.path.join(reference_dir, f"APPX_{hemisphere}_SIT_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"rdeft4_pdfcorrected_{hemisphere}_SIT_25000_{date_str}.nc")
        non_ref_file = os.path.join(input_dir, f"rdeft4_{hemisphere}_SIT_25000_{date_str}.nc")

        # 检查文件是否存在
        if not all(os.path.exists(f) for f in [ref_file, corrected_file, non_ref_file]):
            print(f"Missing file for date {date_str}, skipping...")
            continue

        # 读取数据
        ref_data = xr.open_dataset(ref_file)['appx_sit'].values
        corrected_data = xr.open_dataset(corrected_file)['rdeft4_sit'].values
        non_ref_data = xr.open_dataset(non_ref_file)['rdeft4_sit'].values

        # 绘制散点图
        plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date_str, output_dir)

if __name__ == "__main__":
    import pandas as pd

    # 文件目录路径
    input_dir = r"D:\zmh\icethickness\NSIDC-R\0_pre_com\north"
    corrected_dir = r"D:\zmh\icethickness\NSIDC-R\1_PDFcorrected\north"
    reference_dir = r"D:\zmh\icethickness\APP-X\0_pre_com\north"
    output_dir = r"D:\zmh\icethickness\NSIDC-R\2_scatter_plots"
    os.makedirs(output_dir, exist_ok=True)

    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing scatter plot for date: 20220101
# Missing file for date 20220101, skipping...
# Processing scatter plot for date: 20220102
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220102.png
# Processing scatter plot for date: 20220103
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220103.png
# Processing scatter plot for date: 20220104
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220104.png
# Processing scatter plot for date: 20220105
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220105.png
# Processing scatter plot for date: 20220106
# Missing file for date 20220106, skipping...
# Processing scatter plot for date: 20220107
# Missing file for date 20220107, skipping...
# Processing scatter plot for date: 20220108
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220108.png
# Processing scatter plot for date: 20220109
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220109.png
# Processing scatter plot for date: 20220110
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220110.png
# Processing scatter plot for date: 20220111
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220111.png
# Processing scatter plot for date: 20220112
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220112.png
# Processing scatter plot for date: 20220113
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220113.png
# Processing scatter plot for date: 20220114
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220114.png
# Processing scatter plot for date: 20220115
# Missing file for date 20220115, skipping...
# Processing scatter plot for date: 20220116
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220116.png
# Processing scatter plot for date: 20220117
# Missing file for date 20220117, skipping...
# Processing scatter plot for date: 20220118
# Missing file for date 20220118, skipping...
# Processing scatter plot for date: 20220119
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220119.png
# Processing scatter plot for date: 20220120
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220120.png
# Processing scatter plot for date: 20220121
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220121.png
# Processing scatter plot for date: 20220122
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220329.png
# Processing scatter plot for date: 20220330
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220330.png
# Processing scatter plot for date: 20220331
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220331.png
# Processing scatter plot for date: 20220401
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220401.png
# Processing scatter plot for date: 20220402
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220402.png
# Processing scatter plot for date: 20220403
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220403.png
# Processing scatter plot for date: 20220404
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220404.png
# Processing scatter plot for date: 20220405
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220405.png
# Processing scatter plot for date: 20220406
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220406.png
# Processing scatter plot for date: 20220407
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220407.png
# Processing scatter plot for date: 20220408
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220408.png
# Processing scatter plot for date: 20220409
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220409.png
# Processing scatter plot for date: 20220410
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220410.png
# Processing scatter plot for date: 20220411
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220411.png
# Processing scatter plot for date: 20220412
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220412.png
# Processing scatter plot for date: 20220413
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220413.png
# Processing scatter plot for date: 20220414
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220414.png
# Processing scatter plot for date: 20220415
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220415.png
# Processing scatter plot for date: 20220416
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220416.png
# Processing scatter plot for date: 20220417
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220417.png
# Processing scatter plot for date: 20220418
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220418.png
# Processing scatter plot for date: 20220419
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220419.png
# Processing scatter plot for date: 20220420
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220420.png
# Processing scatter plot for date: 20220421
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220421.png
# Processing scatter plot for date: 20220422
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220422.png
# Processing scatter plot for date: 20220423
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220423.png
# Processing scatter plot for date: 20220424
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220424.png
# Processing scatter plot for date: 20220425
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220425.png
# Processing scatter plot for date: 20220426
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220426.png
# Processing scatter plot for date: 20220427
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220427.png
# Processing scatter plot for date: 20220428
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220428.png
# Processing scatter plot for date: 20220429
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220429.png
# Processing scatter plot for date: 20220430
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220430.png
# Processing scatter plot for date: 20220501
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220501.png
# Processing scatter plot for date: 20220502
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220502.png
# Processing scatter plot for date: 20220503
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220503.png
# Processing scatter plot for date: 20220504
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220504.png
# Processing scatter plot for date: 20220505
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220505.png
# Processing scatter plot for date: 20220506
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220506.png
# Processing scatter plot for date: 20220507
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220507.png
# Processing scatter plot for date: 20220508
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220508.png
# Processing scatter plot for date: 20220509
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220509.png
# Processing scatter plot for date: 20220510
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220510.png
# Processing scatter plot for date: 20220511
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220511.png
# Processing scatter plot for date: 20220512
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220512.png
# Processing scatter plot for date: 20220513
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220513.png
# Processing scatter plot for date: 20220514
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220514.png
# Processing scatter plot for date: 20220515
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20220515.png
# Processing scatter plot for date: 20220516
# Missing file for date 20220516, skipping...
# Processing scatter plot for date: 20220517
# Missing file for date 20220517, skipping...
# Processing scatter plot for date: 20220518
# Missing file for date 20220518, skipping...
# Processing scatter plot for date: 20220519
# Missing file for date 20220519, skipping...
# Processing scatter plot for date: 20220520
# Missing file for date 20220520, skipping...
# Processing scatter plot for date: 20220521
# Missing file for date 20220521, skipping...
# Processing scatter plot for date: 20220522
# Missing file for date 20220522, skipping...
# Processing scatter plot for date: 20220523
# Missing file for date 20220523, skipping...
# Processing scatter plot for date: 20220524
# Missing file for date 20220524, skipping...
# Processing scatter plot for date: 20220525
# Missing file for date 20220525, skipping...
# Processing scatter plot for date: 20220526
# Missing file for date 20220526, skipping...
# Processing scatter plot for date: 20220527
# Missing file for date 20220527, skipping...
# Processing scatter plot for date: 20220528
# Missing file for date 20220528, skipping...
# Processing scatter plot for date: 20220529
# Missing file for date 20220529, skipping...
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20221227.png
# Processing scatter plot for date: 20221228
# Missing file for date 20221228, skipping...
# Processing scatter plot for date: 20221229
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20221229.png
# Processing scatter plot for date: 20221230
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20221230.png
# Processing scatter plot for date: 20221231
# Saved scatter plot: D:\zmh\icethickness\NSIDC-R\2_scatter_plots\scatter_comparison_20221231.png

# %% [markdown]
# ## 偏差

# %%
import numpy as np
import xarray as xr
import os
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
import pandas as pd 

plt.rcParams['font.sans-serif'] = ['SimHei']

def calculate_metrics(reference, corrected, original):
    """
    计算均方根误差（RMSE）、偏差（Bias） 和相关系数（CC）
    """
    # 有效数据掩模
    mask = ~np.isnan(reference) & ~np.isnan(corrected) & ~np.isnan(original)
    ref = reference[mask]
    corr = corrected[mask]
    orig = original[mask]
    
    # 计算 RMSE、Bias 和相关系数
    rmse_corrected = np.sqrt(mean_squared_error(ref, corr))
    rmse_original = np.sqrt(mean_squared_error(ref, orig))
    bias_corrected = np.mean(corr - ref)
    bias_original = np.mean(orig - ref)
    cc_corrected, _ = pearsonr(ref, corr)
    cc_original, _ = pearsonr(ref, orig)
    
    return {
        'RMSE (Corrected)': rmse_corrected,
        'RMSE (Original)': rmse_original,
        'Bias (Corrected)': bias_corrected,
        'Bias (Original)': bias_original,
        'CC (Corrected)': cc_corrected,
        'CC (Original)': cc_original
    }

def compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date):
    """
    比较PDF订正后的结果和原始数据与参考数据之间的差异
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)
    results = []
    
    for current_date in date_range:
        date_str = current_date.strftime('%Y%m%d')
        print(f"Processing date: {date_str}")
        
        # 文件路径
        ref_file = os.path.join(reference_dir, f"APPX_north_SIT_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"rdeft4_pdfcorrected_north_SIT_25000_{date_str}.nc")
        original_file = os.path.join(input_dir, f"rdeft4_north_SIT_25000_{date_str}.nc")
        
        if not all(map(os.path.exists, [ref_file, corrected_file, original_file])):
            print(f"Skipping {date_str}, missing file.")
            continue
        
        # 读取数据
        ref_data = xr.open_dataset(ref_file)['appx_sit'].values
        corrected_data = xr.open_dataset(corrected_file)['rdeft4_sit'].values
        original_data = xr.open_dataset(original_file)['rdeft4_sit'].values
        
        # 计算指标
        metrics = calculate_metrics(ref_data, corrected_data, original_data)
        metrics['Date'] = date_str
        results.append(metrics)
    
    # 保存结果为CSV文件
    results_df = pd.DataFrame(results)
    output_file = os.path.join(output_dir, 'comparison_metrics_north_rdeft4.csv')
    results_df.to_csv(output_file, index=False)
    print(f"Saved metrics to {output_file}")
    

if __name__ == "__main__":
    # 参数设置

    original_dir = r"D:\zmh\icethickness\NSIDC-R\0_pre_com\north"
    corrected_dir = r"D:\zmh\icethickness\NSIDC-R\1_PDFcorrected\north"
    reference_dir = r"D:\zmh\icethickness\APP-X\0_pre_com\north"
    output_dir = r"D:\zmh\icethickness\NSIDC-R\3_bias"

    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"
    
    compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing date: 20220101
# Skipping 20220101, missing file.
# Processing date: 20220102
# Processing date: 20220103
# Processing date: 20220104
# Processing date: 20220105
# Processing date: 20220106
# Skipping 20220106, missing file.
# Processing date: 20220107
# Skipping 20220107, missing file.
# Processing date: 20220108
# Processing date: 20220109
# Processing date: 20220110
# Processing date: 20220111
# Processing date: 20220112
# Processing date: 20220113
# Processing date: 20220114
# Processing date: 20220115
# Skipping 20220115, missing file.
# Processing date: 20220116
# Processing date: 20220117
# Skipping 20220117, missing file.
# Processing date: 20220118
# Skipping 20220118, missing file.
# Processing date: 20220119
# Processing date: 20220120
# Processing date: 20220121
# Processing date: 20220122
# Processing date: 20220123
# Processing date: 20220124
# Processing date: 20220125
# Processing date: 20220126
# Processing date: 20220127
# Processing date: 20220128
# Processing date: 20220129
# Processing date: 20220130
# Processing date: 20220131
# Skipping 20220131, missing file.
# Processing date: 20220201
# Processing date: 20220202
# Processing date: 20220203
# Processing date: 20220204
# Processing date: 20220205
# Processing date: 20220206
# Processing date: 20220207
# Processing date: 20220208
# Processing date: 20220209
# Processing date: 20220210
# Processing date: 20220211
# Processing date: 20220212
# Processing date: 20220213
# Processing date: 20220214
# Processing date: 20220215
# Processing date: 20220216
# Processing date: 20220217
# Processing date: 20220218
# Processing date: 20220219
# Processing date: 20220220
# Processing date: 20220221
# Processing date: 20220222
# Processing date: 20220223
# Processing date: 20220224
# Processing date: 20220225
# Processing date: 20220226
# Processing date: 20220227
# Processing date: 20220228
# Processing date: 20220301
# Processing date: 20220302
# Processing date: 20220303
# Processing date: 20220304
# Processing date: 20220305
# Processing date: 20220306
# Processing date: 20220307
# Processing date: 20220308
# Processing date: 20220309
# Processing date: 20220310
# Processing date: 20220311
# Processing date: 20220312
# Processing date: 20220313
# Processing date: 20220314
# Processing date: 20220315
# Processing date: 20220316
# Processing date: 20220317
# Processing date: 20220318
# Processing date: 20220319
# Skipping 20220319, missing file.
# Processing date: 20220320
# Processing date: 20220321
# Processing date: 20220322
# Processing date: 20220323
# Processing date: 20220324
# Processing date: 20220325
# Processing date: 20220326
# Processing date: 20220327
# Processing date: 20220328
# Processing date: 20220329
# Processing date: 20220330
# Processing date: 20220331
# Processing date: 20220401
# Processing date: 20220402
# Processing date: 20220403
# Processing date: 20220404
# Processing date: 20220405
# Processing date: 20220406
# Processing date: 20220407
# Processing date: 20220408
# Processing date: 20220409
# Processing date: 20220410
# Processing date: 20220411
# Processing date: 20220412
# Processing date: 20220413
# Processing date: 20220414
# Processing date: 20220415
# Processing date: 20220416
# Processing date: 20220417
# Processing date: 20220418
# Processing date: 20220419
# Processing date: 20220420
# Processing date: 20220421
# Processing date: 20220422
# Processing date: 20220423
# Processing date: 20220424
# Processing date: 20220425
# Processing date: 20220426
# Processing date: 20220427
# Processing date: 20220428
# Processing date: 20220429
# Processing date: 20220430
# Processing date: 20220501
# Processing date: 20220502
# Processing date: 20220503
# Processing date: 20220504
# Processing date: 20220505
# Processing date: 20220506
# Processing date: 20220507
# Processing date: 20220508
# Processing date: 20220509
# Processing date: 20220510
# Processing date: 20220511
# Processing date: 20220512
# Processing date: 20220513
# Processing date: 20220514
# Processing date: 20220515
# Processing date: 20220516
# Skipping 20220516, missing file.
# Processing date: 20220517
# Skipping 20220517, missing file.
# Processing date: 20220518
# Skipping 20220518, missing file.
# Processing date: 20220519
# Skipping 20220519, missing file.
# Processing date: 20220520
# Skipping 20220520, missing file.
# Processing date: 20220521
# Skipping 20220521, missing file.
# Processing date: 20220522
# Skipping 20220522, missing file.
# Processing date: 20220523
# Skipping 20220523, missing file.
# Processing date: 20220524
# Skipping 20220524, missing file.
# Processing date: 20220525
# Skipping 20220525, missing file.
# Processing date: 20220526
# Skipping 20220526, missing file.
# Processing date: 20220527
# Skipping 20220527, missing file.
# Processing date: 20220528
# Skipping 20220528, missing file.
# Processing date: 20220529
# Skipping 20220529, missing file.
# Processing date: 20220530
# Skipping 20220530, missing file.
# Processing date: 20220531
# Skipping 20220531, missing file.
# Processing date: 20220601
# Skipping 20220601, missing file.
# Processing date: 20220602
# Skipping 20220602, missing file.
# Processing date: 20220603
# Skipping 20220603, missing file.
# Processing date: 20220604
# Skipping 20220604, missing file.
# Processing date: 20220605
# Skipping 20220605, missing file.
# Processing date: 20220606
# Skipping 20220606, missing file.
# Processing date: 20220607
# Skipping 20220607, missing file.
# Processing date: 20220608
# Skipping 20220608, missing file.
# Processing date: 20220609
# Skipping 20220609, missing file.
# Processing date: 20220610
# Skipping 20220610, missing file.
# Processing date: 20220611
# Skipping 20220611, missing file.
# Processing date: 20220612
# Skipping 20220612, missing file.
# Processing date: 20220613
# Skipping 20220613, missing file.
# Processing date: 20220614
# Skipping 20220614, missing file.
# Processing date: 20220615
# Skipping 20220615, missing file.
# Processing date: 20220616
# Skipping 20220616, missing file.
# Processing date: 20220617
# Skipping 20220617, missing file.
# Processing date: 20220618
# Skipping 20220618, missing file.
# Processing date: 20220619
# Skipping 20220619, missing file.
# Processing date: 20220620
# Skipping 20220620, missing file.
# Processing date: 20220621
# Skipping 20220621, missing file.
# Processing date: 20220622
# Skipping 20220622, missing file.
# Processing date: 20220623
# Skipping 20220623, missing file.
# Processing date: 20220624
# Skipping 20220624, missing file.
# Processing date: 20220625
# Skipping 20220625, missing file.
# Processing date: 20220626
# Skipping 20220626, missing file.
# Processing date: 20220627
# Skipping 20220627, missing file.
# Processing date: 20220628
# Skipping 20220628, missing file.
# Processing date: 20220629
# Skipping 20220629, missing file.
# Processing date: 20220630
# Skipping 20220630, missing file.
# Processing date: 20220701
# Skipping 20220701, missing file.
# Processing date: 20220702
# Skipping 20220702, missing file.
# Processing date: 20220703
# Skipping 20220703, missing file.
# Processing date: 20220704
# Skipping 20220704, missing file.
# Processing date: 20220705
# Skipping 20220705, missing file.
# Processing date: 20220706
# Skipping 20220706, missing file.
# Processing date: 20220707
# Skipping 20220707, missing file.
# Processing date: 20220708
# Skipping 20220708, missing file.
# Processing date: 20220709
# Skipping 20220709, missing file.
# Processing date: 20220710
# Skipping 20220710, missing file.
# Processing date: 20220711
# Skipping 20220711, missing file.
# Processing date: 20220712
# Skipping 20220712, missing file.
# Processing date: 20220713
# Skipping 20220713, missing file.
# Processing date: 20220714
# Skipping 20220714, missing file.
# Processing date: 20220715
# Skipping 20220715, missing file.
# Processing date: 20220716
# Skipping 20220716, missing file.
# Processing date: 20220717
# Skipping 20220717, missing file.
# Processing date: 20220718
# Skipping 20220718, missing file.
# Processing date: 20220719
# Skipping 20220719, missing file.
# Processing date: 20220720
# Skipping 20220720, missing file.
# Processing date: 20220721
# Skipping 20220721, missing file.
# Processing date: 20220722
# Skipping 20220722, missing file.
# Processing date: 20220723
# Skipping 20220723, missing file.
# Processing date: 20220724
# Skipping 20220724, missing file.
# Processing date: 20220725
# Skipping 20220725, missing file.
# Processing date: 20220726
# Skipping 20220726, missing file.
# Processing date: 20220727
# Skipping 20220727, missing file.
# Processing date: 20220728
# Skipping 20220728, missing file.
# Processing date: 20220729
# Skipping 20220729, missing file.
# Processing date: 20220730
# Skipping 20220730, missing file.
# Processing date: 20220731
# Skipping 20220731, missing file.
# Processing date: 20220801
# Skipping 20220801, missing file.
# Processing date: 20220802
# Skipping 20220802, missing file.
# Processing date: 20220803
# Skipping 20220803, missing file.
# Processing date: 20220804
# Skipping 20220804, missing file.
# Processing date: 20220805
# Skipping 20220805, missing file.
# Processing date: 20220806
# Skipping 20220806, missing file.
# Processing date: 20220807
# Skipping 20220807, missing file.
# Processing date: 20220808
# Skipping 20220808, missing file.
# Processing date: 20220809
# Skipping 20220809, missing file.
# Processing date: 20220810
# Skipping 20220810, missing file.
# Processing date: 20220811
# Skipping 20220811, missing file.
# Processing date: 20220812
# Skipping 20220812, missing file.
# Processing date: 20220813
# Skipping 20220813, missing file.
# Processing date: 20220814
# Skipping 20220814, missing file.
# Processing date: 20220815
# Skipping 20220815, missing file.
# Processing date: 20220816
# Skipping 20220816, missing file.
# Processing date: 20220817
# Skipping 20220817, missing file.
# Processing date: 20220818
# Skipping 20220818, missing file.
# Processing date: 20220819
# Skipping 20220819, missing file.
# Processing date: 20220820
# Skipping 20220820, missing file.
# Processing date: 20220821
# Skipping 20220821, missing file.
# Processing date: 20220822
# Skipping 20220822, missing file.
# Processing date: 20220823
# Skipping 20220823, missing file.
# Processing date: 20220824
# Skipping 20220824, missing file.
# Processing date: 20220825
# Skipping 20220825, missing file.
# Processing date: 20220826
# Skipping 20220826, missing file.
# Processing date: 20220827
# Skipping 20220827, missing file.
# Processing date: 20220828
# Skipping 20220828, missing file.
# Processing date: 20220829
# Skipping 20220829, missing file.
# Processing date: 20220830
# Skipping 20220830, missing file.
# Processing date: 20220831
# Skipping 20220831, missing file.
# Processing date: 20220901
# Skipping 20220901, missing file.
# Processing date: 20220902
# Skipping 20220902, missing file.
# Processing date: 20220903
# Skipping 20220903, missing file.
# Processing date: 20220904
# Skipping 20220904, missing file.
# Processing date: 20220905
# Skipping 20220905, missing file.
# Processing date: 20220906
# Skipping 20220906, missing file.
# Processing date: 20220907
# Skipping 20220907, missing file.
# Processing date: 20220908
# Skipping 20220908, missing file.
# Processing date: 20220909
# Skipping 20220909, missing file.
# Processing date: 20220910
# Skipping 20220910, missing file.
# Processing date: 20220911
# Skipping 20220911, missing file.
# Processing date: 20220912
# Skipping 20220912, missing file.
# Processing date: 20220913
# Skipping 20220913, missing file.
# Processing date: 20220914
# Skipping 20220914, missing file.
# Processing date: 20220915
# Skipping 20220915, missing file.
# Processing date: 20220916
# Skipping 20220916, missing file.
# Processing date: 20220917
# Skipping 20220917, missing file.
# Processing date: 20220918
# Skipping 20220918, missing file.
# Processing date: 20220919
# Skipping 20220919, missing file.
# Processing date: 20220920
# Skipping 20220920, missing file.
# Processing date: 20220921
# Skipping 20220921, missing file.
# Processing date: 20220922
# Skipping 20220922, missing file.
# Processing date: 20220923
# Skipping 20220923, missing file.
# Processing date: 20220924
# Processing date: 20220925
# Processing date: 20220926
# Processing date: 20220927
# Processing date: 20220928
# Processing date: 20220929
# Processing date: 20220930
# Processing date: 20221001
# Processing date: 20221002
# Processing date: 20221003
# Processing date: 20221004
# Processing date: 20221005
# Processing date: 20221006
# Processing date: 20221007
# Processing date: 20221008
# Processing date: 20221009
# Processing date: 20221010
# Processing date: 20221011
# Processing date: 20221012
# Processing date: 20221013
# Processing date: 20221014
# Processing date: 20221015
# Processing date: 20221016
# Processing date: 20221017
# Processing date: 20221018
# Processing date: 20221019
# Processing date: 20221020
# Processing date: 20221021
# Processing date: 20221022
# Processing date: 20221023
# Processing date: 20221024
# Processing date: 20221025
# Processing date: 20221026
# Processing date: 20221027
# Skipping 20221027, missing file.
# Processing date: 20221028
# Processing date: 20221029
# Processing date: 20221030
# Processing date: 20221031
# Processing date: 20221101
# Processing date: 20221102
# Processing date: 20221103
# Processing date: 20221104
# Processing date: 20221105
# Processing date: 20221106
# Processing date: 20221107
# Processing date: 20221108
# Processing date: 20221109
# Processing date: 20221110
# Processing date: 20221111
# Processing date: 20221112
# Processing date: 20221113
# Processing date: 20221114
# Processing date: 20221115
# Processing date: 20221116
# Processing date: 20221117
# Processing date: 20221118
# Processing date: 20221119
# C:\Users\holo\AppData\Local\Temp\ipykernel_22220\1936077561.py:25: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   cc_corrected, _ = pearsonr(ref, corr)
# C:\Users\holo\AppData\Local\Temp\ipykernel_22220\1936077561.py:26: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   cc_original, _ = pearsonr(ref, orig)
# Processing date: 20221120
# Processing date: 20221121
# Processing date: 20221122
# Processing date: 20221123
# Processing date: 20221124
# Processing date: 20221125
# Processing date: 20221126
# Processing date: 20221127
# Processing date: 20221128
# Processing date: 20221129
# Processing date: 20221130
# Processing date: 20221201
# Processing date: 20221202
# Processing date: 20221203
# Processing date: 20221204
# Processing date: 20221205
# Processing date: 20221206
# Processing date: 20221207
# Processing date: 20221208
# Processing date: 20221209
# Processing date: 20221210
# Processing date: 20221211
# Processing date: 20221212
# Processing date: 20221213
# Processing date: 20221214
# Processing date: 20221215
# Processing date: 20221216
# Processing date: 20221217
# Processing date: 20221218
# Skipping 20221218, missing file.
# Processing date: 20221219
# Processing date: 20221220
# Skipping 20221220, missing file.
# Processing date: 20221221
# Processing date: 20221222
# Processing date: 20221223
# Skipping 20221223, missing file.
# Processing date: 20221224
# Processing date: 20221225
# Processing date: 20221226
# Processing date: 20221227
# Processing date: 20221228
# Skipping 20221228, missing file.
# Processing date: 20221229
# Processing date: 20221230
# Processing date: 20221231
# Saved metrics to D:\zmh\icethickness\NSIDC-R\3_bias\comparison_metrics_north_rdeft4.csv
