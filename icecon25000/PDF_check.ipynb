# %% [markdown]
# # NISE

# %% [markdown]
# ## 散点图

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

plt.rcParams['font.sans-serif'] = ['SimHei']

def plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date, output_dir):
    """
    绘制订正前、订正后的非参考数据与参考数据的散点图
    :param non_ref_data: 订正前的非参考数据 (2D numpy array)
    :param corrected_data: 订正后的非参考数据 (2D numpy array)
    :param ref_data: 参考数据 (2D numpy array)
    :param date: 当前日期 (str)
    :param output_dir: 输出散点图的保存目录
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 平铺数组，去除 NaN 数据
    mask = (~np.isnan(non_ref_data)) & (~np.isnan(ref_data))
    x_non_ref = non_ref_data[mask]
    x_corrected = corrected_data[mask]
    y_ref = ref_data[mask]
    
    # 绘制订正前的散点图
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_non_ref, y_ref, s=2, alpha=0.5, color='blue')
    plt.plot([90, 100], [90, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(90, 100)
    plt.ylim(90, 100)
   
    plt.xlabel("非参考数据 (订正前)")
    plt.ylabel("参考数据")
    plt.title(f"订正前 ({date})")
    
    # 绘制订正后的散点图
    plt.subplot(1, 2, 2)
    plt.scatter(x_corrected, y_ref, s=2, alpha=0.5, color='red')
    plt.plot([90, 100], [90, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(90, 100)
    plt.ylim(90, 100)
    plt.xlabel("非参考数据 (订正后)")
    plt.ylabel("参考数据")
    plt.title(f"订正后 ({date})")
    
    # 保存散点图
    plt.tight_layout()
    output_file = os.path.join(output_dir, f"scatter_comparison_{date}.png")
    plt.savefig(output_file, dpi=100)
    plt.close()
    print(f"Saved scatter plot: {output_file}")

def generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date):
    """
    生成非参考数据的订正前后与参考数据的散点图
    :param input_dir: 订正前非参考数据目录
    :param corrected_dir: 订正后数据目录
    :param reference_dir: 参考数据目录
    :param output_dir: 输出散点图的保存目录
    :param hemisphere: 'north' 或 'south'
    :param start_date: 开始日期 (str)
    :param end_date: 结束日期 (str)
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        date_str = date.strftime('%Y%m%d')
        print(f"Processing scatter plot for date: {date_str}")

        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_{hemisphere}_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"NISE_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        non_ref_file = os.path.join(input_dir, f"NISE_{hemisphere}_icecon_25000_{date_str}.nc")

        # 检查文件是否存在
        if not all(os.path.exists(f) for f in [ref_file, corrected_file, non_ref_file]):
            print(f"Missing file for date {date_str}, skipping...")
            continue

        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_north_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        non_ref_data = xr.open_dataset(non_ref_file)['NISE_north_icecon'].values

        # 绘制散点图
        plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date_str, output_dir)

if __name__ == "__main__":
    import pandas as pd

    # 文件目录路径
    input_dir = r"D:\zmh\icecon25000_data\NISE\0_pre_com\north"
    corrected_dir = r"D:\zmh\icecon25000_data\NISE\1_PDFcorrected\north"
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\north"
    output_dir = r"D:\zmh\icecon25000_data\NISE\2_scatter_plots"
    # 若output_dir不存在，创建output_dir
    os.makedirs(output_dir, exist_ok=True)

    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing scatter plot for date: 20220101
# Missing file for date 20220101, skipping...
# Processing scatter plot for date: 20220102
# Missing file for date 20220102, skipping...
# Processing scatter plot for date: 20220103
# Missing file for date 20220103, skipping...
# Processing scatter plot for date: 20220104
# Missing file for date 20220104, skipping...
# Processing scatter plot for date: 20220105
# Missing file for date 20220105, skipping...
# Processing scatter plot for date: 20220106
# Missing file for date 20220106, skipping...
# Processing scatter plot for date: 20220107
# Missing file for date 20220107, skipping...
# Processing scatter plot for date: 20220108
# Missing file for date 20220108, skipping...
# Processing scatter plot for date: 20220109
# Missing file for date 20220109, skipping...
# Processing scatter plot for date: 20220110
# Missing file for date 20220110, skipping...
# Processing scatter plot for date: 20220111
# Missing file for date 20220111, skipping...
# Processing scatter plot for date: 20220112
# Missing file for date 20220112, skipping...
# Processing scatter plot for date: 20220113
# Missing file for date 20220113, skipping...
# Processing scatter plot for date: 20220114
# Missing file for date 20220114, skipping...
# Processing scatter plot for date: 20220115
# Missing file for date 20220115, skipping...
# Processing scatter plot for date: 20220116
# Missing file for date 20220116, skipping...
# Processing scatter plot for date: 20220117
# Missing file for date 20220117, skipping...
# Processing scatter plot for date: 20220118
# Missing file for date 20220118, skipping...
# Processing scatter plot for date: 20220119
# Missing file for date 20220119, skipping...
# Processing scatter plot for date: 20220120
# Missing file for date 20220120, skipping...
# Processing scatter plot for date: 20220121
# Missing file for date 20220121, skipping...
# Processing scatter plot for date: 20220122
# Missing file for date 20220122, skipping...
# Processing scatter plot for date: 20220123
# Missing file for date 20220123, skipping...
# Processing scatter plot for date: 20220124
# Missing file for date 20220124, skipping...
# Processing scatter plot for date: 20220125
# Missing file for date 20220125, skipping...
# Processing scatter plot for date: 20220126
# Missing file for date 20220126, skipping...
# Processing scatter plot for date: 20220127
# Missing file for date 20220127, skipping...
# Processing scatter plot for date: 20220128
# Missing file for date 20220128, skipping...
# Processing scatter plot for date: 20220129
# Missing file for date 20220129, skipping...
# Processing scatter plot for date: 20220130
# Missing file for date 20220130, skipping...
# Processing scatter plot for date: 20220131
# Missing file for date 20220131, skipping...
# Processing scatter plot for date: 20220201
# Missing file for date 20220201, skipping...
# Processing scatter plot for date: 20220202
# Missing file for date 20220202, skipping...
# Processing scatter plot for date: 20220203
# Missing file for date 20220203, skipping...
# Processing scatter plot for date: 20220204
# Missing file for date 20220204, skipping...
# Processing scatter plot for date: 20220205
# Missing file for date 20220205, skipping...
# Processing scatter plot for date: 20220206
# Missing file for date 20220206, skipping...
# Processing scatter plot for date: 20220207
# Missing file for date 20220207, skipping...
# Processing scatter plot for date: 20220208
# Missing file for date 20220208, skipping...
# Processing scatter plot for date: 20220209
# Missing file for date 20220209, skipping...
# Processing scatter plot for date: 20220210
# Missing file for date 20220210, skipping...
# Processing scatter plot for date: 20220211
# Missing file for date 20220211, skipping...
# Processing scatter plot for date: 20220212
# Missing file for date 20220212, skipping...
# Processing scatter plot for date: 20220213
# Missing file for date 20220213, skipping...
# Processing scatter plot for date: 20220214
# Missing file for date 20220214, skipping...
# Processing scatter plot for date: 20220215
# Missing file for date 20220215, skipping...
# Processing scatter plot for date: 20220216
# Missing file for date 20220216, skipping...
# Processing scatter plot for date: 20220217
# Missing file for date 20220217, skipping...
# Processing scatter plot for date: 20220218
# Missing file for date 20220218, skipping...
# Processing scatter plot for date: 20220219
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220219.png
# Processing scatter plot for date: 20220220
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220220.png
# Processing scatter plot for date: 20220221
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220221.png
# Processing scatter plot for date: 20220222
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220222.png
# Processing scatter plot for date: 20220223
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220223.png
# Processing scatter plot for date: 20220224
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220224.png
# Processing scatter plot for date: 20220225
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220225.png
# Processing scatter plot for date: 20220226
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220226.png
# Processing scatter plot for date: 20220227
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220227.png
# Processing scatter plot for date: 20220228
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220228.png
# Processing scatter plot for date: 20220301
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220301.png
# Processing scatter plot for date: 20220302
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220302.png
# Processing scatter plot for date: 20220303
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220303.png
# Processing scatter plot for date: 20220304
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220304.png
# Processing scatter plot for date: 20220305
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220305.png
# Processing scatter plot for date: 20220306
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220306.png
# Processing scatter plot for date: 20220307
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220307.png
# Processing scatter plot for date: 20220308
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220308.png
# Processing scatter plot for date: 20220309
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220309.png
# Processing scatter plot for date: 20220310
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220310.png
# Processing scatter plot for date: 20220311
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220311.png
# Processing scatter plot for date: 20220312
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220312.png
# Processing scatter plot for date: 20220313
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220313.png
# Processing scatter plot for date: 20220314
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220314.png
# Processing scatter plot for date: 20220315
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220315.png
# Processing scatter plot for date: 20220316
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220316.png
# Processing scatter plot for date: 20220317
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220317.png
# Processing scatter plot for date: 20220318
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220318.png
# Processing scatter plot for date: 20220319
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220319.png
# Processing scatter plot for date: 20220320
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220320.png
# Processing scatter plot for date: 20220321
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220321.png
# Processing scatter plot for date: 20220322
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220322.png
# Processing scatter plot for date: 20220323
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220323.png
# Processing scatter plot for date: 20220324
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220324.png
# Processing scatter plot for date: 20220325
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220325.png
# Processing scatter plot for date: 20220326
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220326.png
# Processing scatter plot for date: 20220327
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220327.png
# Processing scatter plot for date: 20220328
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220328.png
# Processing scatter plot for date: 20220329
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220329.png
# Processing scatter plot for date: 20220330
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220330.png
# Processing scatter plot for date: 20220331
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220331.png
# Processing scatter plot for date: 20220401
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220401.png
# Processing scatter plot for date: 20220402
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220402.png
# Processing scatter plot for date: 20220403
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220403.png
# Processing scatter plot for date: 20220404
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220404.png
# Processing scatter plot for date: 20220405
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220405.png
# Processing scatter plot for date: 20220406
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220406.png
# Processing scatter plot for date: 20220407
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220407.png
# Processing scatter plot for date: 20220408
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220408.png
# Processing scatter plot for date: 20220409
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220409.png
# Processing scatter plot for date: 20220410
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220410.png
# Processing scatter plot for date: 20220411
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220411.png
# Processing scatter plot for date: 20220412
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220412.png
# Processing scatter plot for date: 20220413
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220413.png
# Processing scatter plot for date: 20220414
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220414.png
# Processing scatter plot for date: 20220415
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220415.png
# Processing scatter plot for date: 20220416
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220416.png
# Processing scatter plot for date: 20220417
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220417.png
# Processing scatter plot for date: 20220418
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220418.png
# Processing scatter plot for date: 20220419
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220419.png
# Processing scatter plot for date: 20220420
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220420.png
# Processing scatter plot for date: 20220421
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220421.png
# Processing scatter plot for date: 20220422
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220422.png
# Processing scatter plot for date: 20220423
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220423.png
# Processing scatter plot for date: 20220424
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220424.png
# Processing scatter plot for date: 20220425
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220425.png
# Processing scatter plot for date: 20220426
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220426.png
# Processing scatter plot for date: 20220427
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220427.png
# Processing scatter plot for date: 20220428
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220428.png
# Processing scatter plot for date: 20220429
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220429.png
# Processing scatter plot for date: 20220430
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220430.png
# Processing scatter plot for date: 20220501
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220501.png
# Processing scatter plot for date: 20220502
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220502.png
# Processing scatter plot for date: 20220503
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220503.png
# Processing scatter plot for date: 20220504
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220504.png
# Processing scatter plot for date: 20220505
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220505.png
# Processing scatter plot for date: 20220506
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220506.png
# Processing scatter plot for date: 20220507
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220507.png
# Processing scatter plot for date: 20220508
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220508.png
# Processing scatter plot for date: 20220509
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220509.png
# Processing scatter plot for date: 20220510
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220510.png
# Processing scatter plot for date: 20220511
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220511.png
# Processing scatter plot for date: 20220512
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220512.png
# Processing scatter plot for date: 20220513
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220513.png
# Processing scatter plot for date: 20220514
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220514.png
# Processing scatter plot for date: 20220515
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220515.png
# Processing scatter plot for date: 20220516
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220516.png
# Processing scatter plot for date: 20220517
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220517.png
# Processing scatter plot for date: 20220518
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220518.png
# Processing scatter plot for date: 20220519
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220519.png
# Processing scatter plot for date: 20220520
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220520.png
# Processing scatter plot for date: 20220521
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220521.png
# Processing scatter plot for date: 20220522
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220522.png
# Processing scatter plot for date: 20220523
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220523.png
# Processing scatter plot for date: 20220524
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220524.png
# Processing scatter plot for date: 20220525
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220525.png
# Processing scatter plot for date: 20220526
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220526.png
# Processing scatter plot for date: 20220527
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220527.png
# Processing scatter plot for date: 20220528
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220528.png
# Processing scatter plot for date: 20220529
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220529.png
# Processing scatter plot for date: 20220530
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220530.png
# Processing scatter plot for date: 20220531
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220531.png
# Processing scatter plot for date: 20220601
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220601.png
# Processing scatter plot for date: 20220602
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220602.png
# Processing scatter plot for date: 20220603
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220603.png
# Processing scatter plot for date: 20220604
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220604.png
# Processing scatter plot for date: 20220605
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220605.png
# Processing scatter plot for date: 20220606
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220606.png
# Processing scatter plot for date: 20220607
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220607.png
# Processing scatter plot for date: 20220608
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220608.png
# Processing scatter plot for date: 20220609
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220609.png
# Processing scatter plot for date: 20220610
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220610.png
# Processing scatter plot for date: 20220611
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220611.png
# Processing scatter plot for date: 20220612
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220612.png
# Processing scatter plot for date: 20220613
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220613.png
# Processing scatter plot for date: 20220614
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220614.png
# Processing scatter plot for date: 20220615
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220615.png
# Processing scatter plot for date: 20220616
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220616.png
# Processing scatter plot for date: 20220617
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220617.png
# Processing scatter plot for date: 20220618
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220618.png
# Processing scatter plot for date: 20220619
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220619.png
# Processing scatter plot for date: 20220620
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220620.png
# Processing scatter plot for date: 20220621
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220621.png
# Processing scatter plot for date: 20220622
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220622.png
# Processing scatter plot for date: 20220623
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220623.png
# Processing scatter plot for date: 20220624
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220624.png
# Processing scatter plot for date: 20220625
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220625.png
# Processing scatter plot for date: 20220626
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220626.png
# Processing scatter plot for date: 20220627
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220627.png
# Processing scatter plot for date: 20220628
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220628.png
# Processing scatter plot for date: 20220629
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220629.png
# Processing scatter plot for date: 20220630
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220630.png
# Processing scatter plot for date: 20220701
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220701.png
# Processing scatter plot for date: 20220702
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220702.png
# Processing scatter plot for date: 20220703
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220703.png
# Processing scatter plot for date: 20220704
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220704.png
# Processing scatter plot for date: 20220705
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220705.png
# Processing scatter plot for date: 20220706
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220706.png
# Processing scatter plot for date: 20220707
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220707.png
# Processing scatter plot for date: 20220708
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220708.png
# Processing scatter plot for date: 20220709
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220709.png
# Processing scatter plot for date: 20220710
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220710.png
# Processing scatter plot for date: 20220711
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220711.png
# Processing scatter plot for date: 20220712
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220712.png
# Processing scatter plot for date: 20220713
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220713.png
# Processing scatter plot for date: 20220714
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220714.png
# Processing scatter plot for date: 20220715
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220715.png
# Processing scatter plot for date: 20220716
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220716.png
# Processing scatter plot for date: 20220717
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220717.png
# Processing scatter plot for date: 20220718
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220718.png
# Processing scatter plot for date: 20220719
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220719.png
# Processing scatter plot for date: 20220720
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220720.png
# Processing scatter plot for date: 20220721
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220721.png
# Processing scatter plot for date: 20220722
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220722.png
# Processing scatter plot for date: 20220723
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220723.png
# Processing scatter plot for date: 20220724
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220724.png
# Processing scatter plot for date: 20220725
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220725.png
# Processing scatter plot for date: 20220726
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220726.png
# Processing scatter plot for date: 20220727
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220727.png
# Processing scatter plot for date: 20220728
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220728.png
# Processing scatter plot for date: 20220729
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220729.png
# Processing scatter plot for date: 20220730
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220730.png
# Processing scatter plot for date: 20220731
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220731.png
# Processing scatter plot for date: 20220801
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220801.png
# Processing scatter plot for date: 20220802
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220802.png
# Processing scatter plot for date: 20220803
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220803.png
# Processing scatter plot for date: 20220804
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220804.png
# Processing scatter plot for date: 20220805
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220805.png
# Processing scatter plot for date: 20220806
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220806.png
# Processing scatter plot for date: 20220807
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220807.png
# Processing scatter plot for date: 20220808
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220808.png
# Processing scatter plot for date: 20220809
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220809.png
# Processing scatter plot for date: 20220810
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220810.png
# Processing scatter plot for date: 20220811
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220811.png
# Processing scatter plot for date: 20220812
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220812.png
# Processing scatter plot for date: 20220813
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220813.png
# Processing scatter plot for date: 20220814
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220814.png
# Processing scatter plot for date: 20220815
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220815.png
# Processing scatter plot for date: 20220816
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220816.png
# Processing scatter plot for date: 20220817
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220817.png
# Processing scatter plot for date: 20220818
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220818.png
# Processing scatter plot for date: 20220819
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220819.png
# Processing scatter plot for date: 20220820
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220820.png
# Processing scatter plot for date: 20220821
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220821.png
# Processing scatter plot for date: 20220822
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220822.png
# Processing scatter plot for date: 20220823
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220823.png
# Processing scatter plot for date: 20220824
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220824.png
# Processing scatter plot for date: 20220825
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220825.png
# Processing scatter plot for date: 20220826
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220826.png
# Processing scatter plot for date: 20220827
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220827.png
# Processing scatter plot for date: 20220828
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220828.png
# Processing scatter plot for date: 20220829
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220829.png
# Processing scatter plot for date: 20220830
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220830.png
# Processing scatter plot for date: 20220831
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220831.png
# Processing scatter plot for date: 20220901
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220901.png
# Processing scatter plot for date: 20220902
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220902.png
# Processing scatter plot for date: 20220903
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220903.png
# Processing scatter plot for date: 20220904
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220904.png
# Processing scatter plot for date: 20220905
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220905.png
# Processing scatter plot for date: 20220906
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220906.png
# Processing scatter plot for date: 20220907
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220907.png
# Processing scatter plot for date: 20220908
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220908.png
# Processing scatter plot for date: 20220909
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220909.png
# Processing scatter plot for date: 20220910
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220910.png
# Processing scatter plot for date: 20220911
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220911.png
# Processing scatter plot for date: 20220912
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220912.png
# Processing scatter plot for date: 20220913
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220913.png
# Processing scatter plot for date: 20220914
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220914.png
# Processing scatter plot for date: 20220915
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220915.png
# Processing scatter plot for date: 20220916
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220916.png
# Processing scatter plot for date: 20220917
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220917.png
# Processing scatter plot for date: 20220918
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220918.png
# Processing scatter plot for date: 20220919
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220919.png
# Processing scatter plot for date: 20220920
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220920.png
# Processing scatter plot for date: 20220921
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220921.png
# Processing scatter plot for date: 20220922
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220922.png
# Processing scatter plot for date: 20220923
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220923.png
# Processing scatter plot for date: 20220924
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220924.png
# Processing scatter plot for date: 20220925
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220925.png
# Processing scatter plot for date: 20220926
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220926.png
# Processing scatter plot for date: 20220927
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220927.png
# Processing scatter plot for date: 20220928
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220928.png
# Processing scatter plot for date: 20220929
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220929.png
# Processing scatter plot for date: 20220930
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220930.png
# Processing scatter plot for date: 20221001
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221001.png
# Processing scatter plot for date: 20221002
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221002.png
# Processing scatter plot for date: 20221003
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221003.png
# Processing scatter plot for date: 20221004
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221004.png
# Processing scatter plot for date: 20221005
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221005.png
# Processing scatter plot for date: 20221006
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221006.png
# Processing scatter plot for date: 20221007
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221007.png
# Processing scatter plot for date: 20221008
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221008.png
# Processing scatter plot for date: 20221009
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221009.png
# Processing scatter plot for date: 20221010
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221010.png
# Processing scatter plot for date: 20221011
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221011.png
# Processing scatter plot for date: 20221012
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221012.png
# Processing scatter plot for date: 20221013
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221013.png
# Processing scatter plot for date: 20221014
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221014.png
# Processing scatter plot for date: 20221015
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221015.png
# Processing scatter plot for date: 20221016
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221016.png
# Processing scatter plot for date: 20221017
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221017.png
# Processing scatter plot for date: 20221018
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221018.png
# Processing scatter plot for date: 20221019
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221019.png
# Processing scatter plot for date: 20221020
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221020.png
# Processing scatter plot for date: 20221021
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221021.png
# Processing scatter plot for date: 20221022
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221022.png
# Processing scatter plot for date: 20221023
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221023.png
# Processing scatter plot for date: 20221024
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221024.png
# Processing scatter plot for date: 20221025
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221025.png
# Processing scatter plot for date: 20221026
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221026.png
# Processing scatter plot for date: 20221027
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221027.png
# Processing scatter plot for date: 20221028
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221028.png
# Processing scatter plot for date: 20221029
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221029.png
# Processing scatter plot for date: 20221030
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221030.png
# Processing scatter plot for date: 20221031
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221031.png
# Processing scatter plot for date: 20221101
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221101.png
# Processing scatter plot for date: 20221102
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221102.png
# Processing scatter plot for date: 20221103
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221103.png
# Processing scatter plot for date: 20221104
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221104.png
# Processing scatter plot for date: 20221105
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221105.png
# Processing scatter plot for date: 20221106
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221106.png
# Processing scatter plot for date: 20221107
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221107.png
# Processing scatter plot for date: 20221108
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221108.png
# Processing scatter plot for date: 20221109
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221109.png
# Processing scatter plot for date: 20221110
# Missing file for date 20221110, skipping...
# Processing scatter plot for date: 20221111
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221111.png
# Processing scatter plot for date: 20221112
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221112.png
# Processing scatter plot for date: 20221113
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221113.png
# Processing scatter plot for date: 20221114
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221114.png
# Processing scatter plot for date: 20221115
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221115.png
# Processing scatter plot for date: 20221116
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221116.png
# Processing scatter plot for date: 20221117
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221117.png
# Processing scatter plot for date: 20221118
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221118.png
# Processing scatter plot for date: 20221119
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221119.png
# Processing scatter plot for date: 20221120
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221120.png
# Processing scatter plot for date: 20221121
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221121.png
# Processing scatter plot for date: 20221122
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221122.png
# Processing scatter plot for date: 20221123
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221123.png
# Processing scatter plot for date: 20221124
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221124.png
# Processing scatter plot for date: 20221125
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221125.png
# Processing scatter plot for date: 20221126
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221126.png
# Processing scatter plot for date: 20221127
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221127.png
# Processing scatter plot for date: 20221128
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221128.png
# Processing scatter plot for date: 20221129
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221129.png
# Processing scatter plot for date: 20221130
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221130.png
# Processing scatter plot for date: 20221201
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221201.png
# Processing scatter plot for date: 20221202
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221202.png
# Processing scatter plot for date: 20221203
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221203.png
# Processing scatter plot for date: 20221204
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221204.png
# Processing scatter plot for date: 20221205
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221205.png
# Processing scatter plot for date: 20221206
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221206.png
# Processing scatter plot for date: 20221207
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221207.png
# Processing scatter plot for date: 20221208
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221208.png
# Processing scatter plot for date: 20221209
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221209.png
# Processing scatter plot for date: 20221210
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221210.png
# Processing scatter plot for date: 20221211
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221211.png
# Processing scatter plot for date: 20221212
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221212.png
# Processing scatter plot for date: 20221213
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221213.png
# Processing scatter plot for date: 20221214
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221214.png
# Processing scatter plot for date: 20221215
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221215.png
# Processing scatter plot for date: 20221216
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221216.png
# Processing scatter plot for date: 20221217
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221217.png
# Processing scatter plot for date: 20221218
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221218.png
# Processing scatter plot for date: 20221219
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221219.png
# Processing scatter plot for date: 20221220
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221220.png
# Processing scatter plot for date: 20221221
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221221.png
# Processing scatter plot for date: 20221222
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221222.png
# Processing scatter plot for date: 20221223
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221223.png
# Processing scatter plot for date: 20221224
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221224.png
# Processing scatter plot for date: 20221225
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221225.png
# Processing scatter plot for date: 20221226
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221226.png
# Processing scatter plot for date: 20221227
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221227.png
# Processing scatter plot for date: 20221228
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221228.png
# Processing scatter plot for date: 20221229
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221229.png
# Processing scatter plot for date: 20221230
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221230.png
# Processing scatter plot for date: 20221231
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221231.png

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

plt.rcParams['font.sans-serif'] = ['SimHei']

def plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date, output_dir):
    """
    绘制订正前、订正后的非参考数据与参考数据的散点图
    :param non_ref_data: 订正前的非参考数据 (2D numpy array)
    :param corrected_data: 订正后的非参考数据 (2D numpy array)
    :param ref_data: 参考数据 (2D numpy array)
    :param date: 当前日期 (str)
    :param output_dir: 输出散点图的保存目录
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 平铺数组，去除 NaN 数据
    mask = (~np.isnan(non_ref_data)) & (~np.isnan(ref_data))
    x_non_ref = non_ref_data[mask]
    x_corrected = corrected_data[mask]
    y_ref = ref_data[mask]
    
    # 绘制订正前的散点图
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_non_ref, y_ref, s=2, alpha=0.5, color='blue')
    plt.plot([0, 100], [0, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 100)
    plt.ylim(0, 100)
   
    plt.xlabel("非参考数据 (订正前)")
    plt.ylabel("参考数据")
    plt.title(f"订正前 ({date})")
    
    # 绘制订正后的散点图
    plt.subplot(1, 2, 2)
    plt.scatter(x_corrected, y_ref, s=2, alpha=0.5, color='red')
    plt.plot([0, 100], [0, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 100)
    plt.ylim(0, 100)
    plt.xlabel("非参考数据 (订正后)")
    plt.ylabel("参考数据")
    plt.title(f"订正后 ({date})")
     
    # 保存散点图
    plt.tight_layout()
    output_file = os.path.join(output_dir, f"scatter_comparison_{date}_south.png")
    plt.savefig(output_file, dpi=100)
    plt.close()
    print(f"Saved scatter plot: {output_file}")

def generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date):
    """
    生成非参考数据的订正前后与参考数据的散点图
    :param input_dir: 订正前非参考数据目录
    :param corrected_dir: 订正后数据目录
    :param reference_dir: 参考数据目录
    :param output_dir: 输出散点图的保存目录
    :param hemisphere: 'north' 或 'south'
    :param start_date: 开始日期 (str)
    :param end_date: 结束日期 (str)
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        date_str = date.strftime('%Y%m%d')
        print(f"Processing scatter plot for date: {date_str}")

        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_{hemisphere}_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"NISE_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        non_ref_file = os.path.join(input_dir, f"NISE_{hemisphere}_icecon_25000_{date_str}.nc")

        # 检查文件是否存在
        if not all(os.path.exists(f) for f in [ref_file, corrected_file, non_ref_file]):
            print(f"Missing file for date {date_str}, skipping...")
            continue

        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_south_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        non_ref_data = xr.open_dataset(non_ref_file)['NISE_south_icecon'].values

        # 绘制散点图
        plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date_str, output_dir)

if __name__ == "__main__":
    import pandas as pd

    # 文件目录路径
    input_dir = r"D:\zmh\icecon25000_data\NISE\0_pre_com\south"
    corrected_dir = r"D:\zmh\icecon25000_data\NISE\1_PDFcorrected\south"
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\south"
    output_dir = r"D:\zmh\icecon25000_data\NISE\2_scatter_plots"
    # 若output_dir不存在，创建output_dir
    os.makedirs(output_dir, exist_ok=True)

    hemisphere = "south"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing scatter plot for date: 20220101
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220101_south.png
# Processing scatter plot for date: 20220102
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220102_south.png
# Processing scatter plot for date: 20220103
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220103_south.png
# Processing scatter plot for date: 20220104
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220104_south.png
# Processing scatter plot for date: 20220105
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220105_south.png
# Processing scatter plot for date: 20220106
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220106_south.png
# Processing scatter plot for date: 20220107
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220107_south.png
# Processing scatter plot for date: 20220108
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220108_south.png
# Processing scatter plot for date: 20220109
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220109_south.png
# Processing scatter plot for date: 20220110
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220110_south.png
# Processing scatter plot for date: 20220111
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220111_south.png
# Processing scatter plot for date: 20220112
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220112_south.png
# Processing scatter plot for date: 20220113
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220113_south.png
# Processing scatter plot for date: 20220114
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220114_south.png
# Processing scatter plot for date: 20220115
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220115_south.png
# Processing scatter plot for date: 20220116
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220116_south.png
# Processing scatter plot for date: 20220117
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220117_south.png
# Processing scatter plot for date: 20220118
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220118_south.png
# Processing scatter plot for date: 20220119
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220119_south.png
# Processing scatter plot for date: 20220120
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220120_south.png
# Processing scatter plot for date: 20220121
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220121_south.png
# Processing scatter plot for date: 20220122
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220122_south.png
# Processing scatter plot for date: 20220123
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220123_south.png
# Processing scatter plot for date: 20220124
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220124_south.png
# Processing scatter plot for date: 20220125
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220125_south.png
# Processing scatter plot for date: 20220126
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220126_south.png
# Processing scatter plot for date: 20220127
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220127_south.png
# Processing scatter plot for date: 20220128
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220128_south.png
# Processing scatter plot for date: 20220129
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220129_south.png
# Processing scatter plot for date: 20220130
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220130_south.png
# Processing scatter plot for date: 20220131
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220131_south.png
# Processing scatter plot for date: 20220201
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220201_south.png
# Processing scatter plot for date: 20220202
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220202_south.png
# Processing scatter plot for date: 20220203
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220203_south.png
# Processing scatter plot for date: 20220204
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220204_south.png
# Processing scatter plot for date: 20220205
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220205_south.png
# Processing scatter plot for date: 20220206
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220206_south.png
# Processing scatter plot for date: 20220207
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220207_south.png
# Processing scatter plot for date: 20220208
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220208_south.png
# Processing scatter plot for date: 20220209
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220209_south.png
# Processing scatter plot for date: 20220210
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220210_south.png
# Processing scatter plot for date: 20220211
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220211_south.png
# Processing scatter plot for date: 20220212
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220212_south.png
# Processing scatter plot for date: 20220213
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220213_south.png
# Processing scatter plot for date: 20220214
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220214_south.png
# Processing scatter plot for date: 20220215
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220215_south.png
# Processing scatter plot for date: 20220216
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220216_south.png
# Processing scatter plot for date: 20220217
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220217_south.png
# Processing scatter plot for date: 20220218
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220218_south.png
# Processing scatter plot for date: 20220219
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220219_south.png
# Processing scatter plot for date: 20220220
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220220_south.png
# Processing scatter plot for date: 20220221
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220221_south.png
# Processing scatter plot for date: 20220222
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220222_south.png
# Processing scatter plot for date: 20220223
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220223_south.png
# Processing scatter plot for date: 20220224
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220224_south.png
# Processing scatter plot for date: 20220225
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220225_south.png
# Processing scatter plot for date: 20220226
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220226_south.png
# Processing scatter plot for date: 20220227
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220227_south.png
# Processing scatter plot for date: 20220228
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220228_south.png
# Processing scatter plot for date: 20220301
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220301_south.png
# Processing scatter plot for date: 20220302
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220302_south.png
# Processing scatter plot for date: 20220303
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220303_south.png
# Processing scatter plot for date: 20220304
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220304_south.png
# Processing scatter plot for date: 20220305
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220305_south.png
# Processing scatter plot for date: 20220306
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220306_south.png
# Processing scatter plot for date: 20220307
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220307_south.png
# Processing scatter plot for date: 20220308
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220308_south.png
# Processing scatter plot for date: 20220309
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220309_south.png
# Processing scatter plot for date: 20220310
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220310_south.png
# Processing scatter plot for date: 20220311
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220311_south.png
# Processing scatter plot for date: 20220312
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220312_south.png
# Processing scatter plot for date: 20220313
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220313_south.png
# Processing scatter plot for date: 20220314
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220314_south.png
# Processing scatter plot for date: 20220315
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220315_south.png
# Processing scatter plot for date: 20220316
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220316_south.png
# Processing scatter plot for date: 20220317
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220317_south.png
# Processing scatter plot for date: 20220318
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220318_south.png
# Processing scatter plot for date: 20220319
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220319_south.png
# Processing scatter plot for date: 20220320
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220320_south.png
# Processing scatter plot for date: 20220321
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220321_south.png
# Processing scatter plot for date: 20220322
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220322_south.png
# Processing scatter plot for date: 20220323
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220323_south.png
# Processing scatter plot for date: 20220324
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220324_south.png
# Processing scatter plot for date: 20220325
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220325_south.png
# Processing scatter plot for date: 20220326
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220326_south.png
# Processing scatter plot for date: 20220327
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220327_south.png
# Processing scatter plot for date: 20220328
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220328_south.png
# Processing scatter plot for date: 20220329
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220329_south.png
# Processing scatter plot for date: 20220330
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220330_south.png
# Processing scatter plot for date: 20220331
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220331_south.png
# Processing scatter plot for date: 20220401
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220401_south.png
# Processing scatter plot for date: 20220402
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220402_south.png
# Processing scatter plot for date: 20220403
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220403_south.png
# Processing scatter plot for date: 20220404
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220404_south.png
# Processing scatter plot for date: 20220405
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220405_south.png
# Processing scatter plot for date: 20220406
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220406_south.png
# Processing scatter plot for date: 20220407
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220407_south.png
# Processing scatter plot for date: 20220408
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220408_south.png
# Processing scatter plot for date: 20220409
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220409_south.png
# Processing scatter plot for date: 20220410
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220410_south.png
# Processing scatter plot for date: 20220411
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220411_south.png
# Processing scatter plot for date: 20220412
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220412_south.png
# Processing scatter plot for date: 20220413
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220413_south.png
# Processing scatter plot for date: 20220414
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220414_south.png
# Processing scatter plot for date: 20220415
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220415_south.png
# Processing scatter plot for date: 20220416
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220416_south.png
# Processing scatter plot for date: 20220417
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220417_south.png
# Processing scatter plot for date: 20220418
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220418_south.png
# Processing scatter plot for date: 20220419
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220419_south.png
# Processing scatter plot for date: 20220420
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220420_south.png
# Processing scatter plot for date: 20220421
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220421_south.png
# Processing scatter plot for date: 20220422
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220422_south.png
# Processing scatter plot for date: 20220423
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220423_south.png
# Processing scatter plot for date: 20220424
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220424_south.png
# Processing scatter plot for date: 20220425
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220425_south.png
# Processing scatter plot for date: 20220426
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220426_south.png
# Processing scatter plot for date: 20220427
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220427_south.png
# Processing scatter plot for date: 20220428
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220428_south.png
# Processing scatter plot for date: 20220429
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220429_south.png
# Processing scatter plot for date: 20220430
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220430_south.png
# Processing scatter plot for date: 20220501
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220501_south.png
# Processing scatter plot for date: 20220502
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220502_south.png
# Processing scatter plot for date: 20220503
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220503_south.png
# Processing scatter plot for date: 20220504
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220504_south.png
# Processing scatter plot for date: 20220505
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220505_south.png
# Processing scatter plot for date: 20220506
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220506_south.png
# Processing scatter plot for date: 20220507
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220507_south.png
# Processing scatter plot for date: 20220508
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220508_south.png
# Processing scatter plot for date: 20220509
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220509_south.png
# Processing scatter plot for date: 20220510
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220510_south.png
# Processing scatter plot for date: 20220511
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220511_south.png
# Processing scatter plot for date: 20220512
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220512_south.png
# Processing scatter plot for date: 20220513
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220513_south.png
# Processing scatter plot for date: 20220514
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220514_south.png
# Processing scatter plot for date: 20220515
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220515_south.png
# Processing scatter plot for date: 20220516
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220516_south.png
# Processing scatter plot for date: 20220517
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220517_south.png
# Processing scatter plot for date: 20220518
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220518_south.png
# Processing scatter plot for date: 20220519
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220519_south.png
# Processing scatter plot for date: 20220520
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220520_south.png
# Processing scatter plot for date: 20220521
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220521_south.png
# Processing scatter plot for date: 20220522
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220522_south.png
# Processing scatter plot for date: 20220523
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220523_south.png
# Processing scatter plot for date: 20220524
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220524_south.png
# Processing scatter plot for date: 20220525
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220525_south.png
# Processing scatter plot for date: 20220526
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220526_south.png
# Processing scatter plot for date: 20220527
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220527_south.png
# Processing scatter plot for date: 20220528
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220528_south.png
# Processing scatter plot for date: 20220529
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220529_south.png
# Processing scatter plot for date: 20220530
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220530_south.png
# Processing scatter plot for date: 20220531
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220531_south.png
# Processing scatter plot for date: 20220601
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220601_south.png
# Processing scatter plot for date: 20220602
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220602_south.png
# Processing scatter plot for date: 20220603
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220603_south.png
# Processing scatter plot for date: 20220604
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220604_south.png
# Processing scatter plot for date: 20220605
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220605_south.png
# Processing scatter plot for date: 20220606
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220606_south.png
# Processing scatter plot for date: 20220607
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220607_south.png
# Processing scatter plot for date: 20220608
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220608_south.png
# Processing scatter plot for date: 20220609
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220609_south.png
# Processing scatter plot for date: 20220610
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220610_south.png
# Processing scatter plot for date: 20220611
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220611_south.png
# Processing scatter plot for date: 20220612
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220612_south.png
# Processing scatter plot for date: 20220613
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220613_south.png
# Processing scatter plot for date: 20220614
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220614_south.png
# Processing scatter plot for date: 20220615
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220615_south.png
# Processing scatter plot for date: 20220616
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220616_south.png
# Processing scatter plot for date: 20220617
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220617_south.png
# Processing scatter plot for date: 20220618
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220618_south.png
# Processing scatter plot for date: 20220619
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220619_south.png
# Processing scatter plot for date: 20220620
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220620_south.png
# Processing scatter plot for date: 20220621
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220621_south.png
# Processing scatter plot for date: 20220622
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220622_south.png
# Processing scatter plot for date: 20220623
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220623_south.png
# Processing scatter plot for date: 20220624
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220624_south.png
# Processing scatter plot for date: 20220625
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220625_south.png
# Processing scatter plot for date: 20220626
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220626_south.png
# Processing scatter plot for date: 20220627
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220627_south.png
# Processing scatter plot for date: 20220628
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220628_south.png
# Processing scatter plot for date: 20220629
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220629_south.png
# Processing scatter plot for date: 20220630
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220630_south.png
# Processing scatter plot for date: 20220701
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220701_south.png
# Processing scatter plot for date: 20220702
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220702_south.png
# Processing scatter plot for date: 20220703
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220703_south.png
# Processing scatter plot for date: 20220704
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220704_south.png
# Processing scatter plot for date: 20220705
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220705_south.png
# Processing scatter plot for date: 20220706
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220706_south.png
# Processing scatter plot for date: 20220707
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220707_south.png
# Processing scatter plot for date: 20220708
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220708_south.png
# Processing scatter plot for date: 20220709
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220709_south.png
# Processing scatter plot for date: 20220710
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220710_south.png
# Processing scatter plot for date: 20220711
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220711_south.png
# Processing scatter plot for date: 20220712
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220712_south.png
# Processing scatter plot for date: 20220713
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220713_south.png
# Processing scatter plot for date: 20220714
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220714_south.png
# Processing scatter plot for date: 20220715
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220715_south.png
# Processing scatter plot for date: 20220716
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220716_south.png
# Processing scatter plot for date: 20220717
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220717_south.png
# Processing scatter plot for date: 20220718
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220718_south.png
# Processing scatter plot for date: 20220719
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220719_south.png
# Processing scatter plot for date: 20220720
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220720_south.png
# Processing scatter plot for date: 20220721
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220721_south.png
# Processing scatter plot for date: 20220722
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220722_south.png
# Processing scatter plot for date: 20220723
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220723_south.png
# Processing scatter plot for date: 20220724
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220724_south.png
# Processing scatter plot for date: 20220725
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220725_south.png
# Processing scatter plot for date: 20220726
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220726_south.png
# Processing scatter plot for date: 20220727
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220727_south.png
# Processing scatter plot for date: 20220728
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220728_south.png
# Processing scatter plot for date: 20220729
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220729_south.png
# Processing scatter plot for date: 20220730
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220730_south.png
# Processing scatter plot for date: 20220731
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220731_south.png
# Processing scatter plot for date: 20220801
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220801_south.png
# Processing scatter plot for date: 20220802
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220802_south.png
# Processing scatter plot for date: 20220803
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220803_south.png
# Processing scatter plot for date: 20220804
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220804_south.png
# Processing scatter plot for date: 20220805
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220805_south.png
# Processing scatter plot for date: 20220806
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220806_south.png
# Processing scatter plot for date: 20220807
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220807_south.png
# Processing scatter plot for date: 20220808
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220808_south.png
# Processing scatter plot for date: 20220809
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220809_south.png
# Processing scatter plot for date: 20220810
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220810_south.png
# Processing scatter plot for date: 20220811
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220811_south.png
# Processing scatter plot for date: 20220812
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220812_south.png
# Processing scatter plot for date: 20220813
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220813_south.png
# Processing scatter plot for date: 20220814
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220814_south.png
# Processing scatter plot for date: 20220815
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220815_south.png
# Processing scatter plot for date: 20220816
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220816_south.png
# Processing scatter plot for date: 20220817
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220817_south.png
# Processing scatter plot for date: 20220818
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220818_south.png
# Processing scatter plot for date: 20220819
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220819_south.png
# Processing scatter plot for date: 20220820
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220820_south.png
# Processing scatter plot for date: 20220821
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220821_south.png
# Processing scatter plot for date: 20220822
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220822_south.png
# Processing scatter plot for date: 20220823
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220823_south.png
# Processing scatter plot for date: 20220824
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220824_south.png
# Processing scatter plot for date: 20220825
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220825_south.png
# Processing scatter plot for date: 20220826
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220826_south.png
# Processing scatter plot for date: 20220827
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220827_south.png
# Processing scatter plot for date: 20220828
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220828_south.png
# Processing scatter plot for date: 20220829
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220829_south.png
# Processing scatter plot for date: 20220830
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220830_south.png
# Processing scatter plot for date: 20220831
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220831_south.png
# Processing scatter plot for date: 20220901
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220901_south.png
# Processing scatter plot for date: 20220902
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220902_south.png
# Processing scatter plot for date: 20220903
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220903_south.png
# Processing scatter plot for date: 20220904
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220904_south.png
# Processing scatter plot for date: 20220905
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220905_south.png
# Processing scatter plot for date: 20220906
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220906_south.png
# Processing scatter plot for date: 20220907
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220907_south.png
# Processing scatter plot for date: 20220908
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220908_south.png
# Processing scatter plot for date: 20220909
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220909_south.png
# Processing scatter plot for date: 20220910
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220910_south.png
# Processing scatter plot for date: 20220911
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220911_south.png
# Processing scatter plot for date: 20220912
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220912_south.png
# Processing scatter plot for date: 20220913
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220913_south.png
# Processing scatter plot for date: 20220914
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220914_south.png
# Processing scatter plot for date: 20220915
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220915_south.png
# Processing scatter plot for date: 20220916
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220916_south.png
# Processing scatter plot for date: 20220917
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220917_south.png
# Processing scatter plot for date: 20220918
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220918_south.png
# Processing scatter plot for date: 20220919
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220919_south.png
# Processing scatter plot for date: 20220920
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220920_south.png
# Processing scatter plot for date: 20220921
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220921_south.png
# Processing scatter plot for date: 20220922
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220922_south.png
# Processing scatter plot for date: 20220923
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220923_south.png
# Processing scatter plot for date: 20220924
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220924_south.png
# Processing scatter plot for date: 20220925
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220925_south.png
# Processing scatter plot for date: 20220926
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220926_south.png
# Processing scatter plot for date: 20220927
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220927_south.png
# Processing scatter plot for date: 20220928
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220928_south.png
# Processing scatter plot for date: 20220929
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220929_south.png
# Processing scatter plot for date: 20220930
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20220930_south.png
# Processing scatter plot for date: 20221001
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221001_south.png
# Processing scatter plot for date: 20221002
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221002_south.png
# Processing scatter plot for date: 20221003
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221003_south.png
# Processing scatter plot for date: 20221004
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221004_south.png
# Processing scatter plot for date: 20221005
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221005_south.png
# Processing scatter plot for date: 20221006
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221006_south.png
# Processing scatter plot for date: 20221007
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221007_south.png
# Processing scatter plot for date: 20221008
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221008_south.png
# Processing scatter plot for date: 20221009
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221009_south.png
# Processing scatter plot for date: 20221010
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221010_south.png
# Processing scatter plot for date: 20221011
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221011_south.png
# Processing scatter plot for date: 20221012
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221012_south.png
# Processing scatter plot for date: 20221013
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221013_south.png
# Processing scatter plot for date: 20221014
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221014_south.png
# Processing scatter plot for date: 20221015
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221015_south.png
# Processing scatter plot for date: 20221016
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221016_south.png
# Processing scatter plot for date: 20221017
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221017_south.png
# Processing scatter plot for date: 20221018
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221018_south.png
# Processing scatter plot for date: 20221019
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221019_south.png
# Processing scatter plot for date: 20221020
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221020_south.png
# Processing scatter plot for date: 20221021
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221021_south.png
# Processing scatter plot for date: 20221022
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221022_south.png
# Processing scatter plot for date: 20221023
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221023_south.png
# Processing scatter plot for date: 20221024
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221024_south.png
# Processing scatter plot for date: 20221025
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221025_south.png
# Processing scatter plot for date: 20221026
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221026_south.png
# Processing scatter plot for date: 20221027
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221027_south.png
# Processing scatter plot for date: 20221028
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221028_south.png
# Processing scatter plot for date: 20221029
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221029_south.png
# Processing scatter plot for date: 20221030
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221030_south.png
# Processing scatter plot for date: 20221031
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221031_south.png
# Processing scatter plot for date: 20221101
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221101_south.png
# Processing scatter plot for date: 20221102
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221102_south.png
# Processing scatter plot for date: 20221103
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221103_south.png
# Processing scatter plot for date: 20221104
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221104_south.png
# Processing scatter plot for date: 20221105
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221105_south.png
# Processing scatter plot for date: 20221106
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221106_south.png
# Processing scatter plot for date: 20221107
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221107_south.png
# Processing scatter plot for date: 20221108
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221108_south.png
# Processing scatter plot for date: 20221109
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221109_south.png
# Processing scatter plot for date: 20221110
# Missing file for date 20221110, skipping...
# Processing scatter plot for date: 20221111
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221111_south.png
# Processing scatter plot for date: 20221112
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221112_south.png
# Processing scatter plot for date: 20221113
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221113_south.png
# Processing scatter plot for date: 20221114
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221114_south.png
# Processing scatter plot for date: 20221115
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221115_south.png
# Processing scatter plot for date: 20221116
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221116_south.png
# Processing scatter plot for date: 20221117
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221117_south.png
# Processing scatter plot for date: 20221118
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221118_south.png
# Processing scatter plot for date: 20221119
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221119_south.png
# Processing scatter plot for date: 20221120
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221120_south.png
# Processing scatter plot for date: 20221121
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221121_south.png
# Processing scatter plot for date: 20221122
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221122_south.png
# Processing scatter plot for date: 20221123
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221123_south.png
# Processing scatter plot for date: 20221124
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221124_south.png
# Processing scatter plot for date: 20221125
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221125_south.png
# Processing scatter plot for date: 20221126
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221126_south.png
# Processing scatter plot for date: 20221127
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221127_south.png
# Processing scatter plot for date: 20221128
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221128_south.png
# Processing scatter plot for date: 20221129
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221129_south.png
# Processing scatter plot for date: 20221130
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221130_south.png
# Processing scatter plot for date: 20221201
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221201_south.png
# Processing scatter plot for date: 20221202
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221202_south.png
# Processing scatter plot for date: 20221203
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221203_south.png
# Processing scatter plot for date: 20221204
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221204_south.png
# Processing scatter plot for date: 20221205
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221205_south.png
# Processing scatter plot for date: 20221206
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221206_south.png
# Processing scatter plot for date: 20221207
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221207_south.png
# Processing scatter plot for date: 20221208
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221208_south.png
# Processing scatter plot for date: 20221209
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221209_south.png
# Processing scatter plot for date: 20221210
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221210_south.png
# Processing scatter plot for date: 20221211
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221211_south.png
# Processing scatter plot for date: 20221212
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221212_south.png
# Processing scatter plot for date: 20221213
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221213_south.png
# Processing scatter plot for date: 20221214
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221214_south.png
# Processing scatter plot for date: 20221215
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221215_south.png
# Processing scatter plot for date: 20221216
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221216_south.png
# Processing scatter plot for date: 20221217
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221217_south.png
# Processing scatter plot for date: 20221218
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221218_south.png
# Processing scatter plot for date: 20221219
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221219_south.png
# Processing scatter plot for date: 20221220
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221220_south.png
# Processing scatter plot for date: 20221221
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221221_south.png
# Processing scatter plot for date: 20221222
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221222_south.png
# Processing scatter plot for date: 20221223
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221223_south.png
# Processing scatter plot for date: 20221224
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221224_south.png
# Processing scatter plot for date: 20221225
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221225_south.png
# Processing scatter plot for date: 20221226
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221226_south.png
# Processing scatter plot for date: 20221227
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221227_south.png
# Processing scatter plot for date: 20221228
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221228_south.png
# Processing scatter plot for date: 20221229
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221229_south.png
# Processing scatter plot for date: 20221230
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221230_south.png
# Processing scatter plot for date: 20221231
# Saved scatter plot: D:\zmh\icecon25000_data\NISE\2_scatter_plots\scatter_comparison_20221231_south.png

# %% [markdown]
# ## 偏差对比

# %%
import numpy as np
import xarray as xr
import os
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
import pandas as pd 

plt.rcParams['font.sans-serif'] = ['SimHei']

def calculate_metrics(reference, corrected, original):
    """
    计算均方根误差（RMSE）、偏差（Bias） 和相关系数（CC）
    """
    # 有效数据掩模
    mask = ~np.isnan(reference) & ~np.isnan(corrected) & ~np.isnan(original)
    ref = reference[mask]
    corr = corrected[mask]
    orig = original[mask]
    
    # 计算 RMSE、Bias 和相关系数
    rmse_corrected = np.sqrt(mean_squared_error(ref, corr))
    rmse_original = np.sqrt(mean_squared_error(ref, orig))
    bias_corrected = np.mean(corr - ref)
    bias_original = np.mean(orig - ref)
    cc_corrected, _ = pearsonr(ref, corr)
    cc_original, _ = pearsonr(ref, orig)
    
    return {
        'RMSE (Corrected)': rmse_corrected,
        'RMSE (Original)': rmse_original,
        'Bias (Corrected)': bias_corrected,
        'Bias (Original)': bias_original,
        'CC (Corrected)': cc_corrected,
        'CC (Original)': cc_original
    }

def compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date):
    """
    比较PDF订正后的结果和原始数据与参考数据之间的差异
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)
    results = []
    
    for current_date in date_range:
        date_str = current_date.strftime('%Y%m%d')
        print(f"Processing date: {date_str}")
        
        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_north_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"NISE_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        original_file = os.path.join(original_dir, f"NISE_north_icecon_25000_{date_str}.nc")
        
        if not all(map(os.path.exists, [ref_file, corrected_file, original_file])):
            print(f"Skipping {date_str}, missing file.")
            continue
        
        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_north_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        original_data = xr.open_dataset(original_file)['NISE_north_icecon'].values
        
        # 计算指标
        metrics = calculate_metrics(ref_data, corrected_data, original_data)
        metrics['Date'] = date_str
        results.append(metrics)
    
    # 保存结果为CSV文件
    results_df = pd.DataFrame(results)
    output_file = os.path.join(output_dir, 'comparison_metrics_north_NISE.csv')
    results_df.to_csv(output_file, index=False)
    print(f"Saved metrics to {output_file}")
    

if __name__ == "__main__":
    # 参数设置
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\north"
    corrected_dir = r"D:\zmh\icecon25000_data\NISE\1_PDFcorrected\north"
    original_dir = r"D:\zmh\icecon25000_data\NISE\0_pre_com\north"
    output_dir = r"D:\zmh\icecon25000_data\NISE\3_bias"
    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    
    compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing date: 20220101
# Skipping 20220101, missing file.
# Processing date: 20220102
# Skipping 20220102, missing file.
# Processing date: 20220103
# Skipping 20220103, missing file.
# Processing date: 20220104
# Skipping 20220104, missing file.
# Processing date: 20220105
# Skipping 20220105, missing file.
# Processing date: 20220106
# Skipping 20220106, missing file.
# Processing date: 20220107
# Skipping 20220107, missing file.
# Processing date: 20220108
# Skipping 20220108, missing file.
# Processing date: 20220109
# Skipping 20220109, missing file.
# Processing date: 20220110
# Skipping 20220110, missing file.
# Processing date: 20220111
# Skipping 20220111, missing file.
# Processing date: 20220112
# Skipping 20220112, missing file.
# Processing date: 20220113
# Skipping 20220113, missing file.
# Processing date: 20220114
# Skipping 20220114, missing file.
# Processing date: 20220115
# Skipping 20220115, missing file.
# Processing date: 20220116
# Skipping 20220116, missing file.
# Processing date: 20220117
# Skipping 20220117, missing file.
# Processing date: 20220118
# Skipping 20220118, missing file.
# Processing date: 20220119
# Skipping 20220119, missing file.
# Processing date: 20220120
# Skipping 20220120, missing file.
# Processing date: 20220121
# Skipping 20220121, missing file.
# Processing date: 20220122
# Skipping 20220122, missing file.
# Processing date: 20220123
# Skipping 20220123, missing file.
# Processing date: 20220124
# Skipping 20220124, missing file.
# Processing date: 20220125
# Skipping 20220125, missing file.
# Processing date: 20220126
# Skipping 20220126, missing file.
# Processing date: 20220127
# Skipping 20220127, missing file.
# Processing date: 20220128
# Skipping 20220128, missing file.
# Processing date: 20220129
# Skipping 20220129, missing file.
# Processing date: 20220130
# Skipping 20220130, missing file.
# Processing date: 20220131
# Skipping 20220131, missing file.
# Processing date: 20220201
# Skipping 20220201, missing file.
# Processing date: 20220202
# Skipping 20220202, missing file.
# Processing date: 20220203
# Skipping 20220203, missing file.
# Processing date: 20220204
# Skipping 20220204, missing file.
# Processing date: 20220205
# Skipping 20220205, missing file.
# Processing date: 20220206
# Skipping 20220206, missing file.
# Processing date: 20220207
# Skipping 20220207, missing file.
# Processing date: 20220208
# Skipping 20220208, missing file.
# Processing date: 20220209
# Skipping 20220209, missing file.
# Processing date: 20220210
# Skipping 20220210, missing file.
# Processing date: 20220211
# Skipping 20220211, missing file.
# Processing date: 20220212
# Skipping 20220212, missing file.
# Processing date: 20220213
# Skipping 20220213, missing file.
# Processing date: 20220214
# Skipping 20220214, missing file.
# Processing date: 20220215
# Skipping 20220215, missing file.
# Processing date: 20220216
# Skipping 20220216, missing file.
# Processing date: 20220217
# Skipping 20220217, missing file.
# Processing date: 20220218
# Skipping 20220218, missing file.
# Processing date: 20220219
# Processing date: 20220220
# Processing date: 20220221
# Processing date: 20220222
# Processing date: 20220223
# Processing date: 20220224
# Processing date: 20220225
# Processing date: 20220226
# Processing date: 20220227
# Processing date: 20220228
# Processing date: 20220301
# Processing date: 20220302
# Processing date: 20220303
# Processing date: 20220304
# Processing date: 20220305
# Processing date: 20220306
# Processing date: 20220307
# Processing date: 20220308
# Processing date: 20220309
# Processing date: 20220310
# Processing date: 20220311
# Processing date: 20220312
# Processing date: 20220313
# Processing date: 20220314
# Processing date: 20220315
# Processing date: 20220316
# Processing date: 20220317
# Processing date: 20220318
# Processing date: 20220319
# Processing date: 20220320
# Processing date: 20220321
# Processing date: 20220322
# Processing date: 20220323
# Processing date: 20220324
# Processing date: 20220325
# Processing date: 20220326
# Processing date: 20220327
# Processing date: 20220328
# Processing date: 20220329
# Processing date: 20220330
# Processing date: 20220331
# Processing date: 20220401
# Processing date: 20220402
# Processing date: 20220403
# Processing date: 20220404
# Processing date: 20220405
# Processing date: 20220406
# Processing date: 20220407
# Processing date: 20220408
# Processing date: 20220409
# Processing date: 20220410
# Processing date: 20220411
# Processing date: 20220412
# Processing date: 20220413
# Processing date: 20220414
# Processing date: 20220415
# Processing date: 20220416
# Processing date: 20220417
# Processing date: 20220418
# Processing date: 20220419
# Processing date: 20220420
# Processing date: 20220421
# Processing date: 20220422
# Processing date: 20220423
# Processing date: 20220424
# Processing date: 20220425
# Processing date: 20220426
# Processing date: 20220427
# Processing date: 20220428
# Processing date: 20220429
# Processing date: 20220430
# Processing date: 20220501
# Processing date: 20220502
# Processing date: 20220503
# Processing date: 20220504
# Processing date: 20220505
# Processing date: 20220506
# Processing date: 20220507
# Processing date: 20220508
# Processing date: 20220509
# Processing date: 20220510
# Processing date: 20220511
# Processing date: 20220512
# Processing date: 20220513
# Processing date: 20220514
# Processing date: 20220515
# Processing date: 20220516
# Processing date: 20220517
# Processing date: 20220518
# Processing date: 20220519
# Processing date: 20220520
# Processing date: 20220521
# Processing date: 20220522
# Processing date: 20220523
# Processing date: 20220524
# Processing date: 20220525
# Processing date: 20220526
# Processing date: 20220527
# Processing date: 20220528
# Processing date: 20220529
# Processing date: 20220530
# Processing date: 20220531
# Processing date: 20220601
# Processing date: 20220602
# Processing date: 20220603
# Processing date: 20220604
# Processing date: 20220605
# Processing date: 20220606
# Processing date: 20220607
# Processing date: 20220608
# Processing date: 20220609
# Processing date: 20220610
# Processing date: 20220611
# Processing date: 20220612
# Processing date: 20220613
# Processing date: 20220614
# Processing date: 20220615
# Processing date: 20220616
# Processing date: 20220617
# Processing date: 20220618
# Processing date: 20220619
# Processing date: 20220620
# Processing date: 20220621
# Processing date: 20220622
# Processing date: 20220623
# Processing date: 20220624
# Processing date: 20220625
# Processing date: 20220626
# Processing date: 20220627
# Processing date: 20220628
# Processing date: 20220629
# Processing date: 20220630
# Processing date: 20220701
# Processing date: 20220702
# Processing date: 20220703
# Processing date: 20220704
# Processing date: 20220705
# Processing date: 20220706
# Processing date: 20220707
# Processing date: 20220708
# Processing date: 20220709
# Processing date: 20220710
# Processing date: 20220711
# Processing date: 20220712
# Processing date: 20220713
# Processing date: 20220714
# Processing date: 20220715
# Processing date: 20220716
# Processing date: 20220717
# Processing date: 20220718
# Processing date: 20220719
# Processing date: 20220720
# Processing date: 20220721
# Processing date: 20220722
# Processing date: 20220723
# Processing date: 20220724
# Processing date: 20220725
# Processing date: 20220726
# Processing date: 20220727
# Processing date: 20220728
# Processing date: 20220729
# Processing date: 20220730
# Processing date: 20220731
# Processing date: 20220801
# Processing date: 20220802
# Processing date: 20220803
# Processing date: 20220804
# Processing date: 20220805
# Processing date: 20220806
# Processing date: 20220807
# Processing date: 20220808
# Processing date: 20220809
# Processing date: 20220810
# Processing date: 20220811
# Processing date: 20220812
# Processing date: 20220813
# Processing date: 20220814
# Processing date: 20220815
# Processing date: 20220816
# Processing date: 20220817
# Processing date: 20220818
# Processing date: 20220819
# Processing date: 20220820
# Processing date: 20220821
# Processing date: 20220822
# Processing date: 20220823
# Processing date: 20220824
# Processing date: 20220825
# Processing date: 20220826
# Processing date: 20220827
# Processing date: 20220828
# Processing date: 20220829
# Processing date: 20220830
# Processing date: 20220831
# Processing date: 20220901
# Processing date: 20220902
# Processing date: 20220903
# Processing date: 20220904
# Processing date: 20220905
# Processing date: 20220906
# Processing date: 20220907
# Processing date: 20220908
# Processing date: 20220909
# Processing date: 20220910
# Processing date: 20220911
# Processing date: 20220912
# Processing date: 20220913
# Processing date: 20220914
# Processing date: 20220915
# Processing date: 20220916
# Processing date: 20220917
# Processing date: 20220918
# Processing date: 20220919
# Processing date: 20220920
# Processing date: 20220921
# Processing date: 20220922
# Processing date: 20220923
# Processing date: 20220924
# Processing date: 20220925
# Processing date: 20220926
# Processing date: 20220927
# Processing date: 20220928
# Processing date: 20220929
# Processing date: 20220930
# Processing date: 20221001
# Processing date: 20221002
# Processing date: 20221003
# Processing date: 20221004
# Processing date: 20221005
# Processing date: 20221006
# Processing date: 20221007
# Processing date: 20221008
# Processing date: 20221009
# Processing date: 20221010
# Processing date: 20221011
# Processing date: 20221012
# Processing date: 20221013
# Processing date: 20221014
# Processing date: 20221015
# Processing date: 20221016
# Processing date: 20221017
# Processing date: 20221018
# Processing date: 20221019
# Processing date: 20221020
# Processing date: 20221021
# Processing date: 20221022
# Processing date: 20221023
# Processing date: 20221024
# Processing date: 20221025
# Processing date: 20221026
# Processing date: 20221027
# Processing date: 20221028
# Processing date: 20221029
# Processing date: 20221030
# Processing date: 20221031
# Processing date: 20221101
# Processing date: 20221102
# Processing date: 20221103
# Processing date: 20221104
# Processing date: 20221105
# Processing date: 20221106
# Processing date: 20221107
# Processing date: 20221108
# Processing date: 20221109
# Processing date: 20221110
# Skipping 20221110, missing file.
# Processing date: 20221111
# Processing date: 20221112
# Processing date: 20221113
# Processing date: 20221114
# Processing date: 20221115
# Processing date: 20221116
# Processing date: 20221117
# Processing date: 20221118
# Processing date: 20221119
# Processing date: 20221120
# Processing date: 20221121
# Processing date: 20221122
# Processing date: 20221123
# Processing date: 20221124
# Processing date: 20221125
# Processing date: 20221126
# Processing date: 20221127
# Processing date: 20221128
# Processing date: 20221129
# Processing date: 20221130
# Processing date: 20221201
# Processing date: 20221202
# Processing date: 20221203
# Processing date: 20221204
# Processing date: 20221205
# Processing date: 20221206
# Processing date: 20221207
# Processing date: 20221208
# Processing date: 20221209
# Processing date: 20221210
# Processing date: 20221211
# Processing date: 20221212
# Processing date: 20221213
# Processing date: 20221214
# Processing date: 20221215
# Processing date: 20221216
# Processing date: 20221217
# Processing date: 20221218
# Processing date: 20221219
# Processing date: 20221220
# Processing date: 20221221
# Processing date: 20221222
# Processing date: 20221223
# Processing date: 20221224
# Processing date: 20221225
# Processing date: 20221226
# Processing date: 20221227
# Processing date: 20221228
# Processing date: 20221229
# Processing date: 20221230
# Processing date: 20221231
# Saved metrics to D:\zmh\icecon25000_data\NISE\3_bias\comparison_metrics_north_NISE.csv

# %%
import numpy as np
import xarray as xr
import os
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
import pandas as pd 

plt.rcParams['font.sans-serif'] = ['SimHei']

def calculate_metrics(reference, corrected, original):
    """
    计算均方根误差（RMSE）、偏差（Bias） 和相关系数（CC）
    """
    # 有效数据掩模
    mask = ~np.isnan(reference) & ~np.isnan(corrected) & ~np.isnan(original)
    ref = reference[mask]
    corr = corrected[mask]
    orig = original[mask]
    
    # 计算 RMSE、Bias 和相关系数
    rmse_corrected = np.sqrt(mean_squared_error(ref, corr))
    rmse_original = np.sqrt(mean_squared_error(ref, orig))
    bias_corrected = np.mean(corr - ref)
    bias_original = np.mean(orig - ref)
    cc_corrected, _ = pearsonr(ref, corr)
    cc_original, _ = pearsonr(ref, orig)
    
    return {
        'RMSE (Corrected)': rmse_corrected,
        'RMSE (Original)': rmse_original,
        'Bias (Corrected)': bias_corrected,
        'Bias (Original)': bias_original,
        'CC (Corrected)': cc_corrected,
        'CC (Original)': cc_original
    }

def compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date):
    """
    比较PDF订正后的结果和原始数据与参考数据之间的差异
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)
    results = []
    
    for current_date in date_range:
        date_str = current_date.strftime('%Y%m%d')
        print(f"Processing date: {date_str}")
        
        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_south_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"NISE_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        original_file = os.path.join(original_dir, f"NISE_south_icecon_25000_{date_str}.nc")
        
        if not all(map(os.path.exists, [ref_file, corrected_file, original_file])):
            print(f"Skipping {date_str}, missing file.")
            continue
        
        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_south_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        original_data = xr.open_dataset(original_file)['NISE_south_icecon'].values
        
        # 计算指标
        metrics = calculate_metrics(ref_data, corrected_data, original_data)
        metrics['Date'] = date_str
        results.append(metrics)
    
    # 保存结果为CSV文件
    results_df = pd.DataFrame(results)
    output_file = os.path.join(output_dir, 'comparison_metrics_south_NISE.csv')
    results_df.to_csv(output_file, index=False)
    print(f"Saved metrics to {output_file}")
    

if __name__ == "__main__":
    # 参数设置
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\south"
    corrected_dir = r"D:\zmh\icecon25000_data\NISE\1_PDFcorrected\south"
    original_dir = r"D:\zmh\icecon25000_data\NISE\0_pre_com\south"
    output_dir = r"D:\zmh\icecon25000_data\NISE\3_bias"
    hemisphere = "south"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    
    compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing date: 20220101
# Processing date: 20220102
# Processing date: 20220103
# Processing date: 20220104
# Processing date: 20220105
# Processing date: 20220106
# Processing date: 20220107
# Processing date: 20220108
# Processing date: 20220109
# Processing date: 20220110
# Processing date: 20220111
# Processing date: 20220112
# Processing date: 20220113
# Processing date: 20220114
# Processing date: 20220115
# Processing date: 20220116
# Processing date: 20220117
# Processing date: 20220118
# Processing date: 20220119
# Processing date: 20220120
# Processing date: 20220121
# Processing date: 20220122
# Processing date: 20220123
# Processing date: 20220124
# Processing date: 20220125
# Processing date: 20220126
# Processing date: 20220127
# Processing date: 20220128
# Processing date: 20220129
# Processing date: 20220130
# Processing date: 20220131
# Processing date: 20220201
# Processing date: 20220202
# Processing date: 20220203
# Processing date: 20220204
# Processing date: 20220205
# Processing date: 20220206
# Processing date: 20220207
# Processing date: 20220208
# Processing date: 20220209
# Processing date: 20220210
# Processing date: 20220211
# Processing date: 20220212
# Processing date: 20220213
# Processing date: 20220214
# Processing date: 20220215
# Processing date: 20220216
# Processing date: 20220217
# Processing date: 20220218
# Processing date: 20220219
# Processing date: 20220220
# Processing date: 20220221
# Processing date: 20220222
# Processing date: 20220223
# Processing date: 20220224
# Processing date: 20220225
# Processing date: 20220226
# Processing date: 20220227
# Processing date: 20220228
# Processing date: 20220301
# Processing date: 20220302
# Processing date: 20220303
# Processing date: 20220304
# Processing date: 20220305
# Processing date: 20220306
# Processing date: 20220307
# Processing date: 20220308
# Processing date: 20220309
# Processing date: 20220310
# Processing date: 20220311
# Processing date: 20220312
# Processing date: 20220313
# Processing date: 20220314
# Processing date: 20220315
# Processing date: 20220316
# Processing date: 20220317
# Processing date: 20220318
# Processing date: 20220319
# Processing date: 20220320
# Processing date: 20220321
# Processing date: 20220322
# Processing date: 20220323
# Processing date: 20220324
# Processing date: 20220325
# Processing date: 20220326
# Processing date: 20220327
# Processing date: 20220328
# Processing date: 20220329
# Processing date: 20220330
# Processing date: 20220331
# Processing date: 20220401
# Processing date: 20220402
# Processing date: 20220403
# Processing date: 20220404
# Processing date: 20220405
# Processing date: 20220406
# Processing date: 20220407
# Processing date: 20220408
# Processing date: 20220409
# Processing date: 20220410
# Processing date: 20220411
# Processing date: 20220412
# Processing date: 20220413
# Processing date: 20220414
# Processing date: 20220415
# Processing date: 20220416
# Processing date: 20220417
# Processing date: 20220418
# Processing date: 20220419
# Processing date: 20220420
# Processing date: 20220421
# Processing date: 20220422
# Processing date: 20220423
# Processing date: 20220424
# Processing date: 20220425
# Processing date: 20220426
# Processing date: 20220427
# Processing date: 20220428
# Processing date: 20220429
# Processing date: 20220430
# Processing date: 20220501
# Processing date: 20220502
# Processing date: 20220503
# Processing date: 20220504
# Processing date: 20220505
# Processing date: 20220506
# Processing date: 20220507
# Processing date: 20220508
# Processing date: 20220509
# Processing date: 20220510
# Processing date: 20220511
# Processing date: 20220512
# Processing date: 20220513
# Processing date: 20220514
# Processing date: 20220515
# Processing date: 20220516
# Processing date: 20220517
# Processing date: 20220518
# Processing date: 20220519
# Processing date: 20220520
# Processing date: 20220521
# Processing date: 20220522
# Processing date: 20220523
# Processing date: 20220524
# Processing date: 20220525
# Processing date: 20220526
# Processing date: 20220527
# Processing date: 20220528
# Processing date: 20220529
# Processing date: 20220530
# Processing date: 20220531
# Processing date: 20220601
# Processing date: 20220602
# Processing date: 20220603
# Processing date: 20220604
# Processing date: 20220605
# Processing date: 20220606
# Processing date: 20220607
# Processing date: 20220608
# Processing date: 20220609
# Processing date: 20220610
# Processing date: 20220611
# Processing date: 20220612
# Processing date: 20220613
# Processing date: 20220614
# Processing date: 20220615
# Processing date: 20220616
# Processing date: 20220617
# Processing date: 20220618
# Processing date: 20220619
# Processing date: 20220620
# Processing date: 20220621
# Processing date: 20220622
# Processing date: 20220623
# Processing date: 20220624
# Processing date: 20220625
# Processing date: 20220626
# Processing date: 20220627
# Processing date: 20220628
# Processing date: 20220629
# Processing date: 20220630
# Processing date: 20220701
# Processing date: 20220702
# Processing date: 20220703
# Processing date: 20220704
# Processing date: 20220705
# Processing date: 20220706
# Processing date: 20220707
# Processing date: 20220708
# Processing date: 20220709
# Processing date: 20220710
# Processing date: 20220711
# Processing date: 20220712
# Processing date: 20220713
# Processing date: 20220714
# Processing date: 20220715
# Processing date: 20220716
# Processing date: 20220717
# Processing date: 20220718
# Processing date: 20220719
# Processing date: 20220720
# Processing date: 20220721
# Processing date: 20220722
# Processing date: 20220723
# Processing date: 20220724
# Processing date: 20220725
# Processing date: 20220726
# Processing date: 20220727
# Processing date: 20220728
# Processing date: 20220729
# Processing date: 20220730
# Processing date: 20220731
# Processing date: 20220801
# Processing date: 20220802
# Processing date: 20220803
# Processing date: 20220804
# Processing date: 20220805
# Processing date: 20220806
# Processing date: 20220807
# Processing date: 20220808
# Processing date: 20220809
# Processing date: 20220810
# Processing date: 20220811
# Processing date: 20220812
# Processing date: 20220813
# Processing date: 20220814
# Processing date: 20220815
# Processing date: 20220816
# Processing date: 20220817
# Processing date: 20220818
# Processing date: 20220819
# Processing date: 20220820
# Processing date: 20220821
# Processing date: 20220822
# Processing date: 20220823
# Processing date: 20220824
# Processing date: 20220825
# Processing date: 20220826
# Processing date: 20220827
# Processing date: 20220828
# Processing date: 20220829
# Processing date: 20220830
# Processing date: 20220831
# Processing date: 20220901
# Processing date: 20220902
# Processing date: 20220903
# Processing date: 20220904
# Processing date: 20220905
# Processing date: 20220906
# Processing date: 20220907
# Processing date: 20220908
# Processing date: 20220909
# Processing date: 20220910
# Processing date: 20220911
# Processing date: 20220912
# Processing date: 20220913
# Processing date: 20220914
# Processing date: 20220915
# Processing date: 20220916
# Processing date: 20220917
# Processing date: 20220918
# Processing date: 20220919
# Processing date: 20220920
# Processing date: 20220921
# Processing date: 20220922
# Processing date: 20220923
# Processing date: 20220924
# Processing date: 20220925
# Processing date: 20220926
# Processing date: 20220927
# Processing date: 20220928
# Processing date: 20220929
# Processing date: 20220930
# Processing date: 20221001
# Processing date: 20221002
# Processing date: 20221003
# Processing date: 20221004
# Processing date: 20221005
# Processing date: 20221006
# Processing date: 20221007
# Processing date: 20221008
# Processing date: 20221009
# Processing date: 20221010
# Processing date: 20221011
# Processing date: 20221012
# Processing date: 20221013
# Processing date: 20221014
# Processing date: 20221015
# Processing date: 20221016
# Processing date: 20221017
# Processing date: 20221018
# Processing date: 20221019
# Processing date: 20221020
# Processing date: 20221021
# Processing date: 20221022
# Processing date: 20221023
# Processing date: 20221024
# Processing date: 20221025
# Processing date: 20221026
# Processing date: 20221027
# Processing date: 20221028
# Processing date: 20221029
# Processing date: 20221030
# Processing date: 20221031
# Processing date: 20221101
# Processing date: 20221102
# Processing date: 20221103
# Processing date: 20221104
# Processing date: 20221105
# Processing date: 20221106
# Processing date: 20221107
# Processing date: 20221108
# Processing date: 20221109
# Processing date: 20221110
# Skipping 20221110, missing file.
# Processing date: 20221111
# Processing date: 20221112
# Processing date: 20221113
# Processing date: 20221114
# Processing date: 20221115
# Processing date: 20221116
# Processing date: 20221117
# Processing date: 20221118
# Processing date: 20221119
# Processing date: 20221120
# Processing date: 20221121
# Processing date: 20221122
# Processing date: 20221123
# Processing date: 20221124
# Processing date: 20221125
# Processing date: 20221126
# Processing date: 20221127
# Processing date: 20221128
# Processing date: 20221129
# Processing date: 20221130
# Processing date: 20221201
# Processing date: 20221202
# Processing date: 20221203
# Processing date: 20221204
# Processing date: 20221205
# Processing date: 20221206
# Processing date: 20221207
# Processing date: 20221208
# Processing date: 20221209
# Processing date: 20221210
# Processing date: 20221211
# Processing date: 20221212
# Processing date: 20221213
# Processing date: 20221214
# Processing date: 20221215
# Processing date: 20221216
# Processing date: 20221217
# Processing date: 20221218
# Processing date: 20221219
# Processing date: 20221220
# Processing date: 20221221
# Processing date: 20221222
# Processing date: 20221223
# Processing date: 20221224
# Processing date: 20221225
# Processing date: 20221226
# Processing date: 20221227
# Processing date: 20221228
# Processing date: 20221229
# Processing date: 20221230
# Processing date: 20221231
# Saved metrics to D:\zmh\icecon25000_data\NISE\3_bias\comparison_metrics_south_NISE.csv

# %% [markdown]
# # OISST

# %% [markdown]
# ## 散点图

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

plt.rcParams['font.sans-serif'] = ['SimHei']

def plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date, output_dir):
    """
    绘制订正前、订正后的非参考数据与参考数据的散点图
    :param non_ref_data: 订正前的非参考数据 (2D numpy array)
    :param corrected_data: 订正后的非参考数据 (2D numpy array)
    :param ref_data: 参考数据 (2D numpy array)
    :param date: 当前日期 (str)
    :param output_dir: 输出散点图的保存目录
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 平铺数组，去除 NaN 数据
    mask = (~np.isnan(non_ref_data)) & (~np.isnan(ref_data))
    x_non_ref = non_ref_data[mask]
    x_corrected = corrected_data[mask]
    y_ref = ref_data[mask]
    
    # 绘制订正前的散点图
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_non_ref, y_ref, s=2, alpha=0.5, color='blue')
    plt.plot([90, 100], [90, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(90, 100)
    plt.ylim(90, 100)
   
    plt.xlabel("非参考数据 (订正前)")
    plt.ylabel("参考数据")
    plt.title(f"订正前 ({date})")
    
    # 绘制订正后的散点图
    plt.subplot(1, 2, 2)
    plt.scatter(x_corrected, y_ref, s=2, alpha=0.5, color='red')
    plt.plot([90, 100], [90, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(90, 100)
    plt.ylim(90, 100)
    plt.xlabel("非参考数据 (订正后)")
    plt.ylabel("参考数据")
    plt.title(f"订正后 ({date})")
    
    # 保存散点图
    plt.tight_layout()
    output_file = os.path.join(output_dir, f"scatter_comparison_{date}_north.png")
    plt.savefig(output_file, dpi=100)
    plt.close()
    print(f"Saved scatter plot: {output_file}")

def generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date):
    """
    生成非参考数据的订正前后与参考数据的散点图
    :param input_dir: 订正前非参考数据目录
    :param corrected_dir: 订正后数据目录
    :param reference_dir: 参考数据目录
    :param output_dir: 输出散点图的保存目录
    :param hemisphere: 'north' 或 'south'
    :param start_date: 开始日期 (str)
    :param end_date: 结束日期 (str)
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        date_str = date.strftime('%Y%m%d')
        print(f"Processing scatter plot for date: {date_str}")

        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_{hemisphere}_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"OISST_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        non_ref_file = os.path.join(input_dir, f"OISST_{hemisphere}_icecon_25000_{date_str}.nc")

        # 检查文件是否存在
        if not all(os.path.exists(f) for f in [ref_file, corrected_file, non_ref_file]):
            print(f"Missing file for date {date_str}, skipping...")
            continue

        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_north_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        non_ref_data = xr.open_dataset(non_ref_file)['OISST_north_icecon'].values

        # 绘制散点图
        plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date_str, output_dir)

if __name__ == "__main__":
    import pandas as pd

    # 文件目录路径
    input_dir = r"D:\zmh\icecon25000_data\OISST\0_pre_com\north"
    corrected_dir = r"D:\zmh\icecon25000_data\OISST\1_PDFcorrected\north"
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\north"
    output_dir = r"D:\zmh\icecon25000_data\OISST\2_scatter_plots"
    # 若output_dir不存在，创建output_dir
    os.makedirs(output_dir, exist_ok=True)

    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-03-31"

    generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing scatter plot for date: 20220101
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220101_north.png
# Processing scatter plot for date: 20220102
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220102_north.png
# Processing scatter plot for date: 20220103
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220103_north.png
# Processing scatter plot for date: 20220104
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220104_north.png
# Processing scatter plot for date: 20220105
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220105_north.png
# Processing scatter plot for date: 20220106
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220106_north.png
# Processing scatter plot for date: 20220107
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220107_north.png
# Processing scatter plot for date: 20220108
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220108_north.png
# Processing scatter plot for date: 20220109
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220109_north.png
# Processing scatter plot for date: 20220110
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220110_north.png
# Processing scatter plot for date: 20220111
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220111_north.png
# Processing scatter plot for date: 20220112
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220112_north.png
# Processing scatter plot for date: 20220113
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220113_north.png
# Processing scatter plot for date: 20220114
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220114_north.png
# Processing scatter plot for date: 20220115
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220115_north.png
# Processing scatter plot for date: 20220116
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220116_north.png
# Processing scatter plot for date: 20220117
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220117_north.png
# Processing scatter plot for date: 20220118
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220118_north.png
# Processing scatter plot for date: 20220119
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220119_north.png
# Processing scatter plot for date: 20220120
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220120_north.png
# Processing scatter plot for date: 20220121
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220121_north.png
# Processing scatter plot for date: 20220122
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220122_north.png
# Processing scatter plot for date: 20220123
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220123_north.png
# Processing scatter plot for date: 20220124
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220124_north.png
# Processing scatter plot for date: 20220125
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220125_north.png
# Processing scatter plot for date: 20220126
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220126_north.png
# Processing scatter plot for date: 20220127
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220127_north.png
# Processing scatter plot for date: 20220128
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220128_north.png
# Processing scatter plot for date: 20220129
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220129_north.png
# Processing scatter plot for date: 20220130
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220130_north.png
# Processing scatter plot for date: 20220131
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220131_north.png
# Processing scatter plot for date: 20220201
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220201_north.png
# Processing scatter plot for date: 20220202
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220202_north.png
# Processing scatter plot for date: 20220203
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220203_north.png
# Processing scatter plot for date: 20220204
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220204_north.png
# Processing scatter plot for date: 20220205
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220205_north.png
# Processing scatter plot for date: 20220206
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220206_north.png
# Processing scatter plot for date: 20220207
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220207_north.png
# Processing scatter plot for date: 20220208
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220208_north.png
# Processing scatter plot for date: 20220209
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220209_north.png
# Processing scatter plot for date: 20220210
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220210_north.png
# Processing scatter plot for date: 20220211
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220211_north.png
# Processing scatter plot for date: 20220212
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220212_north.png
# Processing scatter plot for date: 20220213
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220213_north.png
# Processing scatter plot for date: 20220214
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220214_north.png
# Processing scatter plot for date: 20220215
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220215_north.png
# Processing scatter plot for date: 20220216
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220216_north.png
# Processing scatter plot for date: 20220217
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220217_north.png
# Processing scatter plot for date: 20220218
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220218_north.png
# Processing scatter plot for date: 20220219
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220219_north.png
# Processing scatter plot for date: 20220220
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220220_north.png
# Processing scatter plot for date: 20220221
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220221_north.png
# Processing scatter plot for date: 20220222
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220222_north.png
# Processing scatter plot for date: 20220223
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220223_north.png
# Processing scatter plot for date: 20220224
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220224_north.png
# Processing scatter plot for date: 20220225
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220225_north.png
# Processing scatter plot for date: 20220226
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220226_north.png
# Processing scatter plot for date: 20220227
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220227_north.png
# Processing scatter plot for date: 20220228
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220228_north.png
# Processing scatter plot for date: 20220301
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220301_north.png
# Processing scatter plot for date: 20220302
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220302_north.png
# Processing scatter plot for date: 20220303
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220303_north.png
# Processing scatter plot for date: 20220304
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220304_north.png
# Processing scatter plot for date: 20220305
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220305_north.png
# Processing scatter plot for date: 20220306
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220306_north.png
# Processing scatter plot for date: 20220307
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220307_north.png
# Processing scatter plot for date: 20220308
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220308_north.png
# Processing scatter plot for date: 20220309
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220309_north.png
# Processing scatter plot for date: 20220310
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220310_north.png
# Processing scatter plot for date: 20220311
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220311_north.png
# Processing scatter plot for date: 20220312
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220312_north.png
# Processing scatter plot for date: 20220313
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220313_north.png
# Processing scatter plot for date: 20220314
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220314_north.png
# Processing scatter plot for date: 20220315
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220315_north.png
# Processing scatter plot for date: 20220316
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220316_north.png
# Processing scatter plot for date: 20220317
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220317_north.png
# Processing scatter plot for date: 20220318
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220318_north.png
# Processing scatter plot for date: 20220319
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220319_north.png
# Processing scatter plot for date: 20220320
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220320_north.png
# Processing scatter plot for date: 20220321
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220321_north.png
# Processing scatter plot for date: 20220322
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220322_north.png
# Processing scatter plot for date: 20220323
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220323_north.png
# Processing scatter plot for date: 20220324
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220324_north.png
# Processing scatter plot for date: 20220325
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220325_north.png
# Processing scatter plot for date: 20220326
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220326_north.png
# Processing scatter plot for date: 20220327
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220327_north.png
# Processing scatter plot for date: 20220328
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220328_north.png
# Processing scatter plot for date: 20220329
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220329_north.png
# Processing scatter plot for date: 20220330
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220330_north.png
# Processing scatter plot for date: 20220331
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220331_north.png

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

plt.rcParams['font.sans-serif'] = ['SimHei']

def plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date, output_dir):
    """
    绘制订正前、订正后的非参考数据与参考数据的散点图
    :param non_ref_data: 订正前的非参考数据 (2D numpy array)
    :param corrected_data: 订正后的非参考数据 (2D numpy array)
    :param ref_data: 参考数据 (2D numpy array)
    :param date: 当前日期 (str)
    :param output_dir: 输出散点图的保存目录
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 平铺数组，去除 NaN 数据
    mask = (~np.isnan(non_ref_data)) & (~np.isnan(ref_data))
    x_non_ref = non_ref_data[mask]
    x_corrected = corrected_data[mask]
    y_ref = ref_data[mask]
    
    # 绘制订正前的散点图
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_non_ref, y_ref, s=2, alpha=0.5, color='blue')
    plt.plot([0, 100], [0, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 100)
    plt.ylim(0, 100)
   
    plt.xlabel("非参考数据 (订正前)")
    plt.ylabel("参考数据")
    plt.title(f"订正前 ({date})")
    
    # 绘制订正后的散点图
    plt.subplot(1, 2, 2)
    plt.scatter(x_corrected, y_ref, s=2, alpha=0.5, color='red')
    plt.plot([0, 100], [0, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 100)
    plt.ylim(0, 100)
    plt.xlabel("非参考数据 (订正后)")
    plt.ylabel("参考数据")
    plt.title(f"订正后 ({date})")
     
    # 保存散点图
    plt.tight_layout()
    output_file = os.path.join(output_dir, f"scatter_comparison_{date}_south.png")
    plt.savefig(output_file, dpi=100)
    plt.close()
    print(f"Saved scatter plot: {output_file}")

def generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date):
    """
    生成非参考数据的订正前后与参考数据的散点图
    :param input_dir: 订正前非参考数据目录
    :param corrected_dir: 订正后数据目录
    :param reference_dir: 参考数据目录
    :param output_dir: 输出散点图的保存目录
    :param hemisphere: 'north' 或 'south'
    :param start_date: 开始日期 (str)
    :param end_date: 结束日期 (str)
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        date_str = date.strftime('%Y%m%d')
        print(f"Processing scatter plot for date: {date_str}")

        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_{hemisphere}_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"OISST_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        non_ref_file = os.path.join(input_dir, f"OISST_{hemisphere}_icecon_25000_{date_str}.nc")

        # 检查文件是否存在
        if not all(os.path.exists(f) for f in [ref_file, corrected_file, non_ref_file]):
            print(f"Missing file for date {date_str}, skipping...")
            continue

        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_south_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        non_ref_data = xr.open_dataset(non_ref_file)['OISST_south_icecon'].values

        # 绘制散点图
        plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date_str, output_dir)

if __name__ == "__main__":
    import pandas as pd

    # 文件目录路径
    input_dir = r"D:\zmh\icecon25000_data\OISST\0_pre_com\south"
    corrected_dir = r"D:\zmh\icecon25000_data\OISST\1_PDFcorrected\south"
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\south"
    output_dir = r"D:\zmh\icecon25000_data\OISST\2_scatter_plots"
    # 若output_dir不存在，创建output_dir
    os.makedirs(output_dir, exist_ok=True)

    hemisphere = "south"
    start_date = "2022-01-01"
    end_date = "2022-03-31"

    generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing scatter plot for date: 20220101
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220101_south.png
# Processing scatter plot for date: 20220102
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220102_south.png
# Processing scatter plot for date: 20220103
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220103_south.png
# Processing scatter plot for date: 20220104
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220104_south.png
# Processing scatter plot for date: 20220105
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220105_south.png
# Processing scatter plot for date: 20220106
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220106_south.png
# Processing scatter plot for date: 20220107
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220107_south.png
# Processing scatter plot for date: 20220108
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220108_south.png
# Processing scatter plot for date: 20220109
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220109_south.png
# Processing scatter plot for date: 20220110
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220110_south.png
# Processing scatter plot for date: 20220111
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220111_south.png
# Processing scatter plot for date: 20220112
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220112_south.png
# Processing scatter plot for date: 20220113
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220113_south.png
# Processing scatter plot for date: 20220114
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220114_south.png
# Processing scatter plot for date: 20220115
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220115_south.png
# Processing scatter plot for date: 20220116
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220116_south.png
# Processing scatter plot for date: 20220117
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220117_south.png
# Processing scatter plot for date: 20220118
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220118_south.png
# Processing scatter plot for date: 20220119
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220119_south.png
# Processing scatter plot for date: 20220120
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220120_south.png
# Processing scatter plot for date: 20220121
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220121_south.png
# Processing scatter plot for date: 20220122
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220122_south.png
# Processing scatter plot for date: 20220123
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220123_south.png
# Processing scatter plot for date: 20220124
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220124_south.png
# Processing scatter plot for date: 20220125
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220125_south.png
# Processing scatter plot for date: 20220126
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220126_south.png
# Processing scatter plot for date: 20220127
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220127_south.png
# Processing scatter plot for date: 20220128
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220128_south.png
# Processing scatter plot for date: 20220129
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220129_south.png
# Processing scatter plot for date: 20220130
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220130_south.png
# Processing scatter plot for date: 20220131
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220131_south.png
# Processing scatter plot for date: 20220201
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220201_south.png
# Processing scatter plot for date: 20220202
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220202_south.png
# Processing scatter plot for date: 20220203
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220203_south.png
# Processing scatter plot for date: 20220204
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220204_south.png
# Processing scatter plot for date: 20220205
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220205_south.png
# Processing scatter plot for date: 20220206
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220206_south.png
# Processing scatter plot for date: 20220207
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220207_south.png
# Processing scatter plot for date: 20220208
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220208_south.png
# Processing scatter plot for date: 20220209
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220209_south.png
# Processing scatter plot for date: 20220210
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220210_south.png
# Processing scatter plot for date: 20220211
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220211_south.png
# Processing scatter plot for date: 20220212
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220212_south.png
# Processing scatter plot for date: 20220213
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220213_south.png
# Processing scatter plot for date: 20220214
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220214_south.png
# Processing scatter plot for date: 20220215
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220215_south.png
# Processing scatter plot for date: 20220216
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220216_south.png
# Processing scatter plot for date: 20220217
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220217_south.png
# Processing scatter plot for date: 20220218
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220218_south.png
# Processing scatter plot for date: 20220219
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220219_south.png
# Processing scatter plot for date: 20220220
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220220_south.png
# Processing scatter plot for date: 20220221
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220221_south.png
# Processing scatter plot for date: 20220222
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220222_south.png
# Processing scatter plot for date: 20220223
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220223_south.png
# Processing scatter plot for date: 20220224
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220224_south.png
# Processing scatter plot for date: 20220225
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220225_south.png
# Processing scatter plot for date: 20220226
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220226_south.png
# Processing scatter plot for date: 20220227
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220227_south.png
# Processing scatter plot for date: 20220228
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220228_south.png
# Processing scatter plot for date: 20220301
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220301_south.png
# Processing scatter plot for date: 20220302
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220302_south.png
# Processing scatter plot for date: 20220303
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220303_south.png
# Processing scatter plot for date: 20220304
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220304_south.png
# Processing scatter plot for date: 20220305
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220305_south.png
# Processing scatter plot for date: 20220306
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220306_south.png
# Processing scatter plot for date: 20220307
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220307_south.png
# Processing scatter plot for date: 20220308
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220308_south.png
# Processing scatter plot for date: 20220309
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220309_south.png
# Processing scatter plot for date: 20220310
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220310_south.png
# Processing scatter plot for date: 20220311
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220311_south.png
# Processing scatter plot for date: 20220312
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220312_south.png
# Processing scatter plot for date: 20220313
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220313_south.png
# Processing scatter plot for date: 20220314
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220314_south.png
# Processing scatter plot for date: 20220315
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220315_south.png
# Processing scatter plot for date: 20220316
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220316_south.png
# Processing scatter plot for date: 20220317
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220317_south.png
# Processing scatter plot for date: 20220318
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220318_south.png
# Processing scatter plot for date: 20220319
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220319_south.png
# Processing scatter plot for date: 20220320
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220320_south.png
# Processing scatter plot for date: 20220321
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220321_south.png
# Processing scatter plot for date: 20220322
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220322_south.png
# Processing scatter plot for date: 20220323
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220323_south.png
# Processing scatter plot for date: 20220324
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220324_south.png
# Processing scatter plot for date: 20220325
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220325_south.png
# Processing scatter plot for date: 20220326
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220326_south.png
# Processing scatter plot for date: 20220327
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220327_south.png
# Processing scatter plot for date: 20220328
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220328_south.png
# Processing scatter plot for date: 20220329
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220329_south.png
# Processing scatter plot for date: 20220330
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220330_south.png
# Processing scatter plot for date: 20220331
# Saved scatter plot: D:\zmh\icecon25000_data\OISST\2_scatter_plots\scatter_comparison_20220331_south.png

# %% [markdown]
# ## 偏差对比

# %%
import numpy as np
import xarray as xr
import os
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
import pandas as pd 

plt.rcParams['font.sans-serif'] = ['SimHei']

def calculate_metrics(reference, corrected, original):
    """
    计算均方根误差（RMSE）、偏差（Bias） 和相关系数（CC）
    """
    # 有效数据掩模
    mask = ~np.isnan(reference) & ~np.isnan(corrected) & ~np.isnan(original)
    ref = reference[mask]
    corr = corrected[mask]
    orig = original[mask]
    
    # 计算 RMSE、Bias 和相关系数
    rmse_corrected = np.sqrt(mean_squared_error(ref, corr))
    rmse_original = np.sqrt(mean_squared_error(ref, orig))
    bias_corrected = np.mean(corr - ref)
    bias_original = np.mean(orig - ref)
    cc_corrected, _ = pearsonr(ref, corr)
    cc_original, _ = pearsonr(ref, orig)
    
    return {
        'RMSE (Corrected)': rmse_corrected,
        'RMSE (Original)': rmse_original,
        'Bias (Corrected)': bias_corrected,
        'Bias (Original)': bias_original,
        'CC (Corrected)': cc_corrected,
        'CC (Original)': cc_original
    }

def compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date):
    """
    比较PDF订正后的结果和原始数据与参考数据之间的差异
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)
    results = []
    
    for current_date in date_range:
        date_str = current_date.strftime('%Y%m%d')
        print(f"Processing date: {date_str}")
        
        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_north_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"OISST_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        original_file = os.path.join(original_dir, f"OISST_north_icecon_25000_{date_str}.nc")
        
        if not all(map(os.path.exists, [ref_file, corrected_file, original_file])):
            print(f"Skipping {date_str}, missing file.")
            continue
        
        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_north_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        original_data = xr.open_dataset(original_file)['OISST_north_icecon'].values
        
        # 计算指标
        metrics = calculate_metrics(ref_data, corrected_data, original_data)
        metrics['Date'] = date_str
        results.append(metrics)
    
    # 保存结果为CSV文件
    results_df = pd.DataFrame(results)
    output_file = os.path.join(output_dir, 'comparison_metrics_north_OISST.csv')
    results_df.to_csv(output_file, index=False)
    print(f"Saved metrics to {output_file}")
    

if __name__ == "__main__":
    # 参数设置
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\north"
    corrected_dir = r"D:\zmh\icecon25000_data\OISST\1_PDFcorrected\north"
    original_dir = r"D:\zmh\icecon25000_data\OISST\0_pre_com\north"
    output_dir = r"D:\zmh\icecon25000_data\OISST\3_bias"
    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-03-31"

    
    compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing date: 20220101
# Processing date: 20220102
# Processing date: 20220103
# Processing date: 20220104
# Processing date: 20220105
# Processing date: 20220106
# Processing date: 20220107
# Processing date: 20220108
# Processing date: 20220109
# Processing date: 20220110
# Processing date: 20220111
# Processing date: 20220112
# Processing date: 20220113
# Processing date: 20220114
# Processing date: 20220115
# Processing date: 20220116
# Processing date: 20220117
# Processing date: 20220118
# Processing date: 20220119
# Processing date: 20220120
# Processing date: 20220121
# Processing date: 20220122
# Processing date: 20220123
# Processing date: 20220124
# Processing date: 20220125
# Processing date: 20220126
# Processing date: 20220127
# Processing date: 20220128
# Processing date: 20220129
# Processing date: 20220130
# Processing date: 20220131
# Processing date: 20220201
# Processing date: 20220202
# Processing date: 20220203
# Processing date: 20220204
# Processing date: 20220205
# Processing date: 20220206
# Processing date: 20220207
# Processing date: 20220208
# Processing date: 20220209
# Processing date: 20220210
# Processing date: 20220211
# Processing date: 20220212
# Processing date: 20220213
# Processing date: 20220214
# Processing date: 20220215
# Processing date: 20220216
# Processing date: 20220217
# Processing date: 20220218
# Processing date: 20220219
# Processing date: 20220220
# Processing date: 20220221
# Processing date: 20220222
# Processing date: 20220223
# Processing date: 20220224
# Processing date: 20220225
# Processing date: 20220226
# Processing date: 20220227
# Processing date: 20220228
# Processing date: 20220301
# Processing date: 20220302
# Processing date: 20220303
# Processing date: 20220304
# Processing date: 20220305
# Processing date: 20220306
# Processing date: 20220307
# Processing date: 20220308
# Processing date: 20220309
# Processing date: 20220310
# Processing date: 20220311
# Processing date: 20220312
# Processing date: 20220313
# Processing date: 20220314
# Processing date: 20220315
# Processing date: 20220316
# Processing date: 20220317
# Processing date: 20220318
# Processing date: 20220319
# Processing date: 20220320
# Processing date: 20220321
# Processing date: 20220322
# Processing date: 20220323
# Processing date: 20220324
# Processing date: 20220325
# Processing date: 20220326
# Processing date: 20220327
# Processing date: 20220328
# Processing date: 20220329
# Processing date: 20220330
# Processing date: 20220331
# Saved metrics to D:\zmh\icecon25000_data\OISST\3_bias\comparison_metrics_north_OISST.csv

# %%
import numpy as np
import xarray as xr
import os
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
import pandas as pd 

plt.rcParams['font.sans-serif'] = ['SimHei']

def calculate_metrics(reference, corrected, original):
    """
    计算均方根误差（RMSE）、偏差（Bias） 和相关系数（CC）
    """
    # 有效数据掩模
    mask = ~np.isnan(reference) & ~np.isnan(corrected) & ~np.isnan(original)
    ref = reference[mask]
    corr = corrected[mask]
    orig = original[mask]
    
    # 计算 RMSE、Bias 和相关系数
    rmse_corrected = np.sqrt(mean_squared_error(ref, corr))
    rmse_original = np.sqrt(mean_squared_error(ref, orig))
    bias_corrected = np.mean(corr - ref)
    bias_original = np.mean(orig - ref)
    cc_corrected, _ = pearsonr(ref, corr)
    cc_original, _ = pearsonr(ref, orig)
    
    return {
        'RMSE (Corrected)': rmse_corrected,
        'RMSE (Original)': rmse_original,
        'Bias (Corrected)': bias_corrected,
        'Bias (Original)': bias_original,
        'CC (Corrected)': cc_corrected,
        'CC (Original)': cc_original
    }

def compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date):
    """
    比较PDF订正后的结果和原始数据与参考数据之间的差异
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)
    results = []
    
    for current_date in date_range:
        date_str = current_date.strftime('%Y%m%d')
        print(f"Processing date: {date_str}")
        
        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_south_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"OISST_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        original_file = os.path.join(original_dir, f"OISST_south_icecon_25000_{date_str}.nc")
        
        if not all(map(os.path.exists, [ref_file, corrected_file, original_file])):
            print(f"Skipping {date_str}, missing file.")
            continue
        
        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_south_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        original_data = xr.open_dataset(original_file)['OISST_south_icecon'].values
        
        # 计算指标
        metrics = calculate_metrics(ref_data, corrected_data, original_data)
        metrics['Date'] = date_str
        results.append(metrics)
    
    # 保存结果为CSV文件
    results_df = pd.DataFrame(results)
    output_file = os.path.join(output_dir, 'comparison_metrics_south_OISST.csv')
    results_df.to_csv(output_file, index=False)
    print(f"Saved metrics to {output_file}")
    

if __name__ == "__main__":
    # 参数设置
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\south"
    corrected_dir = r"D:\zmh\icecon25000_data\OISST\1_PDFcorrected\south"
    original_dir = r"D:\zmh\icecon25000_data\OISST\0_pre_com\south"
    output_dir = r"D:\zmh\icecon25000_data\OISST\3_bias"
    hemisphere = "south"
    start_date = "2022-01-01"
    end_date = "2022-03-31"

    
    compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing date: 20220101
# Processing date: 20220102
# Processing date: 20220103
# Processing date: 20220104
# Processing date: 20220105
# Processing date: 20220106
# Processing date: 20220107
# Processing date: 20220108
# Processing date: 20220109
# Processing date: 20220110
# Processing date: 20220111
# Processing date: 20220112
# Processing date: 20220113
# Processing date: 20220114
# Processing date: 20220115
# Processing date: 20220116
# Processing date: 20220117
# Processing date: 20220118
# Processing date: 20220119
# Processing date: 20220120
# Processing date: 20220121
# Processing date: 20220122
# Processing date: 20220123
# Processing date: 20220124
# Processing date: 20220125
# Processing date: 20220126
# Processing date: 20220127
# Processing date: 20220128
# Processing date: 20220129
# Processing date: 20220130
# Processing date: 20220131
# Processing date: 20220201
# Processing date: 20220202
# Processing date: 20220203
# Processing date: 20220204
# Processing date: 20220205
# Processing date: 20220206
# Processing date: 20220207
# Processing date: 20220208
# Processing date: 20220209
# Processing date: 20220210
# Processing date: 20220211
# Processing date: 20220212
# Processing date: 20220213
# Processing date: 20220214
# Processing date: 20220215
# Processing date: 20220216
# Processing date: 20220217
# Processing date: 20220218
# Processing date: 20220219
# Processing date: 20220220
# Processing date: 20220221
# Processing date: 20220222
# Processing date: 20220223
# Processing date: 20220224
# Processing date: 20220225
# Processing date: 20220226
# Processing date: 20220227
# Processing date: 20220228
# Processing date: 20220301
# Processing date: 20220302
# Processing date: 20220303
# Processing date: 20220304
# Processing date: 20220305
# Processing date: 20220306
# Processing date: 20220307
# Processing date: 20220308
# Processing date: 20220309
# Processing date: 20220310
# Processing date: 20220311
# Processing date: 20220312
# Processing date: 20220313
# Processing date: 20220314
# Processing date: 20220315
# Processing date: 20220316
# Processing date: 20220317
# Processing date: 20220318
# Processing date: 20220319
# Processing date: 20220320
# Processing date: 20220321
# Processing date: 20220322
# Processing date: 20220323
# Processing date: 20220324
# Processing date: 20220325
# Processing date: 20220326
# Processing date: 20220327
# Processing date: 20220328
# Processing date: 20220329
# Processing date: 20220330
# Processing date: 20220331
# Saved metrics to D:\zmh\icecon25000_data\OISST\3_bias\comparison_metrics_south_OISST.csv

# %% [markdown]
# # FY3D

# %% [markdown]
# ## 散点图

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

plt.rcParams['font.sans-serif'] = ['SimHei']

def plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date, output_dir):
    """
    绘制订正前、订正后的非参考数据与参考数据的散点图
    :param non_ref_data: 订正前的非参考数据 (2D numpy array)
    :param corrected_data: 订正后的非参考数据 (2D numpy array)
    :param ref_data: 参考数据 (2D numpy array)
    :param date: 当前日期 (str)
    :param output_dir: 输出散点图的保存目录
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 平铺数组，去除 NaN 数据
    mask = (~np.isnan(non_ref_data)) & (~np.isnan(ref_data))
    x_non_ref = non_ref_data[mask]
    x_corrected = corrected_data[mask]
    y_ref = ref_data[mask]
    
    # 绘制订正前的散点图
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_non_ref, y_ref, s=2, alpha=0.5, color='blue')
    plt.plot([90, 100], [90, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(90, 100)
    plt.ylim(90, 100)
   
    plt.xlabel("非参考数据 (订正前)")
    plt.ylabel("参考数据")
    plt.title(f"订正前 ({date})")
    
    # 绘制订正后的散点图
    plt.subplot(1, 2, 2)
    plt.scatter(x_corrected, y_ref, s=2, alpha=0.5, color='red')
    plt.plot([90, 100], [90, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(90, 100)
    plt.ylim(90, 100)
    plt.xlabel("非参考数据 (订正后)")
    plt.ylabel("参考数据")
    plt.title(f"订正后 ({date})")
    
    # 保存散点图
    plt.tight_layout()
    output_file = os.path.join(output_dir, f"scatter_comparison_{date}_north.png")
    plt.savefig(output_file, dpi=100)
    plt.close()
    print(f"Saved scatter plot: {output_file}")

def generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date):
    """
    生成非参考数据的订正前后与参考数据的散点图
    :param input_dir: 订正前非参考数据目录
    :param corrected_dir: 订正后数据目录
    :param reference_dir: 参考数据目录
    :param output_dir: 输出散点图的保存目录
    :param hemisphere: 'north' 或 'south'
    :param start_date: 开始日期 (str)
    :param end_date: 结束日期 (str)
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        date_str = date.strftime('%Y%m%d')
        print(f"Processing scatter plot for date: {date_str}")

        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_{hemisphere}_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"FY3D_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        non_ref_file = os.path.join(input_dir, f"FY3D_{hemisphere}_icecon_25000_{date_str}.nc")

        # 检查文件是否存在
        if not all(os.path.exists(f) for f in [ref_file, corrected_file, non_ref_file]):
            print(f"Missing file for date {date_str}, skipping...")
            continue

        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_north_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        non_ref_data = xr.open_dataset(non_ref_file)['FY3D_north_icecon'].values

        # 绘制散点图
        plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date_str, output_dir)

if __name__ == "__main__":
    import pandas as pd

    # 文件目录路径
    input_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\0_pre_com\north"
    corrected_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\1_PDFcorrected\north"
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\north"
    output_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots"
    # 若output_dir不存在，创建output_dir
    os.makedirs(output_dir, exist_ok=True)

    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing scatter plot for date: 20220101
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220101_north.png
# Processing scatter plot for date: 20220102
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220102_north.png
# Processing scatter plot for date: 20220103
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220103_north.png
# Processing scatter plot for date: 20220104
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220104_north.png
# Processing scatter plot for date: 20220105
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220105_north.png
# Processing scatter plot for date: 20220106
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220106_north.png
# Processing scatter plot for date: 20220107
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220107_north.png
# Processing scatter plot for date: 20220108
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220108_north.png
# Processing scatter plot for date: 20220109
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220109_north.png
# Processing scatter plot for date: 20220110
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220110_north.png
# Processing scatter plot for date: 20220111
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220111_north.png
# Processing scatter plot for date: 20220112
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220112_north.png
# Processing scatter plot for date: 20220113
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220113_north.png
# Processing scatter plot for date: 20220114
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220114_north.png
# Processing scatter plot for date: 20220115
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220115_north.png
# Processing scatter plot for date: 20220116
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220116_north.png
# Processing scatter plot for date: 20220117
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220117_north.png
# Processing scatter plot for date: 20220118
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220118_north.png
# Processing scatter plot for date: 20220119
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220119_north.png
# Processing scatter plot for date: 20220120
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220120_north.png
# Processing scatter plot for date: 20220121
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220121_north.png
# Processing scatter plot for date: 20220122
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220122_north.png
# Processing scatter plot for date: 20220123
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220123_north.png
# Processing scatter plot for date: 20220124
# Missing file for date 20220124, skipping...
# Processing scatter plot for date: 20220125
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220125_north.png
# Processing scatter plot for date: 20220126
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220126_north.png
# Processing scatter plot for date: 20220127
# Missing file for date 20220127, skipping...
# Processing scatter plot for date: 20220128
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220128_north.png
# Processing scatter plot for date: 20220129
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220129_north.png
# Processing scatter plot for date: 20220130
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220130_north.png
# Processing scatter plot for date: 20220131
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220131_north.png
# Processing scatter plot for date: 20220201
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220201_north.png
# Processing scatter plot for date: 20220202
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220202_north.png
# Processing scatter plot for date: 20220203
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220203_north.png
# Processing scatter plot for date: 20220204
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220204_north.png
# Processing scatter plot for date: 20220205
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220205_north.png
# Processing scatter plot for date: 20220206
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220206_north.png
# Processing scatter plot for date: 20220207
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220207_north.png
# Processing scatter plot for date: 20220208
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220208_north.png
# Processing scatter plot for date: 20220209
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220209_north.png
# Processing scatter plot for date: 20220210
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220210_north.png
# Processing scatter plot for date: 20220211
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220211_north.png
# Processing scatter plot for date: 20220212
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220212_north.png
# Processing scatter plot for date: 20220213
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220213_north.png
# Processing scatter plot for date: 20220214
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220214_north.png
# Processing scatter plot for date: 20220215
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220215_north.png
# Processing scatter plot for date: 20220216
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220216_north.png
# Processing scatter plot for date: 20220217
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220217_north.png
# Processing scatter plot for date: 20220218
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220218_north.png
# Processing scatter plot for date: 20220219
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220219_north.png
# Processing scatter plot for date: 20220220
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220220_north.png
# Processing scatter plot for date: 20220221
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220221_north.png
# Processing scatter plot for date: 20220222
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220222_north.png
# Processing scatter plot for date: 20220223
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220223_north.png
# Processing scatter plot for date: 20220224
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220224_north.png
# Processing scatter plot for date: 20220225
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220225_north.png
# Processing scatter plot for date: 20220226
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220226_north.png
# Processing scatter plot for date: 20220227
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220227_north.png
# Processing scatter plot for date: 20220228
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220228_north.png
# Processing scatter plot for date: 20220301
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220301_north.png
# Processing scatter plot for date: 20220302
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220302_north.png
# Processing scatter plot for date: 20220303
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220303_north.png
# Processing scatter plot for date: 20220304
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220304_north.png
# Processing scatter plot for date: 20220305
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220305_north.png
# Processing scatter plot for date: 20220306
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220306_north.png
# Processing scatter plot for date: 20220307
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220307_north.png
# Processing scatter plot for date: 20220308
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220308_north.png
# Processing scatter plot for date: 20220309
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220309_north.png
# Processing scatter plot for date: 20220310
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220310_north.png
# Processing scatter plot for date: 20220311
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220311_north.png
# Processing scatter plot for date: 20220312
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220312_north.png
# Processing scatter plot for date: 20220313
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220313_north.png
# Processing scatter plot for date: 20220314
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220314_north.png
# Processing scatter plot for date: 20220315
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220315_north.png
# Processing scatter plot for date: 20220316
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220316_north.png
# Processing scatter plot for date: 20220317
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220317_north.png
# Processing scatter plot for date: 20220318
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220318_north.png
# Processing scatter plot for date: 20220319
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220319_north.png
# Processing scatter plot for date: 20220320
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220320_north.png
# Processing scatter plot for date: 20220321
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220321_north.png
# Processing scatter plot for date: 20220322
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220322_north.png
# Processing scatter plot for date: 20220323
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220323_north.png
# Processing scatter plot for date: 20220324
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220324_north.png
# Processing scatter plot for date: 20220325
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220325_north.png
# Processing scatter plot for date: 20220326
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220326_north.png
# Processing scatter plot for date: 20220327
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220327_north.png
# Processing scatter plot for date: 20220328
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220328_north.png
# Processing scatter plot for date: 20220329
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220329_north.png
# Processing scatter plot for date: 20220330
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220330_north.png
# Processing scatter plot for date: 20220331
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220331_north.png
# Processing scatter plot for date: 20220401
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220401_north.png
# Processing scatter plot for date: 20220402
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220402_north.png
# Processing scatter plot for date: 20220403
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220403_north.png
# Processing scatter plot for date: 20220404
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220404_north.png
# Processing scatter plot for date: 20220405
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220405_north.png
# Processing scatter plot for date: 20220406
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220406_north.png
# Processing scatter plot for date: 20220407
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220407_north.png
# Processing scatter plot for date: 20220408
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220408_north.png
# Processing scatter plot for date: 20220409
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220409_north.png
# Processing scatter plot for date: 20220410
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220410_north.png
# Processing scatter plot for date: 20220411
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220411_north.png
# Processing scatter plot for date: 20220412
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220412_north.png
# Processing scatter plot for date: 20220413
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220413_north.png
# Processing scatter plot for date: 20220414
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220414_north.png
# Processing scatter plot for date: 20220415
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220415_north.png
# Processing scatter plot for date: 20220416
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220416_north.png
# Processing scatter plot for date: 20220417
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220417_north.png
# Processing scatter plot for date: 20220418
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220418_north.png
# Processing scatter plot for date: 20220419
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220419_north.png
# Processing scatter plot for date: 20220420
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220420_north.png
# Processing scatter plot for date: 20220421
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220421_north.png
# Processing scatter plot for date: 20220422
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220422_north.png
# Processing scatter plot for date: 20220423
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220423_north.png
# Processing scatter plot for date: 20220424
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220424_north.png
# Processing scatter plot for date: 20220425
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220425_north.png
# Processing scatter plot for date: 20220426
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220426_north.png
# Processing scatter plot for date: 20220427
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220427_north.png
# Processing scatter plot for date: 20220428
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220428_north.png
# Processing scatter plot for date: 20220429
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220429_north.png
# Processing scatter plot for date: 20220430
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220430_north.png
# Processing scatter plot for date: 20220501
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220501_north.png
# Processing scatter plot for date: 20220502
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220502_north.png
# Processing scatter plot for date: 20220503
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220503_north.png
# Processing scatter plot for date: 20220504
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220504_north.png
# Processing scatter plot for date: 20220505
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220505_north.png
# Processing scatter plot for date: 20220506
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220506_north.png
# Processing scatter plot for date: 20220507
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220507_north.png
# Processing scatter plot for date: 20220508
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220508_north.png
# Processing scatter plot for date: 20220509
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220509_north.png
# Processing scatter plot for date: 20220510
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220510_north.png
# Processing scatter plot for date: 20220511
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220511_north.png
# Processing scatter plot for date: 20220512
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220512_north.png
# Processing scatter plot for date: 20220513
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220513_north.png
# Processing scatter plot for date: 20220514
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220514_north.png
# Processing scatter plot for date: 20220515
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220515_north.png
# Processing scatter plot for date: 20220516
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220516_north.png
# Processing scatter plot for date: 20220517
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220517_north.png
# Processing scatter plot for date: 20220518
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220518_north.png
# Processing scatter plot for date: 20220519
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220519_north.png
# Processing scatter plot for date: 20220520
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220520_north.png
# Processing scatter plot for date: 20220521
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220521_north.png
# Processing scatter plot for date: 20220522
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220522_north.png
# Processing scatter plot for date: 20220523
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220523_north.png
# Processing scatter plot for date: 20220524
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220524_north.png
# Processing scatter plot for date: 20220525
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220525_north.png
# Processing scatter plot for date: 20220526
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220526_north.png
# Processing scatter plot for date: 20220527
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220527_north.png
# Processing scatter plot for date: 20220528
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220528_north.png
# Processing scatter plot for date: 20220529
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220529_north.png
# Processing scatter plot for date: 20220530
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220530_north.png
# Processing scatter plot for date: 20220531
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220531_north.png
# Processing scatter plot for date: 20220601
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220601_north.png
# Processing scatter plot for date: 20220602
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220602_north.png
# Processing scatter plot for date: 20220603
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220603_north.png
# Processing scatter plot for date: 20220604
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220604_north.png
# Processing scatter plot for date: 20220605
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220605_north.png
# Processing scatter plot for date: 20220606
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220606_north.png
# Processing scatter plot for date: 20220607
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220607_north.png
# Processing scatter plot for date: 20220608
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220608_north.png
# Processing scatter plot for date: 20220609
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220609_north.png
# Processing scatter plot for date: 20220610
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220610_north.png
# Processing scatter plot for date: 20220611
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220611_north.png
# Processing scatter plot for date: 20220612
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220612_north.png
# Processing scatter plot for date: 20220613
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220613_north.png
# Processing scatter plot for date: 20220614
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220614_north.png
# Processing scatter plot for date: 20220615
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220615_north.png
# Processing scatter plot for date: 20220616
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220616_north.png
# Processing scatter plot for date: 20220617
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220617_north.png
# Processing scatter plot for date: 20220618
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220618_north.png
# Processing scatter plot for date: 20220619
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220619_north.png
# Processing scatter plot for date: 20220620
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220620_north.png
# Processing scatter plot for date: 20220621
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220621_north.png
# Processing scatter plot for date: 20220622
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220622_north.png
# Processing scatter plot for date: 20220623
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220623_north.png
# Processing scatter plot for date: 20220624
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220624_north.png
# Processing scatter plot for date: 20220625
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220625_north.png
# Processing scatter plot for date: 20220626
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220626_north.png
# Processing scatter plot for date: 20220627
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220627_north.png
# Processing scatter plot for date: 20220628
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220628_north.png
# Processing scatter plot for date: 20220629
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220629_north.png
# Processing scatter plot for date: 20220630
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220630_north.png
# Processing scatter plot for date: 20220701
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220701_north.png
# Processing scatter plot for date: 20220702
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220702_north.png
# Processing scatter plot for date: 20220703
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220703_north.png
# Processing scatter plot for date: 20220704
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220704_north.png
# Processing scatter plot for date: 20220705
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220705_north.png
# Processing scatter plot for date: 20220706
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220706_north.png
# Processing scatter plot for date: 20220707
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220707_north.png
# Processing scatter plot for date: 20220708
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220708_north.png
# Processing scatter plot for date: 20220709
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220709_north.png
# Processing scatter plot for date: 20220710
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220710_north.png
# Processing scatter plot for date: 20220711
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220711_north.png
# Processing scatter plot for date: 20220712
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220712_north.png
# Processing scatter plot for date: 20220713
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220713_north.png
# Processing scatter plot for date: 20220714
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220714_north.png
# Processing scatter plot for date: 20220715
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220715_north.png
# Processing scatter plot for date: 20220716
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220716_north.png
# Processing scatter plot for date: 20220717
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220717_north.png
# Processing scatter plot for date: 20220718
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220718_north.png
# Processing scatter plot for date: 20220719
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220719_north.png
# Processing scatter plot for date: 20220720
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220720_north.png
# Processing scatter plot for date: 20220721
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220721_north.png
# Processing scatter plot for date: 20220722
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220722_north.png
# Processing scatter plot for date: 20220723
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220723_north.png
# Processing scatter plot for date: 20220724
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220724_north.png
# Processing scatter plot for date: 20220725
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220725_north.png
# Processing scatter plot for date: 20220726
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220726_north.png
# Processing scatter plot for date: 20220727
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220727_north.png
# Processing scatter plot for date: 20220728
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220728_north.png
# Processing scatter plot for date: 20220729
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220729_north.png
# Processing scatter plot for date: 20220730
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220730_north.png
# Processing scatter plot for date: 20220731
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220731_north.png
# Processing scatter plot for date: 20220801
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220801_north.png
# Processing scatter plot for date: 20220802
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220802_north.png
# Processing scatter plot for date: 20220803
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220803_north.png
# Processing scatter plot for date: 20220804
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220804_north.png
# Processing scatter plot for date: 20220805
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220805_north.png
# Processing scatter plot for date: 20220806
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220806_north.png
# Processing scatter plot for date: 20220807
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220807_north.png
# Processing scatter plot for date: 20220808
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220808_north.png
# Processing scatter plot for date: 20220809
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220809_north.png
# Processing scatter plot for date: 20220810
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220810_north.png
# Processing scatter plot for date: 20220811
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220811_north.png
# Processing scatter plot for date: 20220812
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220812_north.png
# Processing scatter plot for date: 20220813
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220813_north.png
# Processing scatter plot for date: 20220814
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220814_north.png
# Processing scatter plot for date: 20220815
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220815_north.png
# Processing scatter plot for date: 20220816
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220816_north.png
# Processing scatter plot for date: 20220817
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220817_north.png
# Processing scatter plot for date: 20220818
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220818_north.png
# Processing scatter plot for date: 20220819
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220819_north.png
# Processing scatter plot for date: 20220820
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220820_north.png
# Processing scatter plot for date: 20220821
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220821_north.png
# Processing scatter plot for date: 20220822
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220822_north.png
# Processing scatter plot for date: 20220823
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220823_north.png
# Processing scatter plot for date: 20220824
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220824_north.png
# Processing scatter plot for date: 20220825
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220825_north.png
# Processing scatter plot for date: 20220826
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220826_north.png
# Processing scatter plot for date: 20220827
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220827_north.png
# Processing scatter plot for date: 20220828
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220828_north.png
# Processing scatter plot for date: 20220829
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220829_north.png
# Processing scatter plot for date: 20220830
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220830_north.png
# Processing scatter plot for date: 20220831
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220831_north.png
# Processing scatter plot for date: 20220901
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220901_north.png
# Processing scatter plot for date: 20220902
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220902_north.png
# Processing scatter plot for date: 20220903
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220903_north.png
# Processing scatter plot for date: 20220904
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220904_north.png
# Processing scatter plot for date: 20220905
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220905_north.png
# Processing scatter plot for date: 20220906
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220906_north.png
# Processing scatter plot for date: 20220907
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220907_north.png
# Processing scatter plot for date: 20220908
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220908_north.png
# Processing scatter plot for date: 20220909
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220909_north.png
# Processing scatter plot for date: 20220910
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220910_north.png
# Processing scatter plot for date: 20220911
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220911_north.png
# Processing scatter plot for date: 20220912
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220912_north.png
# Processing scatter plot for date: 20220913
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220913_north.png
# Processing scatter plot for date: 20220914
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220914_north.png
# Processing scatter plot for date: 20220915
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220915_north.png
# Processing scatter plot for date: 20220916
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220916_north.png
# Processing scatter plot for date: 20220917
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220917_north.png
# Processing scatter plot for date: 20220918
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220918_north.png
# Processing scatter plot for date: 20220919
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220919_north.png
# Processing scatter plot for date: 20220920
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220920_north.png
# Processing scatter plot for date: 20220921
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220921_north.png
# Processing scatter plot for date: 20220922
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220922_north.png
# Processing scatter plot for date: 20220923
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220923_north.png
# Processing scatter plot for date: 20220924
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220924_north.png
# Processing scatter plot for date: 20220925
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220925_north.png
# Processing scatter plot for date: 20220926
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220926_north.png
# Processing scatter plot for date: 20220927
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220927_north.png
# Processing scatter plot for date: 20220928
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220928_north.png
# Processing scatter plot for date: 20220929
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220929_north.png
# Processing scatter plot for date: 20220930
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220930_north.png
# Processing scatter plot for date: 20221001
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221001_north.png
# Processing scatter plot for date: 20221002
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221002_north.png
# Processing scatter plot for date: 20221003
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221003_north.png
# Processing scatter plot for date: 20221004
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221004_north.png
# Processing scatter plot for date: 20221005
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221005_north.png
# Processing scatter plot for date: 20221006
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221006_north.png
# Processing scatter plot for date: 20221007
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221007_north.png
# Processing scatter plot for date: 20221008
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221008_north.png
# Processing scatter plot for date: 20221009
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221009_north.png
# Processing scatter plot for date: 20221010
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221010_north.png
# Processing scatter plot for date: 20221011
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221011_north.png
# Processing scatter plot for date: 20221012
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221012_north.png
# Processing scatter plot for date: 20221013
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221013_north.png
# Processing scatter plot for date: 20221014
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221014_north.png
# Processing scatter plot for date: 20221015
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221015_north.png
# Processing scatter plot for date: 20221016
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221016_north.png
# Processing scatter plot for date: 20221017
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221017_north.png
# Processing scatter plot for date: 20221018
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221018_north.png
# Processing scatter plot for date: 20221019
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221019_north.png
# Processing scatter plot for date: 20221020
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221020_north.png
# Processing scatter plot for date: 20221021
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221021_north.png
# Processing scatter plot for date: 20221022
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221022_north.png
# Processing scatter plot for date: 20221023
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221023_north.png
# Processing scatter plot for date: 20221024
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221024_north.png
# Processing scatter plot for date: 20221025
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221025_north.png
# Processing scatter plot for date: 20221026
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221026_north.png
# Processing scatter plot for date: 20221027
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221027_north.png
# Processing scatter plot for date: 20221028
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221028_north.png
# Processing scatter plot for date: 20221029
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221029_north.png
# Processing scatter plot for date: 20221030
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221030_north.png
# Processing scatter plot for date: 20221031
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221031_north.png
# Processing scatter plot for date: 20221101
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221101_north.png
# Processing scatter plot for date: 20221102
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221102_north.png
# Processing scatter plot for date: 20221103
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221103_north.png
# Processing scatter plot for date: 20221104
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221104_north.png
# Processing scatter plot for date: 20221105
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221105_north.png
# Processing scatter plot for date: 20221106
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221106_north.png
# Processing scatter plot for date: 20221107
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221107_north.png
# Processing scatter plot for date: 20221108
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221108_north.png
# Processing scatter plot for date: 20221109
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221109_north.png
# Processing scatter plot for date: 20221110
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221110_north.png
# Processing scatter plot for date: 20221111
# Missing file for date 20221111, skipping...
# Processing scatter plot for date: 20221112
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221112_north.png
# Processing scatter plot for date: 20221113
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221113_north.png
# Processing scatter plot for date: 20221114
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221114_north.png
# Processing scatter plot for date: 20221115
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221115_north.png
# Processing scatter plot for date: 20221116
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221116_north.png
# Processing scatter plot for date: 20221117
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221117_north.png
# Processing scatter plot for date: 20221118
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221118_north.png
# Processing scatter plot for date: 20221119
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221119_north.png
# Processing scatter plot for date: 20221120
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221120_north.png
# Processing scatter plot for date: 20221121
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221121_north.png
# Processing scatter plot for date: 20221122
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221122_north.png
# Processing scatter plot for date: 20221123
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221123_north.png
# Processing scatter plot for date: 20221124
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221124_north.png
# Processing scatter plot for date: 20221125
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221125_north.png
# Processing scatter plot for date: 20221126
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221126_north.png
# Processing scatter plot for date: 20221127
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221127_north.png
# Processing scatter plot for date: 20221128
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221128_north.png
# Processing scatter plot for date: 20221129
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221129_north.png
# Processing scatter plot for date: 20221130
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221130_north.png
# Processing scatter plot for date: 20221201
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221201_north.png
# Processing scatter plot for date: 20221202
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221202_north.png
# Processing scatter plot for date: 20221203
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221203_north.png
# Processing scatter plot for date: 20221204
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221204_north.png
# Processing scatter plot for date: 20221205
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221205_north.png
# Processing scatter plot for date: 20221206
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221206_north.png
# Processing scatter plot for date: 20221207
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221207_north.png
# Processing scatter plot for date: 20221208
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221208_north.png
# Processing scatter plot for date: 20221209
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221209_north.png
# Processing scatter plot for date: 20221210
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221210_north.png
# Processing scatter plot for date: 20221211
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221211_north.png
# Processing scatter plot for date: 20221212
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221212_north.png
# Processing scatter plot for date: 20221213
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221213_north.png
# Processing scatter plot for date: 20221214
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221214_north.png
# Processing scatter plot for date: 20221215
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221215_north.png
# Processing scatter plot for date: 20221216
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221216_north.png
# Processing scatter plot for date: 20221217
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221217_north.png
# Processing scatter plot for date: 20221218
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221218_north.png
# Processing scatter plot for date: 20221219
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221219_north.png
# Processing scatter plot for date: 20221220
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221220_north.png
# Processing scatter plot for date: 20221221
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221221_north.png
# Processing scatter plot for date: 20221222
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221222_north.png
# Processing scatter plot for date: 20221223
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221223_north.png
# Processing scatter plot for date: 20221224
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221224_north.png
# Processing scatter plot for date: 20221225
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221225_north.png
# Processing scatter plot for date: 20221226
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221226_north.png
# Processing scatter plot for date: 20221227
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221227_north.png
# Processing scatter plot for date: 20221228
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221228_north.png
# Processing scatter plot for date: 20221229
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221229_north.png
# Processing scatter plot for date: 20221230
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221230_north.png
# Processing scatter plot for date: 20221231
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221231_north.png

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import os

plt.rcParams['font.sans-serif'] = ['SimHei']

def plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date, output_dir):
    """
    绘制订正前、订正后的非参考数据与参考数据的散点图
    :param non_ref_data: 订正前的非参考数据 (2D numpy array)
    :param corrected_data: 订正后的非参考数据 (2D numpy array)
    :param ref_data: 参考数据 (2D numpy array)
    :param date: 当前日期 (str)
    :param output_dir: 输出散点图的保存目录
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # 平铺数组，去除 NaN 数据
    mask = (~np.isnan(non_ref_data)) & (~np.isnan(ref_data))
    x_non_ref = non_ref_data[mask]
    x_corrected = corrected_data[mask]
    y_ref = ref_data[mask]
    
    # 绘制订正前的散点图
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.scatter(x_non_ref, y_ref, s=2, alpha=0.5, color='blue')
    plt.plot([0, 100], [0, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 100)
    plt.ylim(0, 100)
   
    plt.xlabel("非参考数据 (订正前)")
    plt.ylabel("参考数据")
    plt.title(f"订正前 ({date})")
    
    # 绘制订正后的散点图
    plt.subplot(1, 2, 2)
    plt.scatter(x_corrected, y_ref, s=2, alpha=0.5, color='red')
    plt.plot([0, 100], [0, 100], 'k--', lw=1)  # 1:1 线
    plt.xlim(0, 100)
    plt.ylim(0, 100)
    plt.xlabel("非参考数据 (订正后)")
    plt.ylabel("参考数据")
    plt.title(f"订正后 ({date})")
     
    # 保存散点图
    plt.tight_layout()
    output_file = os.path.join(output_dir, f"scatter_comparison_{date}_south.png")
    plt.savefig(output_file, dpi=100)
    plt.close()
    print(f"Saved scatter plot: {output_file}")

def generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date):
    """
    生成非参考数据的订正前后与参考数据的散点图
    :param input_dir: 订正前非参考数据目录
    :param corrected_dir: 订正后数据目录
    :param reference_dir: 参考数据目录
    :param output_dir: 输出散点图的保存目录
    :param hemisphere: 'north' 或 'south'
    :param start_date: 开始日期 (str)
    :param end_date: 结束日期 (str)
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)

    for date in date_range:
        date_str = date.strftime('%Y%m%d')
        print(f"Processing scatter plot for date: {date_str}")

        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_{hemisphere}_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"FY3D_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        non_ref_file = os.path.join(input_dir, f"FY3D_{hemisphere}_icecon_25000_{date_str}.nc")

        # 检查文件是否存在
        if not all(os.path.exists(f) for f in [ref_file, corrected_file, non_ref_file]):
            print(f"Missing file for date {date_str}, skipping...")
            continue

        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_south_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        non_ref_data = xr.open_dataset(non_ref_file)['FY3D_south_icecon'].values

        # 绘制散点图
        plot_scatter_comparison(non_ref_data, corrected_data, ref_data, date_str, output_dir)

if __name__ == "__main__":
    import pandas as pd

    # 文件目录路径
    input_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\0_pre_com\south"
    corrected_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\1_PDFcorrected\south"
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\south"
    output_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots"
    # 若output_dir不存在，创建output_dir
    os.makedirs(output_dir, exist_ok=True)

    hemisphere = "south"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    generate_scatter_plots(input_dir, corrected_dir, reference_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing scatter plot for date: 20220101
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220101_south.png
# Processing scatter plot for date: 20220102
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220102_south.png
# Processing scatter plot for date: 20220103
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220103_south.png
# Processing scatter plot for date: 20220104
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220104_south.png
# Processing scatter plot for date: 20220105
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220105_south.png
# Processing scatter plot for date: 20220106
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220106_south.png
# Processing scatter plot for date: 20220107
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220107_south.png
# Processing scatter plot for date: 20220108
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220108_south.png
# Processing scatter plot for date: 20220109
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220109_south.png
# Processing scatter plot for date: 20220110
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220110_south.png
# Processing scatter plot for date: 20220111
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220111_south.png
# Processing scatter plot for date: 20220112
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220112_south.png
# Processing scatter plot for date: 20220113
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220113_south.png
# Processing scatter plot for date: 20220114
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220114_south.png
# Processing scatter plot for date: 20220115
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220115_south.png
# Processing scatter plot for date: 20220116
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220116_south.png
# Processing scatter plot for date: 20220117
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220117_south.png
# Processing scatter plot for date: 20220118
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220118_south.png
# Processing scatter plot for date: 20220119
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220119_south.png
# Processing scatter plot for date: 20220120
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220120_south.png
# Processing scatter plot for date: 20220121
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220121_south.png
# Processing scatter plot for date: 20220122
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220122_south.png
# Processing scatter plot for date: 20220123
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220123_south.png
# Processing scatter plot for date: 20220124
# Missing file for date 20220124, skipping...
# Processing scatter plot for date: 20220125
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220125_south.png
# Processing scatter plot for date: 20220126
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220126_south.png
# Processing scatter plot for date: 20220127
# Missing file for date 20220127, skipping...
# Processing scatter plot for date: 20220128
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220128_south.png
# Processing scatter plot for date: 20220129
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220129_south.png
# Processing scatter plot for date: 20220130
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220130_south.png
# Processing scatter plot for date: 20220131
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220131_south.png
# Processing scatter plot for date: 20220201
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220201_south.png
# Processing scatter plot for date: 20220202
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220202_south.png
# Processing scatter plot for date: 20220203
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220203_south.png
# Processing scatter plot for date: 20220204
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220204_south.png
# Processing scatter plot for date: 20220205
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220205_south.png
# Processing scatter plot for date: 20220206
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220206_south.png
# Processing scatter plot for date: 20220207
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220207_south.png
# Processing scatter plot for date: 20220208
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220208_south.png
# Processing scatter plot for date: 20220209
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220209_south.png
# Processing scatter plot for date: 20220210
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220210_south.png
# Processing scatter plot for date: 20220211
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220211_south.png
# Processing scatter plot for date: 20220212
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220212_south.png
# Processing scatter plot for date: 20220213
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220213_south.png
# Processing scatter plot for date: 20220214
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220214_south.png
# Processing scatter plot for date: 20220215
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220215_south.png
# Processing scatter plot for date: 20220216
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220216_south.png
# Processing scatter plot for date: 20220217
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220217_south.png
# Processing scatter plot for date: 20220218
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220218_south.png
# Processing scatter plot for date: 20220219
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220219_south.png
# Processing scatter plot for date: 20220220
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220220_south.png
# Processing scatter plot for date: 20220221
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220221_south.png
# Processing scatter plot for date: 20220222
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220222_south.png
# Processing scatter plot for date: 20220223
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220223_south.png
# Processing scatter plot for date: 20220224
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220224_south.png
# Processing scatter plot for date: 20220225
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220225_south.png
# Processing scatter plot for date: 20220226
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220226_south.png
# Processing scatter plot for date: 20220227
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220227_south.png
# Processing scatter plot for date: 20220228
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220228_south.png
# Processing scatter plot for date: 20220301
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220301_south.png
# Processing scatter plot for date: 20220302
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220302_south.png
# Processing scatter plot for date: 20220303
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220303_south.png
# Processing scatter plot for date: 20220304
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220304_south.png
# Processing scatter plot for date: 20220305
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220305_south.png
# Processing scatter plot for date: 20220306
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220306_south.png
# Processing scatter plot for date: 20220307
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220307_south.png
# Processing scatter plot for date: 20220308
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220308_south.png
# Processing scatter plot for date: 20220309
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220309_south.png
# Processing scatter plot for date: 20220310
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220310_south.png
# Processing scatter plot for date: 20220311
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220311_south.png
# Processing scatter plot for date: 20220312
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220312_south.png
# Processing scatter plot for date: 20220313
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220313_south.png
# Processing scatter plot for date: 20220314
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220314_south.png
# Processing scatter plot for date: 20220315
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220315_south.png
# Processing scatter plot for date: 20220316
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220316_south.png
# Processing scatter plot for date: 20220317
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220317_south.png
# Processing scatter plot for date: 20220318
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220318_south.png
# Processing scatter plot for date: 20220319
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220319_south.png
# Processing scatter plot for date: 20220320
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220320_south.png
# Processing scatter plot for date: 20220321
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220321_south.png
# Processing scatter plot for date: 20220322
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220322_south.png
# Processing scatter plot for date: 20220323
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220323_south.png
# Processing scatter plot for date: 20220324
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220324_south.png
# Processing scatter plot for date: 20220325
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220325_south.png
# Processing scatter plot for date: 20220326
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220326_south.png
# Processing scatter plot for date: 20220327
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220327_south.png
# Processing scatter plot for date: 20220328
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220328_south.png
# Processing scatter plot for date: 20220329
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220329_south.png
# Processing scatter plot for date: 20220330
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220330_south.png
# Processing scatter plot for date: 20220331
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220331_south.png
# Processing scatter plot for date: 20220401
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220401_south.png
# Processing scatter plot for date: 20220402
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220402_south.png
# Processing scatter plot for date: 20220403
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220403_south.png
# Processing scatter plot for date: 20220404
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220404_south.png
# Processing scatter plot for date: 20220405
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220405_south.png
# Processing scatter plot for date: 20220406
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220406_south.png
# Processing scatter plot for date: 20220407
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220407_south.png
# Processing scatter plot for date: 20220408
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220408_south.png
# Processing scatter plot for date: 20220409
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220409_south.png
# Processing scatter plot for date: 20220410
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220410_south.png
# Processing scatter plot for date: 20220411
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220411_south.png
# Processing scatter plot for date: 20220412
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220412_south.png
# Processing scatter plot for date: 20220413
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220413_south.png
# Processing scatter plot for date: 20220414
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220414_south.png
# Processing scatter plot for date: 20220415
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220415_south.png
# Processing scatter plot for date: 20220416
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220416_south.png
# Processing scatter plot for date: 20220417
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220417_south.png
# Processing scatter plot for date: 20220418
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220418_south.png
# Processing scatter plot for date: 20220419
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220419_south.png
# Processing scatter plot for date: 20220420
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220420_south.png
# Processing scatter plot for date: 20220421
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220421_south.png
# Processing scatter plot for date: 20220422
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220422_south.png
# Processing scatter plot for date: 20220423
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220423_south.png
# Processing scatter plot for date: 20220424
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220424_south.png
# Processing scatter plot for date: 20220425
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220425_south.png
# Processing scatter plot for date: 20220426
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220426_south.png
# Processing scatter plot for date: 20220427
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220427_south.png
# Processing scatter plot for date: 20220428
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220428_south.png
# Processing scatter plot for date: 20220429
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220429_south.png
# Processing scatter plot for date: 20220430
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220430_south.png
# Processing scatter plot for date: 20220501
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220501_south.png
# Processing scatter plot for date: 20220502
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220502_south.png
# Processing scatter plot for date: 20220503
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220503_south.png
# Processing scatter plot for date: 20220504
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220504_south.png
# Processing scatter plot for date: 20220505
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220505_south.png
# Processing scatter plot for date: 20220506
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220506_south.png
# Processing scatter plot for date: 20220507
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220507_south.png
# Processing scatter plot for date: 20220508
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220508_south.png
# Processing scatter plot for date: 20220509
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220509_south.png
# Processing scatter plot for date: 20220510
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220510_south.png
# Processing scatter plot for date: 20220511
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220511_south.png
# Processing scatter plot for date: 20220512
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220512_south.png
# Processing scatter plot for date: 20220513
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220513_south.png
# Processing scatter plot for date: 20220514
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220514_south.png
# Processing scatter plot for date: 20220515
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220515_south.png
# Processing scatter plot for date: 20220516
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220516_south.png
# Processing scatter plot for date: 20220517
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220517_south.png
# Processing scatter plot for date: 20220518
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220518_south.png
# Processing scatter plot for date: 20220519
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220519_south.png
# Processing scatter plot for date: 20220520
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220520_south.png
# Processing scatter plot for date: 20220521
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220521_south.png
# Processing scatter plot for date: 20220522
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220522_south.png
# Processing scatter plot for date: 20220523
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220523_south.png
# Processing scatter plot for date: 20220524
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220524_south.png
# Processing scatter plot for date: 20220525
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220525_south.png
# Processing scatter plot for date: 20220526
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220526_south.png
# Processing scatter plot for date: 20220527
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220527_south.png
# Processing scatter plot for date: 20220528
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220528_south.png
# Processing scatter plot for date: 20220529
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220529_south.png
# Processing scatter plot for date: 20220530
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220530_south.png
# Processing scatter plot for date: 20220531
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220531_south.png
# Processing scatter plot for date: 20220601
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220601_south.png
# Processing scatter plot for date: 20220602
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220602_south.png
# Processing scatter plot for date: 20220603
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220603_south.png
# Processing scatter plot for date: 20220604
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220604_south.png
# Processing scatter plot for date: 20220605
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220605_south.png
# Processing scatter plot for date: 20220606
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220606_south.png
# Processing scatter plot for date: 20220607
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220607_south.png
# Processing scatter plot for date: 20220608
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220608_south.png
# Processing scatter plot for date: 20220609
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220609_south.png
# Processing scatter plot for date: 20220610
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220610_south.png
# Processing scatter plot for date: 20220611
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220611_south.png
# Processing scatter plot for date: 20220612
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220612_south.png
# Processing scatter plot for date: 20220613
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220613_south.png
# Processing scatter plot for date: 20220614
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220614_south.png
# Processing scatter plot for date: 20220615
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220615_south.png
# Processing scatter plot for date: 20220616
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220616_south.png
# Processing scatter plot for date: 20220617
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220617_south.png
# Processing scatter plot for date: 20220618
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220618_south.png
# Processing scatter plot for date: 20220619
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220619_south.png
# Processing scatter plot for date: 20220620
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220620_south.png
# Processing scatter plot for date: 20220621
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220621_south.png
# Processing scatter plot for date: 20220622
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220622_south.png
# Processing scatter plot for date: 20220623
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220623_south.png
# Processing scatter plot for date: 20220624
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220624_south.png
# Processing scatter plot for date: 20220625
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220625_south.png
# Processing scatter plot for date: 20220626
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220626_south.png
# Processing scatter plot for date: 20220627
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220627_south.png
# Processing scatter plot for date: 20220628
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220628_south.png
# Processing scatter plot for date: 20220629
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220629_south.png
# Processing scatter plot for date: 20220630
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220630_south.png
# Processing scatter plot for date: 20220701
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220701_south.png
# Processing scatter plot for date: 20220702
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220702_south.png
# Processing scatter plot for date: 20220703
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220703_south.png
# Processing scatter plot for date: 20220704
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220704_south.png
# Processing scatter plot for date: 20220705
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220705_south.png
# Processing scatter plot for date: 20220706
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220706_south.png
# Processing scatter plot for date: 20220707
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220707_south.png
# Processing scatter plot for date: 20220708
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220708_south.png
# Processing scatter plot for date: 20220709
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220709_south.png
# Processing scatter plot for date: 20220710
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220710_south.png
# Processing scatter plot for date: 20220711
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220711_south.png
# Processing scatter plot for date: 20220712
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220712_south.png
# Processing scatter plot for date: 20220713
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220713_south.png
# Processing scatter plot for date: 20220714
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220714_south.png
# Processing scatter plot for date: 20220715
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220715_south.png
# Processing scatter plot for date: 20220716
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220716_south.png
# Processing scatter plot for date: 20220717
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220717_south.png
# Processing scatter plot for date: 20220718
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220718_south.png
# Processing scatter plot for date: 20220719
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220719_south.png
# Processing scatter plot for date: 20220720
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220720_south.png
# Processing scatter plot for date: 20220721
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220721_south.png
# Processing scatter plot for date: 20220722
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220722_south.png
# Processing scatter plot for date: 20220723
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220723_south.png
# Processing scatter plot for date: 20220724
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220724_south.png
# Processing scatter plot for date: 20220725
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220725_south.png
# Processing scatter plot for date: 20220726
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220726_south.png
# Processing scatter plot for date: 20220727
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220727_south.png
# Processing scatter plot for date: 20220728
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220728_south.png
# Processing scatter plot for date: 20220729
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220729_south.png
# Processing scatter plot for date: 20220730
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220730_south.png
# Processing scatter plot for date: 20220731
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220731_south.png
# Processing scatter plot for date: 20220801
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220801_south.png
# Processing scatter plot for date: 20220802
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220802_south.png
# Processing scatter plot for date: 20220803
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220803_south.png
# Processing scatter plot for date: 20220804
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220804_south.png
# Processing scatter plot for date: 20220805
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220805_south.png
# Processing scatter plot for date: 20220806
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220806_south.png
# Processing scatter plot for date: 20220807
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220807_south.png
# Processing scatter plot for date: 20220808
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220808_south.png
# Processing scatter plot for date: 20220809
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220809_south.png
# Processing scatter plot for date: 20220810
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220810_south.png
# Processing scatter plot for date: 20220811
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220811_south.png
# Processing scatter plot for date: 20220812
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220812_south.png
# Processing scatter plot for date: 20220813
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220813_south.png
# Processing scatter plot for date: 20220814
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220814_south.png
# Processing scatter plot for date: 20220815
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220815_south.png
# Processing scatter plot for date: 20220816
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220816_south.png
# Processing scatter plot for date: 20220817
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220817_south.png
# Processing scatter plot for date: 20220818
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220818_south.png
# Processing scatter plot for date: 20220819
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220819_south.png
# Processing scatter plot for date: 20220820
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220820_south.png
# Processing scatter plot for date: 20220821
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220821_south.png
# Processing scatter plot for date: 20220822
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220822_south.png
# Processing scatter plot for date: 20220823
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220823_south.png
# Processing scatter plot for date: 20220824
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220824_south.png
# Processing scatter plot for date: 20220825
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220825_south.png
# Processing scatter plot for date: 20220826
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220826_south.png
# Processing scatter plot for date: 20220827
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220827_south.png
# Processing scatter plot for date: 20220828
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220828_south.png
# Processing scatter plot for date: 20220829
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220829_south.png
# Processing scatter plot for date: 20220830
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220830_south.png
# Processing scatter plot for date: 20220831
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220831_south.png
# Processing scatter plot for date: 20220901
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220901_south.png
# Processing scatter plot for date: 20220902
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220902_south.png
# Processing scatter plot for date: 20220903
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220903_south.png
# Processing scatter plot for date: 20220904
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220904_south.png
# Processing scatter plot for date: 20220905
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220905_south.png
# Processing scatter plot for date: 20220906
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220906_south.png
# Processing scatter plot for date: 20220907
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220907_south.png
# Processing scatter plot for date: 20220908
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220908_south.png
# Processing scatter plot for date: 20220909
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220909_south.png
# Processing scatter plot for date: 20220910
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220910_south.png
# Processing scatter plot for date: 20220911
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220911_south.png
# Processing scatter plot for date: 20220912
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220912_south.png
# Processing scatter plot for date: 20220913
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220913_south.png
# Processing scatter plot for date: 20220914
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220914_south.png
# Processing scatter plot for date: 20220915
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220915_south.png
# Processing scatter plot for date: 20220916
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220916_south.png
# Processing scatter plot for date: 20220917
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220917_south.png
# Processing scatter plot for date: 20220918
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220918_south.png
# Processing scatter plot for date: 20220919
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220919_south.png
# Processing scatter plot for date: 20220920
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220920_south.png
# Processing scatter plot for date: 20220921
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220921_south.png
# Processing scatter plot for date: 20220922
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220922_south.png
# Processing scatter plot for date: 20220923
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220923_south.png
# Processing scatter plot for date: 20220924
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220924_south.png
# Processing scatter plot for date: 20220925
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220925_south.png
# Processing scatter plot for date: 20220926
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220926_south.png
# Processing scatter plot for date: 20220927
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220927_south.png
# Processing scatter plot for date: 20220928
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220928_south.png
# Processing scatter plot for date: 20220929
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220929_south.png
# Processing scatter plot for date: 20220930
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20220930_south.png
# Processing scatter plot for date: 20221001
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221001_south.png
# Processing scatter plot for date: 20221002
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221002_south.png
# Processing scatter plot for date: 20221003
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221003_south.png
# Processing scatter plot for date: 20221004
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221004_south.png
# Processing scatter plot for date: 20221005
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221005_south.png
# Processing scatter plot for date: 20221006
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221006_south.png
# Processing scatter plot for date: 20221007
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221007_south.png
# Processing scatter plot for date: 20221008
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221008_south.png
# Processing scatter plot for date: 20221009
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221009_south.png
# Processing scatter plot for date: 20221010
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221010_south.png
# Processing scatter plot for date: 20221011
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221011_south.png
# Processing scatter plot for date: 20221012
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221012_south.png
# Processing scatter plot for date: 20221013
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221013_south.png
# Processing scatter plot for date: 20221014
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221014_south.png
# Processing scatter plot for date: 20221015
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221015_south.png
# Processing scatter plot for date: 20221016
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221016_south.png
# Processing scatter plot for date: 20221017
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221017_south.png
# Processing scatter plot for date: 20221018
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221018_south.png
# Processing scatter plot for date: 20221019
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221019_south.png
# Processing scatter plot for date: 20221020
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221020_south.png
# Processing scatter plot for date: 20221021
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221021_south.png
# Processing scatter plot for date: 20221022
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221022_south.png
# Processing scatter plot for date: 20221023
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221023_south.png
# Processing scatter plot for date: 20221024
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221024_south.png
# Processing scatter plot for date: 20221025
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221025_south.png
# Processing scatter plot for date: 20221026
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221026_south.png
# Processing scatter plot for date: 20221027
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221027_south.png
# Processing scatter plot for date: 20221028
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221028_south.png
# Processing scatter plot for date: 20221029
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221029_south.png
# Processing scatter plot for date: 20221030
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221030_south.png
# Processing scatter plot for date: 20221031
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221031_south.png
# Processing scatter plot for date: 20221101
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221101_south.png
# Processing scatter plot for date: 20221102
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221102_south.png
# Processing scatter plot for date: 20221103
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221103_south.png
# Processing scatter plot for date: 20221104
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221104_south.png
# Processing scatter plot for date: 20221105
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221105_south.png
# Processing scatter plot for date: 20221106
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221106_south.png
# Processing scatter plot for date: 20221107
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221107_south.png
# Processing scatter plot for date: 20221108
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221108_south.png
# Processing scatter plot for date: 20221109
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221109_south.png
# Processing scatter plot for date: 20221110
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221110_south.png
# Processing scatter plot for date: 20221111
# Missing file for date 20221111, skipping...
# Processing scatter plot for date: 20221112
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221112_south.png
# Processing scatter plot for date: 20221113
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221113_south.png
# Processing scatter plot for date: 20221114
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221114_south.png
# Processing scatter plot for date: 20221115
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221115_south.png
# Processing scatter plot for date: 20221116
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221116_south.png
# Processing scatter plot for date: 20221117
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221117_south.png
# Processing scatter plot for date: 20221118
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221118_south.png
# Processing scatter plot for date: 20221119
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221119_south.png
# Processing scatter plot for date: 20221120
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221120_south.png
# Processing scatter plot for date: 20221121
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221121_south.png
# Processing scatter plot for date: 20221122
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221122_south.png
# Processing scatter plot for date: 20221123
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221123_south.png
# Processing scatter plot for date: 20221124
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221124_south.png
# Processing scatter plot for date: 20221125
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221125_south.png
# Processing scatter plot for date: 20221126
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221126_south.png
# Processing scatter plot for date: 20221127
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221127_south.png
# Processing scatter plot for date: 20221128
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221128_south.png
# Processing scatter plot for date: 20221129
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221129_south.png
# Processing scatter plot for date: 20221130
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221130_south.png
# Processing scatter plot for date: 20221201
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221201_south.png
# Processing scatter plot for date: 20221202
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221202_south.png
# Processing scatter plot for date: 20221203
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221203_south.png
# Processing scatter plot for date: 20221204
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221204_south.png
# Processing scatter plot for date: 20221205
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221205_south.png
# Processing scatter plot for date: 20221206
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221206_south.png
# Processing scatter plot for date: 20221207
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221207_south.png
# Processing scatter plot for date: 20221208
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221208_south.png
# Processing scatter plot for date: 20221209
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221209_south.png
# Processing scatter plot for date: 20221210
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221210_south.png
# Processing scatter plot for date: 20221211
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221211_south.png
# Processing scatter plot for date: 20221212
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221212_south.png
# Processing scatter plot for date: 20221213
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221213_south.png
# Processing scatter plot for date: 20221214
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221214_south.png
# Processing scatter plot for date: 20221215
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221215_south.png
# Processing scatter plot for date: 20221216
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221216_south.png
# Processing scatter plot for date: 20221217
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221217_south.png
# Processing scatter plot for date: 20221218
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221218_south.png
# Processing scatter plot for date: 20221219
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221219_south.png
# Processing scatter plot for date: 20221220
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221220_south.png
# Processing scatter plot for date: 20221221
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221221_south.png
# Processing scatter plot for date: 20221222
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221222_south.png
# Processing scatter plot for date: 20221223
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221223_south.png
# Processing scatter plot for date: 20221224
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221224_south.png
# Processing scatter plot for date: 20221225
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221225_south.png
# Processing scatter plot for date: 20221226
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221226_south.png
# Processing scatter plot for date: 20221227
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221227_south.png
# Processing scatter plot for date: 20221228
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221228_south.png
# Processing scatter plot for date: 20221229
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221229_south.png
# Processing scatter plot for date: 20221230
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221230_south.png
# Processing scatter plot for date: 20221231
# Saved scatter plot: D:\zmh\icecon25000_data\FY\FY-3D\2_scatter_plots\scatter_comparison_20221231_south.png

# %% [markdown]
# ## 偏差对比

# %%
import numpy as np
import xarray as xr
import os
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
import pandas as pd 

plt.rcParams['font.sans-serif'] = ['SimHei']

def calculate_metrics(reference, corrected, original):
    """
    计算均方根误差（RMSE）、偏差（Bias） 和相关系数（CC）
    """
    # 有效数据掩模
    mask = ~np.isnan(reference) & ~np.isnan(corrected) & ~np.isnan(original)
    ref = reference[mask]
    corr = corrected[mask]
    orig = original[mask]
    
    # 计算 RMSE、Bias 和相关系数
    rmse_corrected = np.sqrt(mean_squared_error(ref, corr))
    rmse_original = np.sqrt(mean_squared_error(ref, orig))
    bias_corrected = np.mean(corr - ref)
    bias_original = np.mean(orig - ref)
    cc_corrected, _ = pearsonr(ref, corr)
    cc_original, _ = pearsonr(ref, orig)
    
    return {
        'RMSE (Corrected)': rmse_corrected,
        'RMSE (Original)': rmse_original,
        'Bias (Corrected)': bias_corrected,
        'Bias (Original)': bias_original,
        'CC (Corrected)': cc_corrected,
        'CC (Original)': cc_original
    }

def compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date):
    """
    比较PDF订正后的结果和原始数据与参考数据之间的差异
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)
    results = []
    
    for current_date in date_range:
        date_str = current_date.strftime('%Y%m%d')
        print(f"Processing date: {date_str}")
        
        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_north_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"FY3D_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        original_file = os.path.join(original_dir, f"FY3D_north_icecon_25000_{date_str}.nc")
        
        if not all(map(os.path.exists, [ref_file, corrected_file, original_file])):
            print(f"Skipping {date_str}, missing file.")
            continue
        
        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_north_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        original_data = xr.open_dataset(original_file)['FY3D_north_icecon'].values
        
        # 计算指标
        metrics = calculate_metrics(ref_data, corrected_data, original_data)
        metrics['Date'] = date_str
        results.append(metrics)
    
    # 保存结果为CSV文件
    results_df = pd.DataFrame(results)
    output_file = os.path.join(output_dir, 'comparison_metrics_north_OISST.csv')
    results_df.to_csv(output_file, index=False)
    print(f"Saved metrics to {output_file}")
    

if __name__ == "__main__":
    # 参数设置
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\north"
    corrected_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\1_PDFcorrected\north"
    original_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\0_pre_com\north"
    output_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\3_bias"
    hemisphere = "north"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    
    compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing date: 20220101
# Processing date: 20220102
# Processing date: 20220103
# Processing date: 20220104
# Processing date: 20220105
# Processing date: 20220106
# Processing date: 20220107
# Processing date: 20220108
# Processing date: 20220109
# Processing date: 20220110
# Processing date: 20220111
# Processing date: 20220112
# Processing date: 20220113
# Processing date: 20220114
# Processing date: 20220115
# Processing date: 20220116
# Processing date: 20220117
# Processing date: 20220118
# Processing date: 20220119
# Processing date: 20220120
# Processing date: 20220121
# Processing date: 20220122
# Processing date: 20220123
# Processing date: 20220124
# Skipping 20220124, missing file.
# Processing date: 20220125
# Processing date: 20220126
# Processing date: 20220127
# Skipping 20220127, missing file.
# Processing date: 20220128
# Processing date: 20220129
# Processing date: 20220130
# Processing date: 20220131
# Processing date: 20220201
# Processing date: 20220202
# Processing date: 20220203
# Processing date: 20220204
# Processing date: 20220205
# Processing date: 20220206
# Processing date: 20220207
# Processing date: 20220208
# Processing date: 20220209
# Processing date: 20220210
# Processing date: 20220211
# Processing date: 20220212
# Processing date: 20220213
# Processing date: 20220214
# Processing date: 20220215
# Processing date: 20220216
# Processing date: 20220217
# Processing date: 20220218
# Processing date: 20220219
# Processing date: 20220220
# Processing date: 20220221
# Processing date: 20220222
# Processing date: 20220223
# Processing date: 20220224
# Processing date: 20220225
# Processing date: 20220226
# Processing date: 20220227
# Processing date: 20220228
# Processing date: 20220301
# Processing date: 20220302
# Processing date: 20220303
# Processing date: 20220304
# Processing date: 20220305
# Processing date: 20220306
# Processing date: 20220307
# Processing date: 20220308
# Processing date: 20220309
# Processing date: 20220310
# Processing date: 20220311
# Processing date: 20220312
# Processing date: 20220313
# Processing date: 20220314
# Processing date: 20220315
# Processing date: 20220316
# Processing date: 20220317
# Processing date: 20220318
# Processing date: 20220319
# Processing date: 20220320
# Processing date: 20220321
# Processing date: 20220322
# Processing date: 20220323
# Processing date: 20220324
# Processing date: 20220325
# Processing date: 20220326
# Processing date: 20220327
# Processing date: 20220328
# Processing date: 20220329
# Processing date: 20220330
# Processing date: 20220331
# Processing date: 20220401
# Processing date: 20220402
# Processing date: 20220403
# Processing date: 20220404
# Processing date: 20220405
# Processing date: 20220406
# Processing date: 20220407
# Processing date: 20220408
# Processing date: 20220409
# Processing date: 20220410
# Processing date: 20220411
# Processing date: 20220412
# Processing date: 20220413
# Processing date: 20220414
# Processing date: 20220415
# Processing date: 20220416
# Processing date: 20220417
# Processing date: 20220418
# Processing date: 20220419
# Processing date: 20220420
# Processing date: 20220421
# Processing date: 20220422
# Processing date: 20220423
# Processing date: 20220424
# Processing date: 20220425
# Processing date: 20220426
# Processing date: 20220427
# Processing date: 20220428
# Processing date: 20220429
# Processing date: 20220430
# Processing date: 20220501
# Processing date: 20220502
# Processing date: 20220503
# Processing date: 20220504
# Processing date: 20220505
# Processing date: 20220506
# Processing date: 20220507
# Processing date: 20220508
# Processing date: 20220509
# Processing date: 20220510
# Processing date: 20220511
# Processing date: 20220512
# Processing date: 20220513
# Processing date: 20220514
# Processing date: 20220515
# Processing date: 20220516
# Processing date: 20220517
# Processing date: 20220518
# Processing date: 20220519
# Processing date: 20220520
# Processing date: 20220521
# Processing date: 20220522
# Processing date: 20220523
# Processing date: 20220524
# Processing date: 20220525
# Processing date: 20220526
# Processing date: 20220527
# Processing date: 20220528
# Processing date: 20220529
# Processing date: 20220530
# Processing date: 20220531
# Processing date: 20220601
# Processing date: 20220602
# Processing date: 20220603
# Processing date: 20220604
# Processing date: 20220605
# Processing date: 20220606
# Processing date: 20220607
# Processing date: 20220608
# Processing date: 20220609
# Processing date: 20220610
# Processing date: 20220611
# Processing date: 20220612
# Processing date: 20220613
# Processing date: 20220614
# Processing date: 20220615
# Processing date: 20220616
# Processing date: 20220617
# Processing date: 20220618
# Processing date: 20220619
# Processing date: 20220620
# Processing date: 20220621
# Processing date: 20220622
# Processing date: 20220623
# Processing date: 20220624
# Processing date: 20220625
# Processing date: 20220626
# Processing date: 20220627
# Processing date: 20220628
# Processing date: 20220629
# Processing date: 20220630
# Processing date: 20220701
# Processing date: 20220702
# Processing date: 20220703
# Processing date: 20220704
# Processing date: 20220705
# Processing date: 20220706
# Processing date: 20220707
# Processing date: 20220708
# Processing date: 20220709
# Processing date: 20220710
# Processing date: 20220711
# Processing date: 20220712
# Processing date: 20220713
# Processing date: 20220714
# Processing date: 20220715
# Processing date: 20220716
# Processing date: 20220717
# Processing date: 20220718
# Processing date: 20220719
# Processing date: 20220720
# Processing date: 20220721
# Processing date: 20220722
# Processing date: 20220723
# Processing date: 20220724
# Processing date: 20220725
# Processing date: 20220726
# Processing date: 20220727
# Processing date: 20220728
# Processing date: 20220729
# Processing date: 20220730
# Processing date: 20220731
# Processing date: 20220801
# Processing date: 20220802
# Processing date: 20220803
# Processing date: 20220804
# Processing date: 20220805
# Processing date: 20220806
# Processing date: 20220807
# Processing date: 20220808
# Processing date: 20220809
# Processing date: 20220810
# Processing date: 20220811
# Processing date: 20220812
# Processing date: 20220813
# Processing date: 20220814
# Processing date: 20220815
# Processing date: 20220816
# Processing date: 20220817
# Processing date: 20220818
# Processing date: 20220819
# Processing date: 20220820
# Processing date: 20220821
# Processing date: 20220822
# Processing date: 20220823
# Processing date: 20220824
# Processing date: 20220825
# Processing date: 20220826
# Processing date: 20220827
# Processing date: 20220828
# Processing date: 20220829
# Processing date: 20220830
# Processing date: 20220831
# Processing date: 20220901
# Processing date: 20220902
# Processing date: 20220903
# Processing date: 20220904
# Processing date: 20220905
# Processing date: 20220906
# Processing date: 20220907
# Processing date: 20220908
# Processing date: 20220909
# Processing date: 20220910
# Processing date: 20220911
# Processing date: 20220912
# Processing date: 20220913
# Processing date: 20220914
# Processing date: 20220915
# Processing date: 20220916
# Processing date: 20220917
# Processing date: 20220918
# Processing date: 20220919
# Processing date: 20220920
# Processing date: 20220921
# Processing date: 20220922
# Processing date: 20220923
# Processing date: 20220924
# Processing date: 20220925
# Processing date: 20220926
# Processing date: 20220927
# Processing date: 20220928
# Processing date: 20220929
# Processing date: 20220930
# Processing date: 20221001
# Processing date: 20221002
# Processing date: 20221003
# Processing date: 20221004
# Processing date: 20221005
# Processing date: 20221006
# Processing date: 20221007
# Processing date: 20221008
# Processing date: 20221009
# Processing date: 20221010
# Processing date: 20221011
# Processing date: 20221012
# Processing date: 20221013
# Processing date: 20221014
# Processing date: 20221015
# Processing date: 20221016
# Processing date: 20221017
# Processing date: 20221018
# Processing date: 20221019
# Processing date: 20221020
# Processing date: 20221021
# Processing date: 20221022
# Processing date: 20221023
# Processing date: 20221024
# Processing date: 20221025
# Processing date: 20221026
# Processing date: 20221027
# Processing date: 20221028
# Processing date: 20221029
# Processing date: 20221030
# Processing date: 20221031
# Processing date: 20221101
# Processing date: 20221102
# Processing date: 20221103
# Processing date: 20221104
# Processing date: 20221105
# Processing date: 20221106
# Processing date: 20221107
# Processing date: 20221108
# Processing date: 20221109
# Processing date: 20221110
# Processing date: 20221111
# Skipping 20221111, missing file.
# Processing date: 20221112
# Processing date: 20221113
# Processing date: 20221114
# Processing date: 20221115
# Processing date: 20221116
# Processing date: 20221117
# Processing date: 20221118
# Processing date: 20221119
# Processing date: 20221120
# Processing date: 20221121
# Processing date: 20221122
# Processing date: 20221123
# Processing date: 20221124
# Processing date: 20221125
# Processing date: 20221126
# Processing date: 20221127
# Processing date: 20221128
# Processing date: 20221129
# Processing date: 20221130
# Processing date: 20221201
# Processing date: 20221202
# Processing date: 20221203
# Processing date: 20221204
# Processing date: 20221205
# Processing date: 20221206
# Processing date: 20221207
# Processing date: 20221208
# Processing date: 20221209
# Processing date: 20221210
# Processing date: 20221211
# Processing date: 20221212
# Processing date: 20221213
# Processing date: 20221214
# Processing date: 20221215
# Processing date: 20221216
# Processing date: 20221217
# Processing date: 20221218
# Processing date: 20221219
# Processing date: 20221220
# Processing date: 20221221
# Processing date: 20221222
# Processing date: 20221223
# Processing date: 20221224
# Processing date: 20221225
# Processing date: 20221226
# Processing date: 20221227
# Processing date: 20221228
# Processing date: 20221229
# Processing date: 20221230
# Processing date: 20221231
# Saved metrics to D:\zmh\icecon25000_data\FY\FY-3D\3_bias\comparison_metrics_north_OISST.csv

# %%
import numpy as np
import xarray as xr
import os
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
import pandas as pd 

plt.rcParams['font.sans-serif'] = ['SimHei']

def calculate_metrics(reference, corrected, original):
    """
    计算均方根误差（RMSE）、偏差（Bias） 和相关系数（CC）
    """
    # 有效数据掩模
    mask = ~np.isnan(reference) & ~np.isnan(corrected) & ~np.isnan(original)
    ref = reference[mask]
    corr = corrected[mask]
    orig = original[mask]
    
    # 计算 RMSE、Bias 和相关系数
    rmse_corrected = np.sqrt(mean_squared_error(ref, corr))
    rmse_original = np.sqrt(mean_squared_error(ref, orig))
    bias_corrected = np.mean(corr - ref)
    bias_original = np.mean(orig - ref)
    cc_corrected, _ = pearsonr(ref, corr)
    cc_original, _ = pearsonr(ref, orig)
    
    return {
        'RMSE (Corrected)': rmse_corrected,
        'RMSE (Original)': rmse_original,
        'Bias (Corrected)': bias_corrected,
        'Bias (Original)': bias_original,
        'CC (Corrected)': cc_corrected,
        'CC (Original)': cc_original
    }

def compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date):
    """
    比较PDF订正后的结果和原始数据与参考数据之间的差异
    """
    os.makedirs(output_dir, exist_ok=True)
    date_range = pd.date_range(start=start_date, end=end_date)
    results = []
    
    for current_date in date_range:
        date_str = current_date.strftime('%Y%m%d')
        print(f"Processing date: {date_str}")
        
        # 文件路径
        ref_file = os.path.join(reference_dir, f"NSIDC-BS_south_icecon_25000_{date_str}.nc")
        corrected_file = os.path.join(corrected_dir, f"FY3D_pdfcorrected_{hemisphere}_icecon_25000_{date_str}.nc")
        original_file = os.path.join(original_dir, f"FY3D_south_icecon_25000_{date_str}.nc")
        
        if not all(map(os.path.exists, [ref_file, corrected_file, original_file])):
            print(f"Skipping {date_str}, missing file.")
            continue
        
        # 读取数据
        ref_data = xr.open_dataset(ref_file)['NSIDC-BS_south_icecon'].values
        corrected_data = xr.open_dataset(corrected_file)['ice_concentration'].values
        original_data = xr.open_dataset(original_file)['FY3D_south_icecon'].values
        
        # 计算指标
        metrics = calculate_metrics(ref_data, corrected_data, original_data)
        metrics['Date'] = date_str
        results.append(metrics)
    
    # 保存结果为CSV文件
    results_df = pd.DataFrame(results)
    output_file = os.path.join(output_dir, 'comparison_metrics_south_OISST.csv')
    results_df.to_csv(output_file, index=False)
    print(f"Saved metrics to {output_file}")
    

if __name__ == "__main__":
    # 参数设置
    reference_dir = r"D:\zmh\icecon25000_data\NSIDC-Bootstrap\0_pre_com\south"
    corrected_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\1_PDFcorrected\south"
    original_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\0_pre_com\south"
    output_dir = r"D:\zmh\icecon25000_data\FY\FY-3D\3_bias"
    hemisphere = "south"
    start_date = "2022-01-01"
    end_date = "2022-12-31"

    
    compare_datasets(reference_dir, corrected_dir, original_dir, output_dir, hemisphere, start_date, end_date)
# Out:
# Processing date: 20220101
# Processing date: 20220102
# Processing date: 20220103
# Processing date: 20220104
# Processing date: 20220105
# Processing date: 20220106
# Processing date: 20220107
# Processing date: 20220108
# Processing date: 20220109
# Processing date: 20220110
# Processing date: 20220111
# Processing date: 20220112
# Processing date: 20220113
# Processing date: 20220114
# Processing date: 20220115
# Processing date: 20220116
# Processing date: 20220117
# Processing date: 20220118
# Processing date: 20220119
# Processing date: 20220120
# Processing date: 20220121
# Processing date: 20220122
# Processing date: 20220123
# Processing date: 20220124
# Skipping 20220124, missing file.
# Processing date: 20220125
# Processing date: 20220126
# Processing date: 20220127
# Skipping 20220127, missing file.
# Processing date: 20220128
# Processing date: 20220129
# Processing date: 20220130
# Processing date: 20220131
# Processing date: 20220201
# Processing date: 20220202
# Processing date: 20220203
# Processing date: 20220204
# Processing date: 20220205
# Processing date: 20220206
# Processing date: 20220207
# Processing date: 20220208
# Processing date: 20220209
# Processing date: 20220210
# Processing date: 20220211
# Processing date: 20220212
# Processing date: 20220213
# Processing date: 20220214
# Processing date: 20220215
# Processing date: 20220216
# Processing date: 20220217
# Processing date: 20220218
# Processing date: 20220219
# Processing date: 20220220
# Processing date: 20220221
# Processing date: 20220222
# Processing date: 20220223
# Processing date: 20220224
# Processing date: 20220225
# Processing date: 20220226
# Processing date: 20220227
# Processing date: 20220228
# Processing date: 20220301
# Processing date: 20220302
# Processing date: 20220303
# Processing date: 20220304
# Processing date: 20220305
# Processing date: 20220306
# Processing date: 20220307
# Processing date: 20220308
# Processing date: 20220309
# Processing date: 20220310
# Processing date: 20220311
# Processing date: 20220312
# Processing date: 20220313
# Processing date: 20220314
# Processing date: 20220315
# Processing date: 20220316
# Processing date: 20220317
# Processing date: 20220318
# Processing date: 20220319
# Processing date: 20220320
# Processing date: 20220321
# Processing date: 20220322
# Processing date: 20220323
# Processing date: 20220324
# Processing date: 20220325
# Processing date: 20220326
# Processing date: 20220327
# Processing date: 20220328
# Processing date: 20220329
# Processing date: 20220330
# Processing date: 20220331
# Processing date: 20220401
# Processing date: 20220402
# Processing date: 20220403
# Processing date: 20220404
# Processing date: 20220405
# Processing date: 20220406
# Processing date: 20220407
# Processing date: 20220408
# Processing date: 20220409
# Processing date: 20220410
# Processing date: 20220411
# Processing date: 20220412
# Processing date: 20220413
# Processing date: 20220414
# Processing date: 20220415
# Processing date: 20220416
# Processing date: 20220417
# Processing date: 20220418
# Processing date: 20220419
# Processing date: 20220420
# Processing date: 20220421
# Processing date: 20220422
# Processing date: 20220423
# Processing date: 20220424
# Processing date: 20220425
# Processing date: 20220426
# Processing date: 20220427
# Processing date: 20220428
# Processing date: 20220429
# Processing date: 20220430
# Processing date: 20220501
# Processing date: 20220502
# Processing date: 20220503
# Processing date: 20220504
# Processing date: 20220505
# Processing date: 20220506
# Processing date: 20220507
# Processing date: 20220508
# Processing date: 20220509
# Processing date: 20220510
# Processing date: 20220511
# Processing date: 20220512
# Processing date: 20220513
# Processing date: 20220514
# Processing date: 20220515
# Processing date: 20220516
# Processing date: 20220517
# Processing date: 20220518
# Processing date: 20220519
# Processing date: 20220520
# Processing date: 20220521
# Processing date: 20220522
# Processing date: 20220523
# Processing date: 20220524
# Processing date: 20220525
# Processing date: 20220526
# Processing date: 20220527
# Processing date: 20220528
# Processing date: 20220529
# Processing date: 20220530
# Processing date: 20220531
# Processing date: 20220601
# Processing date: 20220602
# Processing date: 20220603
# Processing date: 20220604
# Processing date: 20220605
# Processing date: 20220606
# Processing date: 20220607
# Processing date: 20220608
# Processing date: 20220609
# Processing date: 20220610
# Processing date: 20220611
# Processing date: 20220612
# Processing date: 20220613
# Processing date: 20220614
# Processing date: 20220615
# Processing date: 20220616
# Processing date: 20220617
# Processing date: 20220618
# Processing date: 20220619
# Processing date: 20220620
# Processing date: 20220621
# Processing date: 20220622
# Processing date: 20220623
# Processing date: 20220624
# Processing date: 20220625
# Processing date: 20220626
# Processing date: 20220627
# Processing date: 20220628
# Processing date: 20220629
# Processing date: 20220630
# Processing date: 20220701
# Processing date: 20220702
# Processing date: 20220703
# Processing date: 20220704
# Processing date: 20220705
# Processing date: 20220706
# Processing date: 20220707
# Processing date: 20220708
# Processing date: 20220709
# Processing date: 20220710
# Processing date: 20220711
# Processing date: 20220712
# Processing date: 20220713
# Processing date: 20220714
# Processing date: 20220715
# Processing date: 20220716
# Processing date: 20220717
# Processing date: 20220718
# Processing date: 20220719
# Processing date: 20220720
# Processing date: 20220721
# Processing date: 20220722
# Processing date: 20220723
# Processing date: 20220724
# Processing date: 20220725
# Processing date: 20220726
# Processing date: 20220727
# Processing date: 20220728
# Processing date: 20220729
# Processing date: 20220730
# Processing date: 20220731
# Processing date: 20220801
# Processing date: 20220802
# Processing date: 20220803
# Processing date: 20220804
# Processing date: 20220805
# Processing date: 20220806
# Processing date: 20220807
# Processing date: 20220808
# Processing date: 20220809
# Processing date: 20220810
# Processing date: 20220811
# Processing date: 20220812
# Processing date: 20220813
# Processing date: 20220814
# Processing date: 20220815
# Processing date: 20220816
# Processing date: 20220817
# Processing date: 20220818
# Processing date: 20220819
# Processing date: 20220820
# Processing date: 20220821
# Processing date: 20220822
# Processing date: 20220823
# Processing date: 20220824
# Processing date: 20220825
# Processing date: 20220826
# Processing date: 20220827
# Processing date: 20220828
# Processing date: 20220829
# Processing date: 20220830
# Processing date: 20220831
# Processing date: 20220901
# Processing date: 20220902
# Processing date: 20220903
# Processing date: 20220904
# Processing date: 20220905
# Processing date: 20220906
# Processing date: 20220907
# Processing date: 20220908
# Processing date: 20220909
# Processing date: 20220910
# Processing date: 20220911
# Processing date: 20220912
# Processing date: 20220913
# Processing date: 20220914
# Processing date: 20220915
# Processing date: 20220916
# Processing date: 20220917
# Processing date: 20220918
# Processing date: 20220919
# Processing date: 20220920
# Processing date: 20220921
# Processing date: 20220922
# Processing date: 20220923
# Processing date: 20220924
# Processing date: 20220925
# Processing date: 20220926
# Processing date: 20220927
# Processing date: 20220928
# Processing date: 20220929
# Processing date: 20220930
# Processing date: 20221001
# Processing date: 20221002
# Processing date: 20221003
# Processing date: 20221004
# Processing date: 20221005
# Processing date: 20221006
# Processing date: 20221007
# Processing date: 20221008
# Processing date: 20221009
# Processing date: 20221010
# Processing date: 20221011
# Processing date: 20221012
# Processing date: 20221013
# Processing date: 20221014
# Processing date: 20221015
# Processing date: 20221016
# Processing date: 20221017
# Processing date: 20221018
# Processing date: 20221019
# Processing date: 20221020
# Processing date: 20221021
# Processing date: 20221022
# Processing date: 20221023
# Processing date: 20221024
# Processing date: 20221025
# Processing date: 20221026
# Processing date: 20221027
# Processing date: 20221028
# Processing date: 20221029
# Processing date: 20221030
# Processing date: 20221031
# Processing date: 20221101
# Processing date: 20221102
# Processing date: 20221103
# Processing date: 20221104
# Processing date: 20221105
# Processing date: 20221106
# Processing date: 20221107
# Processing date: 20221108
# Processing date: 20221109
# Processing date: 20221110
# Processing date: 20221111
# Skipping 20221111, missing file.
# Processing date: 20221112
# Processing date: 20221113
# Processing date: 20221114
# Processing date: 20221115
# Processing date: 20221116
# Processing date: 20221117
# Processing date: 20221118
# Processing date: 20221119
# Processing date: 20221120
# Processing date: 20221121
# Processing date: 20221122
# Processing date: 20221123
# Processing date: 20221124
# Processing date: 20221125
# Processing date: 20221126
# Processing date: 20221127
# Processing date: 20221128
# Processing date: 20221129
# Processing date: 20221130
# Processing date: 20221201
# Processing date: 20221202
# Processing date: 20221203
# Processing date: 20221204
# Processing date: 20221205
# Processing date: 20221206
# Processing date: 20221207
# Processing date: 20221208
# Processing date: 20221209
# Processing date: 20221210
# Processing date: 20221211
# Processing date: 20221212
# Processing date: 20221213
# Processing date: 20221214
# Processing date: 20221215
# Processing date: 20221216
# Processing date: 20221217
# Processing date: 20221218
# Processing date: 20221219
# Processing date: 20221220
# Processing date: 20221221
# Processing date: 20221222
# Processing date: 20221223
# Processing date: 20221224
# Processing date: 20221225
# Processing date: 20221226
# Processing date: 20221227
# Processing date: 20221228
# Processing date: 20221229
# Processing date: 20221230
# Processing date: 20221231
# Saved metrics to D:\zmh\icecon25000_data\FY\FY-3D\3_bias\comparison_metrics_south_OISST.csv
